# %%
import sys
sys.path.append('/mnt/disk1/yunseob/Pytorch/SSM/0_modules')
from SSM_utils import GBdataLoad
from SSM_DL_training import CNN_Training

# %%
data_dir = '/mnt/disk1/yunseob/Pytorch/SSM/1_Semblex/06_no_overlap/SemblexData/wt_4040'

GB_Xs, GB_Ys = GBdataLoad(data_dir, ch = [0, 1], data_type = '3_train_data')

# %%
CT = CNN_Training(GB_Xs, GB_Ys, n_ch = 2, n_cls = 2, lr = 0.0001, n_batch_per_cls = 100, n_iter = 15000, model_name = 'GB_00p_AB', GPU_idx = 3)

CT.Run(model_dir = './model/', hist_dir = './results/0_train_hist/npy/')
# Out:
# 0 (1952, 2, 40, 40) (1952,)
# 0 train: (1756, 2, 40, 40) (1756,) valid: (196, 2, 40, 40) (196,)
# 1 (3050, 2, 40, 40) (3050,)
# 1 train: (2745, 2, 40, 40) (2745,) valid: (305, 2, 40, 40) (305,)
#
# Device: GeForce RTX 2080 Ti
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 40, 40]           1,216
#             Conv2d-2           [-1, 64, 40, 40]          36,928
#        BatchNorm2d-3           [-1, 64, 40, 40]             128
#          MaxPool2d-4           [-1, 64, 20, 20]               0
#             Conv2d-5           [-1, 64, 20, 20]          36,928
#             Conv2d-6           [-1, 64, 20, 20]          36,928
#        BatchNorm2d-7           [-1, 64, 20, 20]             128
#          MaxPool2d-8           [-1, 64, 10, 10]               0
#             Conv2d-9           [-1, 64, 10, 10]          36,928
# ...

# %%
CT = CNN_Training(GB_Xs, GB_Ys, n_ch = 2, n_cls = 2, lr = 0.001, n_batch_per_cls = 100, n_iter = 15000, model_name = 'GB_00p_AB', GPU_idx = 3)

CT.Run(model_dir = './model/', hist_dir = './results/0_train_hist/npy/')
# Out:
# 0 (1952, 2, 40, 40) (1952,)
# 0 train: (1756, 2, 40, 40) (1756,) valid: (196, 2, 40, 40) (196,)
# 1 (3050, 2, 40, 40) (3050,)
# 1 train: (2745, 2, 40, 40) (2745,) valid: (305, 2, 40, 40) (305,)
#
# Device: GeForce RTX 2080 Ti
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 40, 40]           1,216
#             Conv2d-2           [-1, 64, 40, 40]          36,928
#        BatchNorm2d-3           [-1, 64, 40, 40]             128
#          MaxPool2d-4           [-1, 64, 20, 20]               0
#             Conv2d-5           [-1, 64, 20, 20]          36,928
#             Conv2d-6           [-1, 64, 20, 20]          36,928
#        BatchNorm2d-7           [-1, 64, 20, 20]             128
#          MaxPool2d-8           [-1, 64, 10, 10]               0
#             Conv2d-9           [-1, 64, 10, 10]          36,928
# ...

# %%
CT = CNN_Training(GB_Xs, GB_Ys, n_ch = 2, n_cls = 2, lr = 0.00001, n_batch_per_cls = 30, n_iter = 15000, model_name = 'GB_00p_AB', GPU_idx = 3)

CT.Run(model_dir = './model/', hist_dir = './results/0_train_hist/npy/')
# Out:
# 0 (1952, 2, 40, 40) (1952,)
# 0 train: (1756, 2, 40, 40) (1756,) valid: (196, 2, 40, 40) (196,)
# 1 (3050, 2, 40, 40) (3050,)
# 1 train: (2745, 2, 40, 40) (2745,) valid: (305, 2, 40, 40) (305,)
#
# Device: GeForce RTX 2080 Ti
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 40, 40]           1,216
#             Conv2d-2           [-1, 64, 40, 40]          36,928
#        BatchNorm2d-3           [-1, 64, 40, 40]             128
#          MaxPool2d-4           [-1, 64, 20, 20]               0
#             Conv2d-5           [-1, 64, 20, 20]          36,928
#             Conv2d-6           [-1, 64, 20, 20]          36,928
#        BatchNorm2d-7           [-1, 64, 20, 20]             128
#          MaxPool2d-8           [-1, 64, 10, 10]               0
#             Conv2d-9           [-1, 64, 10, 10]          36,928
# ...

# %%
CT = CNN_Training(GB_Xs, GB_Ys, n_ch = 2, n_cls = 2, lr = 0.001, n_batch_per_cls = 30, n_iter = 10000, model_name = 'GB_00p_AB', GPU_idx = 3)

CT.Run(model_dir = './model/', hist_dir = './results/0_train_hist/npy/')
# Out:
# 0 (1952, 2, 40, 40) (1952,)
# 0 train: (1756, 2, 40, 40) (1756,) valid: (196, 2, 40, 40) (196,)
# 1 (3050, 2, 40, 40) (3050,)
# 1 train: (2745, 2, 40, 40) (2745,) valid: (305, 2, 40, 40) (305,)
#
# Device: GeForce RTX 2080 Ti
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 40, 40]           1,216
#             Conv2d-2           [-1, 64, 40, 40]          36,928
#        BatchNorm2d-3           [-1, 64, 40, 40]             128
#          MaxPool2d-4           [-1, 64, 20, 20]               0
#             Conv2d-5           [-1, 64, 20, 20]          36,928
#             Conv2d-6           [-1, 64, 20, 20]          36,928
#        BatchNorm2d-7           [-1, 64, 20, 20]             128
#          MaxPool2d-8           [-1, 64, 10, 10]               0
#             Conv2d-9           [-1, 64, 10, 10]          36,928
# ...

# %%
CT = CNN_Training(GB_Xs, GB_Ys, n_ch = 2, n_cls = 2, lr = 0.0001, n_batch_per_cls = 30, n_iter = 10000, model_name = 'GB_00p_AB', GPU_idx = 3)

CT.Run(model_dir = './model/', hist_dir = './results/0_train_hist/npy/')
# Out:
# 0 (1952, 2, 40, 40) (1952,)
# 0 train: (1756, 2, 40, 40) (1756,) valid: (196, 2, 40, 40) (196,)
# 1 (3050, 2, 40, 40) (3050,)
# 1 train: (2745, 2, 40, 40) (2745,) valid: (305, 2, 40, 40) (305,)
#
# Device: GeForce RTX 2080 Ti
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 40, 40]           1,216
#             Conv2d-2           [-1, 64, 40, 40]          36,928
#        BatchNorm2d-3           [-1, 64, 40, 40]             128
#          MaxPool2d-4           [-1, 64, 20, 20]               0
#             Conv2d-5           [-1, 64, 20, 20]          36,928
#             Conv2d-6           [-1, 64, 20, 20]          36,928
#        BatchNorm2d-7           [-1, 64, 20, 20]             128
#          MaxPool2d-8           [-1, 64, 10, 10]               0
#             Conv2d-9           [-1, 64, 10, 10]          36,928
# ...
