# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import itertools

import sys
sys.path.append('/mnt/disk1/yunseob/Pytorch/SSM/0_modules')
from SSM_utils import GBdataLoad, B6dataLoad
from SSM_DL_evl import SSM_Model

from sklearn.metrics import roc_curve, auc

# %%
model_dir = './model/'
CM_save_dir = './results/1_confusion_mat/'

# %%
data_dir = '/mnt/disk1/yunseob/Pytorch/SSM/1_Semblex/06_no_overlap/SemblexData/wt_4040'

GB_test_X, GB_test_Y = GBdataLoad(data_dir, ch = [0, 1], data_type = '4_test_data')
B6_test_X, B6_test_Y = B6dataLoad(data_dir, ch = [0, 1], data_type = '4_test_data')

# %%
GB_train_X, GB_train_Y = GBdataLoad(data_dir, ch = [0, 1], data_type = '3_train_data')
B6_train_X, B6_train_Y = B6dataLoad(data_dir, ch = [0, 1], data_type = '3_train_data')

GB_train_X, GB_train_Y = np.concatenate(GB_train_X), np.concatenate(GB_train_Y)
B6_train_X, B6_train_Y = np.concatenate(B6_train_X), np.concatenate(B6_train_Y)

# %% [markdown]
# # 1. Fault diagnosis

# %%
class_name = ['Good', 'Bad']

# %%
GB_00p_AB_model = SSM_Model(GB_train_X, GB_train_Y, n_ch = 2, n_cls = 2, class_name = class_name, 
                            model_dir = model_dir, model_name = 'GB_00p_AB', batch_size = 20, GPU_idx = 3)

GB_00p_AB_model.Evaluation()
# Out:
# Model: GB_00p_AB_2004250141_02010_accr_0.9511_loss_0.140956_val_accr_0.9641_val_loss_0.121130.pt
#
# Accuracy: 95.24 % (4764 / 5002)
#
# Model: GB_00p_AB_2004250141_02380_accr_0.9784_loss_0.082123_val_accr_0.9701_val_loss_0.090582.pt
#
# Accuracy: 97.76 % (4890 / 5002)
#
# Model: GB_00p_AB_2004250141_02450_accr_0.9818_loss_0.057705_val_accr_0.9780_val_loss_0.073560.pt
#
# Accuracy: 98.14 % (4909 / 5002)
#
# Model: GB_00p_AB_2004250142_02940_accr_0.9871_loss_0.045665_val_accr_0.9780_val_loss_0.054926.pt
#
# Accuracy: 98.62 % (4933 / 5002)
#
# Model: GB_00p_AB_2004250143_03410_accr_0.9900_loss_0.028959_val_accr_0.9880_val_loss_0.046095.pt
#
# Accuracy: 98.98 % (4951 / 5002)
#
# Model: GB_00p_AB_2004250148_06720_accr_0.9978_loss_0.021777_val_accr_0.9880_val_loss_0.066300.pt
#
# Accuracy: 99.68 % (4986 / 5002)
#
# Model: GB_00p_AB_2004250149_07080_accr_0.9996_loss_0.004953_val_accr_0.9880_val_loss_0.050917.pt
#
# Accuracy: 99.84 % (4994 / 5002)
#
# Model: GB_00p_AB_2004250149_07090_accr_0.9976_loss_0.006449_val_accr_0.9880_val_loss_0.046520.pt
#
# Accuracy: 99.66 % (4985 / 5002)
#
# Model: GB_00p_AB_2004250149_07120_accr_0.9984_loss_0.006323_val_accr_0.9880_val_loss_0.042834.pt
#
# Accuracy: 99.74 % (4989 / 5002)
#
# Model: GB_00p_AB_2004250204_01070_accr_0.9516_loss_0.125702_val_accr_0.9461_val_loss_0.151110.pt
#
# Accuracy: 95.10 % (4757 / 5002)
#
# Model: GB_00p_AB_2004250205_01230_accr_0.9587_loss_0.100010_val_accr_0.9461_val_loss_0.147217.pt
#
# Accuracy: 95.74 % (4789 / 5002)
#
# Model: GB_00p_AB_2004250205_01300_accr_0.9560_loss_0.114029_val_accr_0.9461_val_loss_0.154751.pt
#
# Accuracy: 95.50 % (4777 / 5002)
#
# Model: GB_00p_AB_2004250205_01390_accr_0.9638_loss_0.088429_val_accr_0.9561_val_loss_0.132705.pt
#
# Accuracy: 96.30 % (4817 / 5002)
#
# Model: GB_00p_AB_2004250205_01720_accr_0.9629_loss_0.116879_val_accr_0.9601_val_loss_0.189218.pt
#
# Accuracy: 96.26 % (4815 / 5002)
#
# Model: GB_00p_AB_2004250205_01850_accr_0.9693_loss_0.082610_val_accr_0.9621_val_loss_0.160545.pt
#
# Accuracy: 96.86 % (4845 / 5002)
#
# Model: GB_00p_AB_2004250206_01900_accr_0.9898_loss_0.030041_val_accr_0.9721_val_loss_0.081170.pt
#
# Accuracy: 98.80 % (4942 / 5002)
#
# Model: GB_00p_AB_2004250206_02000_accr_0.9893_loss_0.034395_val_accr_0.9721_val_loss_0.072475.pt
#
# Accuracy: 98.76 % (4940 / 5002)
#
# Model: GB_00p_AB_2004250206_02360_accr_0.9953_loss_0.018491_val_accr_0.9760_val_loss_0.056012.pt
#
# Accuracy: 99.34 % (4969 / 5002)
#
# Model: GB_00p_AB_2004250207_02720_accr_0.9958_loss_0.012976_val_accr_0.9760_val_loss_0.061763.pt
#
# Accuracy: 99.38 % (4971 / 5002)
#
# Model: GB_00p_AB_2004250208_03550_accr_0.9953_loss_0.012847_val_accr_0.9780_val_loss_0.069875.pt
#
# Accuracy: 99.36 % (4970 / 5002)
#
# Model: GB_00p_AB_2004250209_03780_accr_0.9882_loss_0.030318_val_accr_0.9800_val_loss_0.081409.pt
#
# Accuracy: 98.74 % (4939 / 5002)
#
# Model: GB_00p_AB_2004250210_04450_accr_0.9982_loss_0.004493_val_accr_0.9820_val_loss_0.064509.pt
#
# Accuracy: 99.66 % (4985 / 5002)
#
# Model: GB_00p_AB_2004250211_05260_accr_0.9944_loss_0.016659_val_accr_0.9820_val_loss_0.077775.pt
#
# Accuracy: 99.32 % (4968 / 5002)
#
# Model: GB_00p_AB_2004250649_00750_accr_0.9656_loss_0.096823_val_accr_0.9701_val_loss_0.093136.pt
#
# Accuracy: 96.60 % (4832 / 5002)
#
# Model: GB_00p_AB_2004250649_00840_accr_0.9871_loss_0.031199_val_accr_0.9880_val_loss_0.040621.pt
#
# Accuracy: 98.72 % (4938 / 5002)
#
# Model: GB_00p_AB_2004250650_01290_accr_0.9844_loss_0.042875_val_accr_0.9900_val_loss_0.050185.pt
#
# Accuracy: 98.50 % (4927 / 5002)
#
# Model: GB_00p_AB_2004250651_01330_accr_0.9960_loss_0.010401_val_accr_0.9900_val_loss_0.022835.pt
#
# Accuracy: 99.54 % (4979 / 5002)
#
# Model: GB_00p_AB_2004250651_01420_accr_0.9993_loss_0.002721_val_accr_0.9920_val_loss_0.034211.pt
#
# Accuracy: 99.86 % (4995 / 5002)
#
# Model: GB_00p_AB_2004250651_01680_accr_0.9991_loss_0.002975_val_accr_0.9940_val_loss_0.015362.pt
#
# Accuracy: 99.86 % (4995 / 5002)
#
# Model: GB_00p_AB_2004250654_02430_accr_1.0000_loss_0.000186_val_accr_0.9960_val_loss_0.013816.pt
#
# Accuracy: 99.96 % (5000 / 5002)
#
# Model: GB_00p_AB_2004250654_02440_accr_1.0000_loss_0.000074_val_accr_0.9960_val_loss_0.019561.pt
#
# Accuracy: 99.96 % (5000 / 5002)
#
# Model: GB_00p_AB_2004250654_02450_accr_1.0000_loss_0.000067_val_accr_0.9960_val_loss_0.020190.pt
#
# Accuracy: 99.96 % (5000 / 5002)
#
# Model: GB_00p_AB_2004250654_02460_accr_1.0000_loss_0.000041_val_accr_0.9960_val_loss_0.015573.pt
#
# Accuracy: 99.96 % (5000 / 5002)
#
# Model: GB_00p_AB_2004250654_02530_accr_1.0000_loss_0.000322_val_accr_0.9960_val_loss_0.010226.pt
#
# Accuracy: 99.96 % (5000 / 5002)
#
# Model: GB_00p_AB_2004250654_02540_accr_0.9987_loss_0.004764_val_accr_0.9960_val_loss_0.015342.pt
#
# Accuracy: 99.84 % (4994 / 5002)
#
# Model: GB_00p_AB_2004250654_02560_accr_1.0000_loss_0.000153_val_accr_1.0000_val_loss_0.002307.pt
#
# Accuracy: 100.00 % (5002 / 5002)
#
# Model: GB_00p_AB_2004250654_02700_accr_1.0000_loss_0.000499_val_accr_1.0000_val_loss_0.001855.pt
#
# Accuracy: 100.00 % (5002 / 5002)
#
# Model: GB_00p_AB_2004250654_02740_accr_1.0000_loss_0.000032_val_accr_1.0000_val_loss_0.001346.pt
#
# Accuracy: 100.00 % (5002 / 5002)
#
# Model: GB_00p_AB_2004250654_02750_accr_1.0000_loss_0.000060_val_accr_1.0000_val_loss_0.000837.pt
#
# Accuracy: 100.00 % (5002 / 5002)
#
# Model: GB_00p_AB_2004250655_02860_accr_1.0000_loss_0.000155_val_accr_1.0000_val_loss_0.001658.pt
#
# Accuracy: 100.00 % (5002 / 5002)
#
# Model: GB_00p_AB_2004250655_02870_accr_1.0000_loss_0.000201_val_accr_1.0000_val_loss_0.001829.pt
#
# Accuracy: 100.00 % (5002 / 5002)
#
# Model: GB_00p_AB_2004250655_02880_accr_1.0000_loss_0.000023_val_accr_1.0000_val_loss_0.001852.pt
#
# Accuracy: 100.00 % (5002 / 5002)
#
# Model: GB_00p_AB_2004250655_02890_accr_1.0000_loss_0.000108_val_accr_1.0000_val_loss_0.001029.pt
#
# Accuracy: 100.00 % (5002 / 5002)
#
# Model: GB_00p_AB_2004250655_02900_accr_1.0000_loss_0.000025_val_accr_1.0000_val_loss_0.001229.pt
#
# Accuracy: 100.00 % (5002 / 5002)
#
# Model: GB_00p_AB_2004250655_02910_accr_1.0000_loss_0.000019_val_accr_1.0000_val_loss_0.001320.pt
#
# Accuracy: 100.00 % (5002 / 5002)
#
# Model: GB_00p_AB_2004250655_02970_accr_1.0000_loss_0.000213_val_accr_1.0000_val_loss_0.002044.pt
#
# Accuracy: 100.00 % (5002 / 5002)
#
# Model: GB_00p_AB_2004250655_02990_accr_1.0000_loss_0.000046_val_accr_1.0000_val_loss_0.000837.pt
#
# Accuracy: 100.00 % (5002 / 5002)
#
# Model: GB_00p_AB_2004250655_03000_accr_1.0000_loss_0.000012_val_accr_1.0000_val_loss_0.001440.pt
#
# Accuracy: 100.00 % (5002 / 5002)
#
# Model: GB_00p_AB_2004250655_03040_accr_1.0000_loss_0.000027_val_accr_1.0000_val_loss_0.001047.pt
#
# Accuracy: 100.00 % (5002 / 5002)
#
# Model: GB_00p_AB_2004250655_03080_accr_1.0000_loss_0.000074_val_accr_1.0000_val_loss_0.001114.pt
#
# Accuracy: 100.00 % (5002 / 5002)
#
# Model: GB_00p_AB_2004250656_03170_accr_1.0000_loss_0.000021_val_accr_1.0000_val_loss_0.000548.pt
#
# Accuracy: 100.00 % (5002 / 5002)
#
# Model: GB_00p_AB_2004250656_03180_accr_1.0000_loss_0.000072_val_accr_1.0000_val_loss_0.001302.pt
#
# Accuracy: 100.00 % (5002 / 5002)
#
# Model: GB_00p_AB_2004250656_03250_accr_1.0000_loss_0.000091_val_accr_1.0000_val_loss_0.002081.pt
#
# Accuracy: 100.00 % (5002 / 5002)
#
# Model: GB_00p_AB_2004250656_03260_accr_1.0000_loss_0.000011_val_accr_1.0000_val_loss_0.000799.pt
#
# Accuracy: 100.00 % (5002 / 5002)
#
# Model: GB_00p_AB_2004250656_03270_accr_1.0000_loss_0.000006_val_accr_1.0000_val_loss_0.001104.pt
#
# Accuracy: 100.00 % (5002 / 5002)
#
# Model: GB_00p_AB_2004250656_03300_accr_1.0000_loss_0.000112_val_accr_1.0000_val_loss_0.002654.pt
#
# Accuracy: 100.00 % (5002 / 5002)
#
# Model: GB_00p_AB_2004250657_03640_accr_1.0000_loss_0.000011_val_accr_1.0000_val_loss_0.002620.pt
#
# Accuracy: 100.00 % (5002 / 5002)
#
# Model: GB_00p_AB_2004250657_03780_accr_1.0000_loss_0.000021_val_accr_1.0000_val_loss_0.001765.pt
#
# Accuracy: 100.00 % (5002 / 5002)
#
# Model: GB_00p_AB_2004250657_03860_accr_1.0000_loss_0.000047_val_accr_1.0000_val_loss_0.003560.pt
#
# Accuracy: 100.00 % (5002 / 5002)
#
# Model: GB_00p_AB_2004250658_03870_accr_1.0000_loss_0.000005_val_accr_1.0000_val_loss_0.001843.pt
#
# Accuracy: 100.00 % (5002 / 5002)
#
# Model: GB_00p_AB_2004250659_04280_accr_1.0000_loss_0.000093_val_accr_1.0000_val_loss_0.004626.pt
#
# Accuracy: 100.00 % (5002 / 5002)
#
# Model: GB_00p_AB_2004250703_05720_accr_1.0000_loss_0.000052_val_accr_1.0000_val_loss_0.004998.pt
#
# Accuracy: 100.00 % (5002 / 5002)
#
# Model: GB_00p_AB_2004250704_06140_accr_1.0000_loss_0.000039_val_accr_1.0000_val_loss_0.004920.pt
# Accuracy: 100.00 % (5002 / 5002)
#
# Model: GB_00p_AB_2004250706_06960_accr_1.0000_loss_0.000029_val_accr_1.0000_val_loss_0.003213.pt
#
# Accuracy: 100.00 % (5002 / 5002)
#
# Model: GB_00p_AB_2004250706_07010_accr_1.0000_loss_0.000026_val_accr_1.0000_val_loss_0.003666.pt
#
# Accuracy: 100.00 % (5002 / 5002)
#
# Model: GB_00p_AB_2004250708_07600_accr_1.0000_loss_0.000016_val_accr_1.0000_val_loss_0.004711.pt
#
# Accuracy: 100.00 % (5002 / 5002)

# %%
GB_00p_AB_model = SSM_Model(GB_test_X, GB_test_Y, n_ch = 2, n_cls = 2, class_name = class_name, 
                            model_dir = model_dir, model_name = 'GB_00p_AB', batch_size = 20, GPU_idx = 3)

GB_00p_AB_model.Evaluation()
# Out:
# Model: GB_00p_AB_2004250141_02010_accr_0.9511_loss_0.140956_val_accr_0.9641_val_loss_0.121130.pt
#
# Accuracy: 94.04 % (1183 / 1258)
#
# Model: GB_00p_AB_2004250141_02380_accr_0.9784_loss_0.082123_val_accr_0.9701_val_loss_0.090582.pt
#
# Accuracy: 96.18 % (1210 / 1258)
#
# Model: GB_00p_AB_2004250141_02450_accr_0.9818_loss_0.057705_val_accr_0.9780_val_loss_0.073560.pt
#
# Accuracy: 96.42 % (1213 / 1258)
#
# Model: GB_00p_AB_2004250142_02940_accr_0.9871_loss_0.045665_val_accr_0.9780_val_loss_0.054926.pt
#
# Accuracy: 95.79 % (1205 / 1258)
#
# Model: GB_00p_AB_2004250143_03410_accr_0.9900_loss_0.028959_val_accr_0.9880_val_loss_0.046095.pt
#
# Accuracy: 96.34 % (1212 / 1258)
#
# Model: GB_00p_AB_2004250148_06720_accr_0.9978_loss_0.021777_val_accr_0.9880_val_loss_0.066300.pt
#
# Accuracy: 97.38 % (1225 / 1258)
#
# Model: GB_00p_AB_2004250149_07080_accr_0.9996_loss_0.004953_val_accr_0.9880_val_loss_0.050917.pt
#
# Accuracy: 97.38 % (1225 / 1258)
#
# Model: GB_00p_AB_2004250149_07090_accr_0.9976_loss_0.006449_val_accr_0.9880_val_loss_0.046520.pt
#
# Accuracy: 97.30 % (1224 / 1258)
#
# Model: GB_00p_AB_2004250149_07120_accr_0.9984_loss_0.006323_val_accr_0.9880_val_loss_0.042834.pt
#
# Accuracy: 97.38 % (1225 / 1258)
#
# Model: GB_00p_AB_2004250204_01070_accr_0.9516_loss_0.125702_val_accr_0.9461_val_loss_0.151110.pt
#
# Accuracy: 94.44 % (1188 / 1258)
#
# Model: GB_00p_AB_2004250205_01230_accr_0.9587_loss_0.100010_val_accr_0.9461_val_loss_0.147217.pt
#
# Accuracy: 95.55 % (1202 / 1258)
#
# Model: GB_00p_AB_2004250205_01300_accr_0.9560_loss_0.114029_val_accr_0.9461_val_loss_0.154751.pt
#
# Accuracy: 94.28 % (1186 / 1258)
#
# Model: GB_00p_AB_2004250205_01390_accr_0.9638_loss_0.088429_val_accr_0.9561_val_loss_0.132705.pt
#
# Accuracy: 96.03 % (1208 / 1258)
#
# Model: GB_00p_AB_2004250205_01720_accr_0.9629_loss_0.116879_val_accr_0.9601_val_loss_0.189218.pt
#
# Accuracy: 95.79 % (1205 / 1258)
#
# Model: GB_00p_AB_2004250205_01850_accr_0.9693_loss_0.082610_val_accr_0.9621_val_loss_0.160545.pt
#
# Accuracy: 95.87 % (1206 / 1258)
#
# Model: GB_00p_AB_2004250206_01900_accr_0.9898_loss_0.030041_val_accr_0.9721_val_loss_0.081170.pt
#
# Accuracy: 98.09 % (1234 / 1258)
#
# Model: GB_00p_AB_2004250206_02000_accr_0.9893_loss_0.034395_val_accr_0.9721_val_loss_0.072475.pt
#
# Accuracy: 97.46 % (1226 / 1258)
#
# Model: GB_00p_AB_2004250206_02360_accr_0.9953_loss_0.018491_val_accr_0.9760_val_loss_0.056012.pt
#
# Accuracy: 97.85 % (1231 / 1258)
#
# Model: GB_00p_AB_2004250207_02720_accr_0.9958_loss_0.012976_val_accr_0.9760_val_loss_0.061763.pt
#
# Accuracy: 97.93 % (1232 / 1258)
#
# Model: GB_00p_AB_2004250208_03550_accr_0.9953_loss_0.012847_val_accr_0.9780_val_loss_0.069875.pt
#
# Accuracy: 97.93 % (1232 / 1258)
#
# Model: GB_00p_AB_2004250209_03780_accr_0.9882_loss_0.030318_val_accr_0.9800_val_loss_0.081409.pt
#
# Accuracy: 97.38 % (1225 / 1258)
#
# Model: GB_00p_AB_2004250210_04450_accr_0.9982_loss_0.004493_val_accr_0.9820_val_loss_0.064509.pt
#
# Accuracy: 98.33 % (1237 / 1258)
#
# Model: GB_00p_AB_2004250211_05260_accr_0.9944_loss_0.016659_val_accr_0.9820_val_loss_0.077775.pt
#
# Accuracy: 97.93 % (1232 / 1258)
#
# Model: GB_00p_AB_2004250649_00750_accr_0.9656_loss_0.096823_val_accr_0.9701_val_loss_0.093136.pt
#
# Accuracy: 95.87 % (1206 / 1258)
#
# Model: GB_00p_AB_2004250649_00840_accr_0.9871_loss_0.031199_val_accr_0.9880_val_loss_0.040621.pt
#
# Accuracy: 97.77 % (1230 / 1258)
#
# Model: GB_00p_AB_2004250650_01290_accr_0.9844_loss_0.042875_val_accr_0.9900_val_loss_0.050185.pt
#
# Accuracy: 97.14 % (1222 / 1258)
#
# Model: GB_00p_AB_2004250651_01330_accr_0.9960_loss_0.010401_val_accr_0.9900_val_loss_0.022835.pt
#
# Accuracy: 98.41 % (1238 / 1258)
#
# Model: GB_00p_AB_2004250651_01420_accr_0.9993_loss_0.002721_val_accr_0.9920_val_loss_0.034211.pt
#
# Accuracy: 98.89 % (1244 / 1258)
#
# Model: GB_00p_AB_2004250651_01680_accr_0.9991_loss_0.002975_val_accr_0.9940_val_loss_0.015362.pt
#
# Accuracy: 99.05 % (1246 / 1258)
#
# Model: GB_00p_AB_2004250654_02430_accr_1.0000_loss_0.000186_val_accr_0.9960_val_loss_0.013816.pt
#
# Accuracy: 98.89 % (1244 / 1258)
#
# Model: GB_00p_AB_2004250654_02440_accr_1.0000_loss_0.000074_val_accr_0.9960_val_loss_0.019561.pt
#
# Accuracy: 98.89 % (1244 / 1258)
#
# Model: GB_00p_AB_2004250654_02450_accr_1.0000_loss_0.000067_val_accr_0.9960_val_loss_0.020190.pt
#
# Accuracy: 98.89 % (1244 / 1258)
#
# Model: GB_00p_AB_2004250654_02460_accr_1.0000_loss_0.000041_val_accr_0.9960_val_loss_0.015573.pt
#
# Accuracy: 99.05 % (1246 / 1258)
#
# Model: GB_00p_AB_2004250654_02530_accr_1.0000_loss_0.000322_val_accr_0.9960_val_loss_0.010226.pt
#
# Accuracy: 98.73 % (1242 / 1258)
#
# Model: GB_00p_AB_2004250654_02540_accr_0.9987_loss_0.004764_val_accr_0.9960_val_loss_0.015342.pt
#
# Accuracy: 97.93 % (1232 / 1258)
#
# Model: GB_00p_AB_2004250654_02560_accr_1.0000_loss_0.000153_val_accr_1.0000_val_loss_0.002307.pt
#
# Accuracy: 98.81 % (1243 / 1258)
#
# Model: GB_00p_AB_2004250654_02700_accr_1.0000_loss_0.000499_val_accr_1.0000_val_loss_0.001855.pt
#
# Accuracy: 98.73 % (1242 / 1258)
#
# Model: GB_00p_AB_2004250654_02740_accr_1.0000_loss_0.000032_val_accr_1.0000_val_loss_0.001346.pt
#
# Accuracy: 99.05 % (1246 / 1258)
#
# Model: GB_00p_AB_2004250654_02750_accr_1.0000_loss_0.000060_val_accr_1.0000_val_loss_0.000837.pt
#
# Accuracy: 98.89 % (1244 / 1258)
#
# Model: GB_00p_AB_2004250655_02860_accr_1.0000_loss_0.000155_val_accr_1.0000_val_loss_0.001658.pt
#
# Accuracy: 98.73 % (1242 / 1258)
#
# Model: GB_00p_AB_2004250655_02870_accr_1.0000_loss_0.000201_val_accr_1.0000_val_loss_0.001829.pt
#
# Accuracy: 98.73 % (1242 / 1258)
#
# Model: GB_00p_AB_2004250655_02880_accr_1.0000_loss_0.000023_val_accr_1.0000_val_loss_0.001852.pt
#
# Accuracy: 99.05 % (1246 / 1258)
#
# Model: GB_00p_AB_2004250655_02890_accr_1.0000_loss_0.000108_val_accr_1.0000_val_loss_0.001029.pt
#
# Accuracy: 98.81 % (1243 / 1258)
#
# Model: GB_00p_AB_2004250655_02900_accr_1.0000_loss_0.000025_val_accr_1.0000_val_loss_0.001229.pt
#
# Accuracy: 99.05 % (1246 / 1258)
#
# Model: GB_00p_AB_2004250655_02910_accr_1.0000_loss_0.000019_val_accr_1.0000_val_loss_0.001320.pt
#
# Accuracy: 99.05 % (1246 / 1258)
#
# Model: GB_00p_AB_2004250655_02970_accr_1.0000_loss_0.000213_val_accr_1.0000_val_loss_0.002044.pt
#
# Accuracy: 98.73 % (1242 / 1258)
#
# Model: GB_00p_AB_2004250655_02990_accr_1.0000_loss_0.000046_val_accr_1.0000_val_loss_0.000837.pt
#
# Accuracy: 98.89 % (1244 / 1258)
#
# Model: GB_00p_AB_2004250655_03000_accr_1.0000_loss_0.000012_val_accr_1.0000_val_loss_0.001440.pt
#
# Accuracy: 99.13 % (1247 / 1258)
#
# Model: GB_00p_AB_2004250655_03040_accr_1.0000_loss_0.000027_val_accr_1.0000_val_loss_0.001047.pt
#
# Accuracy: 98.97 % (1245 / 1258)
#
# Model: GB_00p_AB_2004250655_03080_accr_1.0000_loss_0.000074_val_accr_1.0000_val_loss_0.001114.pt
#
# Accuracy: 98.81 % (1243 / 1258)
#
# Model: GB_00p_AB_2004250656_03170_accr_1.0000_loss_0.000021_val_accr_1.0000_val_loss_0.000548.pt
#
# Accuracy: 99.05 % (1246 / 1258)
#
# Model: GB_00p_AB_2004250656_03180_accr_1.0000_loss_0.000072_val_accr_1.0000_val_loss_0.001302.pt
#
# Accuracy: 98.73 % (1242 / 1258)
#
# Model: GB_00p_AB_2004250656_03250_accr_1.0000_loss_0.000091_val_accr_1.0000_val_loss_0.002081.pt
#
# Accuracy: 98.73 % (1242 / 1258)
#
# Model: GB_00p_AB_2004250656_03260_accr_1.0000_loss_0.000011_val_accr_1.0000_val_loss_0.000799.pt
#
# Accuracy: 99.13 % (1247 / 1258)
#
# Model: GB_00p_AB_2004250656_03270_accr_1.0000_loss_0.000006_val_accr_1.0000_val_loss_0.001104.pt
#
# Accuracy: 99.05 % (1246 / 1258)
#
# Model: GB_00p_AB_2004250656_03300_accr_1.0000_loss_0.000112_val_accr_1.0000_val_loss_0.002654.pt
#
# Accuracy: 98.81 % (1243 / 1258)
#
# Model: GB_00p_AB_2004250657_03640_accr_1.0000_loss_0.000011_val_accr_1.0000_val_loss_0.002620.pt
#
# Accuracy: 98.89 % (1244 / 1258)
#
# Model: GB_00p_AB_2004250657_03780_accr_1.0000_loss_0.000021_val_accr_1.0000_val_loss_0.001765.pt
#
# Accuracy: 98.89 % (1244 / 1258)
#
# Model: GB_00p_AB_2004250657_03860_accr_1.0000_loss_0.000047_val_accr_1.0000_val_loss_0.003560.pt
#
# Accuracy: 98.97 % (1245 / 1258)
#
# Model: GB_00p_AB_2004250658_03870_accr_1.0000_loss_0.000005_val_accr_1.0000_val_loss_0.001843.pt
#
# Accuracy: 98.97 % (1245 / 1258)
#
# Model: GB_00p_AB_2004250659_04280_accr_1.0000_loss_0.000093_val_accr_1.0000_val_loss_0.004626.pt
#
# Accuracy: 98.73 % (1242 / 1258)
#
# Model: GB_00p_AB_2004250703_05720_accr_1.0000_loss_0.000052_val_accr_1.0000_val_loss_0.004998.pt
#
# Accuracy: 98.81 % (1243 / 1258)
#
# Model: GB_00p_AB_2004250704_06140_accr_1.0000_loss_0.000039_val_accr_1.0000_val_loss_0.004920.pt
# Accuracy: 98.89 % (1244 / 1258)
#
# Model: GB_00p_AB_2004250706_06960_accr_1.0000_loss_0.000029_val_accr_1.0000_val_loss_0.003213.pt
#
# Accuracy: 98.89 % (1244 / 1258)
#
# Model: GB_00p_AB_2004250706_07010_accr_1.0000_loss_0.000026_val_accr_1.0000_val_loss_0.003666.pt
#
# Accuracy: 98.89 % (1244 / 1258)
#
# Model: GB_00p_AB_2004250708_07600_accr_1.0000_loss_0.000016_val_accr_1.0000_val_loss_0.004711.pt
#
# Accuracy: 98.81 % (1243 / 1258)
#
# Model: GB_00p_AB_2004250812_00530_accr_0.9573_loss_0.132063_val_accr_0.9261_val_loss_0.200258.pt
#
# Accuracy: 93.56 % (1177 / 1258)
#
# Model: GB_00p_AB_2004250812_00540_accr_0.9556_loss_0.139222_val_accr_0.9261_val_loss_0.223702.pt
#
# Accuracy: 93.64 % (1178 / 1258)
#
# Model: GB_00p_AB_2004250812_00560_accr_0.9518_loss_0.133443_val_accr_0.9301_val_loss_0.203058.pt
#
# Accuracy: 94.12 % (1184 / 1258)
#
# Model: GB_00p_AB_2004250813_00680_accr_0.9573_loss_0.116248_val_accr_0.9301_val_loss_0.187914.pt
#
# Accuracy: 93.96 % (1182 / 1258)
#
# Model: GB_00p_AB_2004250813_00800_accr_0.9558_loss_0.117933_val_accr_0.9301_val_loss_0.203079.pt
#
# Accuracy: 93.80 % (1180 / 1258)
#
# Model: GB_00p_AB_2004250813_00810_accr_0.9647_loss_0.095780_val_accr_0.9341_val_loss_0.187608.pt
#
# Accuracy: 94.67 % (1191 / 1258)
#
# Model: GB_00p_AB_2004250813_00910_accr_0.9671_loss_0.080066_val_accr_0.9361_val_loss_0.143358.pt
#
# Accuracy: 95.07 % (1196 / 1258)
#
# Model: GB_00p_AB_2004250813_00960_accr_0.9793_loss_0.065622_val_accr_0.9441_val_loss_0.159757.pt
#
# Accuracy: 94.99 % (1195 / 1258)
#
# Model: GB_00p_AB_2004250813_00990_accr_0.9807_loss_0.059754_val_accr_0.9481_val_loss_0.135376.pt
#
# Accuracy: 95.31 % (1199 / 1258)
#
# Model: GB_00p_AB_2004250813_01010_accr_0.9858_loss_0.043496_val_accr_0.9621_val_loss_0.100504.pt
#
# Accuracy: 95.71 % (1204 / 1258)
#
# Model: GB_00p_AB_2004250813_01020_accr_0.9876_loss_0.049246_val_accr_0.9621_val_loss_0.102335.pt
#
# Accuracy: 95.07 % (1196 / 1258)
#
# Model: GB_00p_AB_2004250814_01150_accr_0.9838_loss_0.046865_val_accr_0.9641_val_loss_0.101100.pt
#
# Accuracy: 95.87 % (1206 / 1258)
#
# Model: GB_00p_AB_2004250814_01310_accr_0.9949_loss_0.020546_val_accr_0.9661_val_loss_0.091904.pt
#
# Accuracy: 95.63 % (1203 / 1258)
#
# Model: GB_00p_AB_2004250814_01360_accr_0.9991_loss_0.005003_val_accr_0.9701_val_loss_0.107501.pt
#
# Accuracy: 96.50 % (1214 / 1258)
#
# Model: GB_00p_AB_2004250815_01490_accr_0.9976_loss_0.009875_val_accr_0.9701_val_loss_0.086152.pt
#
# Accuracy: 96.50 % (1214 / 1258)
#
# Model: GB_00p_AB_2004250815_01540_accr_0.9987_loss_0.006748_val_accr_0.9721_val_loss_0.094518.pt
#
# Accuracy: 95.95 % (1207 / 1258)
#
# Model: GB_00p_AB_2004250815_01660_accr_0.9998_loss_0.001552_val_accr_0.9741_val_loss_0.095637.pt
#
# Accuracy: 96.98 % (1220 / 1258)
#
# Model: GB_00p_AB_2004250816_01760_accr_0.9989_loss_0.004191_val_accr_0.9760_val_loss_0.114088.pt
#
# Accuracy: 96.18 % (1210 / 1258)
#
# Model: GB_00p_AB_2004250816_02050_accr_0.9991_loss_0.003183_val_accr_0.9780_val_loss_0.092109.pt
#
# Accuracy: 96.66 % (1216 / 1258)
#
# Model: GB_00p_AB_2004250817_02330_accr_1.0000_loss_0.001430_val_accr_0.9780_val_loss_0.101605.pt
#
# Accuracy: 96.50 % (1214 / 1258)
#
# Model: GB_00p_AB_2004250819_02920_accr_0.9998_loss_0.003057_val_accr_0.9800_val_loss_0.113239.pt
#
# Accuracy: 96.50 % (1214 / 1258)
#
# Model: GB_00p_AB_2004250821_03730_accr_0.9998_loss_0.000579_val_accr_0.9820_val_loss_0.079740.pt
#
# Accuracy: 97.46 % (1226 / 1258)
#
# Model: GB_00p_AB_2004250821_03880_accr_1.0000_loss_0.000050_val_accr_0.9820_val_loss_0.099899.pt
#
# Accuracy: 97.46 % (1226 / 1258)
#
# Model: GB_00p_AB_2004250821_03920_accr_1.0000_loss_0.000153_val_accr_0.9840_val_loss_0.085519.pt
#
# Accuracy: 97.54 % (1227 / 1258)
#
# Model: GB_00p_AB_2004250823_04670_accr_1.0000_loss_0.000035_val_accr_0.9840_val_loss_0.100301.pt
#
# Accuracy: 97.46 % (1226 / 1258)
#
# Model: GB_00p_AB_2004250823_04680_accr_1.0000_loss_0.000075_val_accr_0.9840_val_loss_0.097351.pt
#
# Accuracy: 97.54 % (1227 / 1258)
#
# Model: GB_00p_AB_2004250825_05290_accr_0.9984_loss_0.003188_val_accr_0.9860_val_loss_0.077490.pt
#
# Accuracy: 97.06 % (1221 / 1258)
#
# Model: GB_00p_AB_2004250826_05770_accr_1.0000_loss_0.000166_val_accr_0.9860_val_loss_0.073962.pt
#
# Accuracy: 97.69 % (1229 / 1258)
#
# Model: GB_00p_AB_2004250826_05780_accr_1.0000_loss_0.000054_val_accr_0.9860_val_loss_0.076399.pt
#
# Accuracy: 97.69 % (1229 / 1258)
#
# Model: GB_00p_AB_2004250827_06120_accr_1.0000_loss_0.000045_val_accr_0.9860_val_loss_0.078892.pt
#
# Accuracy: 97.62 % (1228 / 1258)
#
# Model: GB_00p_AB_2004250827_06230_accr_1.0000_loss_0.000017_val_accr_0.9860_val_loss_0.085177.pt
#
# Accuracy: 97.69 % (1229 / 1258)
#
# Model: GB_00p_AB_2004250828_06380_accr_1.0000_loss_0.000074_val_accr_0.9860_val_loss_0.094861.pt
#
# Accuracy: 97.54 % (1227 / 1258)
#
# Model: GB_00p_AB_2004250828_06390_accr_1.0000_loss_0.000015_val_accr_0.9860_val_loss_0.089090.pt
#
# Accuracy: 97.62 % (1228 / 1258)
#
# Model: GB_00p_AB_2004250828_06430_accr_1.0000_loss_0.000009_val_accr_0.9860_val_loss_0.087741.pt
#
# Accuracy: 97.69 % (1229 / 1258)
#
# Model: GB_00p_AB_2004250828_06480_accr_1.0000_loss_0.000016_val_accr_0.9860_val_loss_0.085548.pt
#
# Accuracy: 97.54 % (1227 / 1258)
#
# Model: GB_00p_AB_2004250829_06980_accr_1.0000_loss_0.000621_val_accr_0.9880_val_loss_0.065939.pt
#
# Accuracy: 98.01 % (1233 / 1258)
#
# Model: GB_00p_AB_2004250829_07040_accr_0.9998_loss_0.000505_val_accr_0.9880_val_loss_0.059582.pt
#
# Accuracy: 97.85 % (1231 / 1258)
#
# Model: GB_00p_AB_2004250831_07430_accr_1.0000_loss_0.000579_val_accr_0.9880_val_loss_0.044502.pt
#
# Accuracy: 97.38 % (1225 / 1258)
#
# Model: GB_00p_AB_2004250843_11910_accr_1.0000_loss_0.000071_val_accr_0.9880_val_loss_0.076396.pt
#
# Accuracy: 98.25 % (1236 / 1258)

# %%
GB_00p_AB_model = SSM_Model(GB_test_X, GB_test_Y, n_ch = 2, n_cls = 2, class_name = class_name, 
                            model_dir = model_dir, model_name = 'GB_00p_AB', batch_size = 200, GPU_idx = 3)

GB_00p_AB_model.Evaluation()
GB_00p_AB_model.ConfusionMatrix(CM_save_dir, x_angle = 0)
# Out:
# Model: GB_00p_AB_2004250656_03170_accr_1.0000_loss_0.000021_val_accr_1.0000_val_loss_0.000548.pt
#
# Accuracy: 99.05 % (1246 / 1258)

# %%
GB_00p_A_model = SSM_Model(np.expand_dims(GB_train_X[:,0,:,:], axis = 1), GB_train_Y, n_ch = 1, n_cls = 2, 
                           class_name = class_name, model_dir = model_dir, model_name = 'GB_00p_A', batch_size = 20, GPU_idx = 3)

GB_00p_A_model.Evaluation()
# Out:
# Model: GB_00p_A_2004250142_01880_accr_0.9529_loss_0.132626_val_accr_0.9561_val_loss_0.142558.pt
#
# Accuracy: 95.32 % (4768 / 5002)
#
# Model: GB_00p_A_2004250143_02400_accr_0.9538_loss_0.119253_val_accr_0.9601_val_loss_0.123260.pt
#
# Accuracy: 95.44 % (4774 / 5002)
#
# Model: GB_00p_A_2004250143_02580_accr_0.9545_loss_0.116171_val_accr_0.9601_val_loss_0.125371.pt
#
# Accuracy: 95.50 % (4777 / 5002)
#
# Model: GB_00p_A_2004250148_05340_accr_0.9876_loss_0.031918_val_accr_0.9601_val_loss_0.193150.pt
#
# Accuracy: 98.48 % (4926 / 5002)
#
# Model: GB_00p_A_2004250149_06090_accr_0.9904_loss_0.024676_val_accr_0.9601_val_loss_0.210764.pt
#
# Accuracy: 98.74 % (4939 / 5002)
#
# Model: GB_00p_A_2004250149_06140_accr_0.9793_loss_0.048769_val_accr_0.9601_val_loss_0.247013.pt
#
# Accuracy: 97.74 % (4889 / 5002)
#
# Model: GB_00p_A_2004250151_07630_accr_0.9882_loss_0.029701_val_accr_0.9621_val_loss_0.209955.pt
#
# Accuracy: 98.56 % (4930 / 5002)
#
# Model: GB_00p_A_2004250206_02130_accr_0.9518_loss_0.126339_val_accr_0.9321_val_loss_0.154381.pt
#
# Accuracy: 94.98 % (4751 / 5002)
#
# Model: GB_00p_A_2004250207_02680_accr_0.9505_loss_0.111276_val_accr_0.9481_val_loss_0.162378.pt
#
# Accuracy: 95.02 % (4753 / 5002)
#
# Model: GB_00p_A_2004250209_03850_accr_0.9569_loss_0.143443_val_accr_0.9501_val_loss_0.223822.pt
#
# Accuracy: 95.62 % (4783 / 5002)
#
# Model: GB_00p_A_2004250209_03990_accr_0.9873_loss_0.034841_val_accr_0.9601_val_loss_0.170100.pt
#
# Accuracy: 98.46 % (4925 / 5002)
#
# Model: GB_00p_A_2004250211_04960_accr_0.9916_loss_0.022470_val_accr_0.9701_val_loss_0.167857.pt
#
# Accuracy: 98.94 % (4949 / 5002)
#
# Model: GB_00p_A_2004250213_06420_accr_0.9873_loss_0.037098_val_accr_0.9721_val_loss_0.143728.pt
#
# Accuracy: 98.58 % (4931 / 5002)
#
# Model: GB_00p_A_2004250214_06880_accr_0.9949_loss_0.015127_val_accr_0.9780_val_loss_0.205940.pt
#
# Accuracy: 99.32 % (4968 / 5002)
#
# Model: GB_00p_A_2004250401_04310_accr_0.9513_loss_0.151082_val_accr_0.9341_val_loss_0.194980.pt
#
# Accuracy: 94.96 % (4750 / 5002)
#
# Model: GB_00p_A_2004250401_04340_accr_0.9485_loss_0.152395_val_accr_0.9341_val_loss_0.196257.pt
#
# Accuracy: 94.70 % (4737 / 5002)
#
# Model: GB_00p_A_2004250401_04350_accr_0.9529_loss_0.144267_val_accr_0.9341_val_loss_0.191065.pt
#
# Accuracy: 95.10 % (4757 / 5002)
#
# Model: GB_00p_A_2004250401_04440_accr_0.9500_loss_0.149969_val_accr_0.9341_val_loss_0.195383.pt
#
# Accuracy: 94.84 % (4744 / 5002)
#
# Model: GB_00p_A_2004250401_04480_accr_0.9485_loss_0.156706_val_accr_0.9361_val_loss_0.193085.pt
#
# Accuracy: 94.72 % (4738 / 5002)
#
# Model: GB_00p_A_2004250401_04490_accr_0.9542_loss_0.142365_val_accr_0.9381_val_loss_0.189268.pt
#
# Accuracy: 95.26 % (4765 / 5002)
#
# Model: GB_00p_A_2004250401_04630_accr_0.9545_loss_0.140613_val_accr_0.9401_val_loss_0.189072.pt
#
# Accuracy: 95.30 % (4767 / 5002)
#
# Model: GB_00p_A_2004250402_05060_accr_0.9558_loss_0.135333_val_accr_0.9441_val_loss_0.192220.pt
#
# Accuracy: 95.46 % (4775 / 5002)
#
# Model: GB_00p_A_2004250403_05820_accr_0.9567_loss_0.127737_val_accr_0.9441_val_loss_0.186482.pt
#
# Accuracy: 95.54 % (4779 / 5002)
#
# Model: GB_00p_A_2004250405_07050_accr_0.9582_loss_0.116471_val_accr_0.9441_val_loss_0.189491.pt
#
# Accuracy: 95.68 % (4786 / 5002)
#
# Model: GB_00p_A_2004250648_01030_accr_0.9540_loss_0.164352_val_accr_0.9461_val_loss_0.232695.pt
#
# Accuracy: 95.32 % (4768 / 5002)
#
# Model: GB_00p_A_2004250649_01140_accr_0.9636_loss_0.099054_val_accr_0.9581_val_loss_0.162330.pt
#
# Accuracy: 96.30 % (4817 / 5002)
#
# Model: GB_00p_A_2004250649_01250_accr_0.9809_loss_0.053218_val_accr_0.9681_val_loss_0.116661.pt
#
# Accuracy: 97.96 % (4900 / 5002)
#
# Model: GB_00p_A_2004250650_01510_accr_0.9916_loss_0.022023_val_accr_0.9681_val_loss_0.142716.pt
#
# Accuracy: 98.92 % (4948 / 5002)
#
# Model: GB_00p_A_2004250650_01530_accr_0.9942_loss_0.017568_val_accr_0.9701_val_loss_0.143242.pt
#
# Accuracy: 99.18 % (4961 / 5002)
#
# Model: GB_00p_A_2004250650_01620_accr_0.9709_loss_0.079704_val_accr_0.9701_val_loss_0.140991.pt
#
# Accuracy: 97.08 % (4856 / 5002)
#
# Model: GB_00p_A_2004250651_01920_accr_0.9909_loss_0.021385_val_accr_0.9721_val_loss_0.193206.pt
#
# Accuracy: 98.90 % (4947 / 5002)
#
# Model: GB_00p_A_2004250651_01930_accr_0.9962_loss_0.010229_val_accr_0.9741_val_loss_0.180379.pt
#
# Accuracy: 99.40 % (4972 / 5002)
#
# Model: GB_00p_A_2004250651_01990_accr_0.9938_loss_0.017217_val_accr_0.9741_val_loss_0.125704.pt
#
# Accuracy: 99.18 % (4961 / 5002)
#
# Model: GB_00p_A_2004250652_02460_accr_0.9996_loss_0.001273_val_accr_0.9741_val_loss_0.102992.pt
#
# Accuracy: 99.70 % (4987 / 5002)
#
# Model: GB_00p_A_2004250652_02480_accr_1.0000_loss_0.000508_val_accr_0.9760_val_loss_0.114774.pt
#
# Accuracy: 99.76 % (4990 / 5002)
#
# Model: GB_00p_A_2004250652_02500_accr_1.0000_loss_0.000467_val_accr_0.9780_val_loss_0.104977.pt
#
# Accuracy: 99.78 % (4991 / 5002)
#
# Model: GB_00p_A_2004250653_02680_accr_1.0000_loss_0.000187_val_accr_0.9780_val_loss_0.152583.pt
#
# Accuracy: 99.78 % (4991 / 5002)
#
# Model: GB_00p_A_2004250653_02690_accr_1.0000_loss_0.000068_val_accr_0.9780_val_loss_0.153212.pt
#
# Accuracy: 99.78 % (4991 / 5002)
#
# Model: GB_00p_A_2004250653_02820_accr_1.0000_loss_0.000095_val_accr_0.9780_val_loss_0.158331.pt
#
# Accuracy: 99.78 % (4991 / 5002)
#
# Model: GB_00p_A_2004250655_03310_accr_0.9998_loss_0.000864_val_accr_0.9780_val_loss_0.181167.pt
#
# Accuracy: 99.76 % (4990 / 5002)
#
# Model: GB_00p_A_2004250655_03320_accr_0.9998_loss_0.001093_val_accr_0.9780_val_loss_0.185344.pt
#
# Accuracy: 99.76 % (4990 / 5002)
#
# Model: GB_00p_A_2004250655_03510_accr_1.0000_loss_0.000369_val_accr_0.9780_val_loss_0.174860.pt
#
# Accuracy: 99.78 % (4991 / 5002)
#
# Model: GB_00p_A_2004250655_03560_accr_1.0000_loss_0.000075_val_accr_0.9780_val_loss_0.158759.pt
#
# Accuracy: 99.78 % (4991 / 5002)
#
# Model: GB_00p_A_2004250655_03580_accr_1.0000_loss_0.000239_val_accr_0.9800_val_loss_0.171506.pt
#
# Accuracy: 99.80 % (4992 / 5002)
#
# Model: GB_00p_A_2004250713_10160_accr_1.0000_loss_0.000162_val_accr_0.9800_val_loss_0.259390.pt
#
# Accuracy: 99.80 % (4992 / 5002)
#
# Model: GB_00p_A_2004250715_10670_accr_1.0000_loss_0.000055_val_accr_0.9800_val_loss_0.257013.pt
#
# Accuracy: 99.80 % (4992 / 5002)
#
# Model: GB_00p_A_2004250715_10890_accr_1.0000_loss_0.000038_val_accr_0.9800_val_loss_0.265691.pt
#
# Accuracy: 99.80 % (4992 / 5002)
#
# Model: GB_00p_A_2004250719_12160_accr_1.0000_loss_0.000215_val_accr_0.9800_val_loss_0.281035.pt
#
# Accuracy: 99.80 % (4992 / 5002)
#
# Model: GB_00p_A_2004250720_12690_accr_1.0000_loss_0.000049_val_accr_0.9800_val_loss_0.280994.pt
#
# Accuracy: 99.80 % (4992 / 5002)
#
# Model: GB_00p_A_2004250722_13240_accr_1.0000_loss_0.000328_val_accr_0.9800_val_loss_0.298190.pt
#
# Accuracy: 99.80 % (4992 / 5002)
#
# Model: GB_00p_A_2004250723_13770_accr_1.0000_loss_0.000009_val_accr_0.9800_val_loss_0.296451.pt
#
# Accuracy: 99.80 % (4992 / 5002)
#
# Model: GB_00p_A_2004250725_14370_accr_1.0000_loss_0.000116_val_accr_0.9800_val_loss_0.315487.pt
#
# Accuracy: 99.80 % (4992 / 5002)
#
# Model: GB_00p_A_2004250726_14830_accr_1.0000_loss_0.000064_val_accr_0.9800_val_loss_0.318714.pt
#
# Accuracy: 99.80 % (4992 / 5002)

# %%
GB_00p_A_model = SSM_Model(np.expand_dims(GB_test_X[:,0,:,:], axis = 1), GB_test_Y, n_ch = 1, n_cls = 2, 
                           class_name = class_name, model_dir = model_dir, model_name = 'GB_00p_A', batch_size = 20, GPU_idx = 3)

GB_00p_A_model.Evaluation()
# Out:
# Model: GB_00p_A_2004250142_01880_accr_0.9529_loss_0.132626_val_accr_0.9561_val_loss_0.142558.pt
#
# Accuracy: 93.72 % (1179 / 1258)
#
# Model: GB_00p_A_2004250143_02400_accr_0.9538_loss_0.119253_val_accr_0.9601_val_loss_0.123260.pt
#
# Accuracy: 93.72 % (1179 / 1258)
#
# Model: GB_00p_A_2004250143_02580_accr_0.9545_loss_0.116171_val_accr_0.9601_val_loss_0.125371.pt
#
# Accuracy: 93.48 % (1176 / 1258)
#
# Model: GB_00p_A_2004250148_05340_accr_0.9876_loss_0.031918_val_accr_0.9601_val_loss_0.193150.pt
#
# Accuracy: 94.67 % (1191 / 1258)
#
# Model: GB_00p_A_2004250149_06090_accr_0.9904_loss_0.024676_val_accr_0.9601_val_loss_0.210764.pt
#
# Accuracy: 94.36 % (1187 / 1258)
#
# Model: GB_00p_A_2004250149_06140_accr_0.9793_loss_0.048769_val_accr_0.9601_val_loss_0.247013.pt
#
# Accuracy: 94.44 % (1188 / 1258)
#
# Model: GB_00p_A_2004250151_07630_accr_0.9882_loss_0.029701_val_accr_0.9621_val_loss_0.209955.pt
#
# Accuracy: 94.44 % (1188 / 1258)
#
# Model: GB_00p_A_2004250206_02130_accr_0.9518_loss_0.126339_val_accr_0.9321_val_loss_0.154381.pt
#
# Accuracy: 94.28 % (1186 / 1258)
#
# Model: GB_00p_A_2004250207_02680_accr_0.9505_loss_0.111276_val_accr_0.9481_val_loss_0.162378.pt
#
# Accuracy: 93.72 % (1179 / 1258)
#
# Model: GB_00p_A_2004250209_03850_accr_0.9569_loss_0.143443_val_accr_0.9501_val_loss_0.223822.pt
#
# Accuracy: 94.20 % (1185 / 1258)
#
# Model: GB_00p_A_2004250209_03990_accr_0.9873_loss_0.034841_val_accr_0.9601_val_loss_0.170100.pt
#
# Accuracy: 95.95 % (1207 / 1258)
#
# Model: GB_00p_A_2004250211_04960_accr_0.9916_loss_0.022470_val_accr_0.9701_val_loss_0.167857.pt
#
# Accuracy: 96.82 % (1218 / 1258)
#
# Model: GB_00p_A_2004250213_06420_accr_0.9873_loss_0.037098_val_accr_0.9721_val_loss_0.143728.pt
#
# Accuracy: 95.47 % (1201 / 1258)
#
# Model: GB_00p_A_2004250214_06880_accr_0.9949_loss_0.015127_val_accr_0.9780_val_loss_0.205940.pt
#
# Accuracy: 96.50 % (1214 / 1258)
#
# Model: GB_00p_A_2004250401_04310_accr_0.9513_loss_0.151082_val_accr_0.9341_val_loss_0.194980.pt
#
# Accuracy: 93.00 % (1170 / 1258)
#
# Model: GB_00p_A_2004250401_04340_accr_0.9485_loss_0.152395_val_accr_0.9341_val_loss_0.196257.pt
#
# Accuracy: 92.61 % (1165 / 1258)
#
# Model: GB_00p_A_2004250401_04350_accr_0.9529_loss_0.144267_val_accr_0.9341_val_loss_0.191065.pt
#
# Accuracy: 93.08 % (1171 / 1258)
#
# Model: GB_00p_A_2004250401_04440_accr_0.9500_loss_0.149969_val_accr_0.9341_val_loss_0.195383.pt
#
# Accuracy: 92.85 % (1168 / 1258)
#
# Model: GB_00p_A_2004250401_04480_accr_0.9485_loss_0.156706_val_accr_0.9361_val_loss_0.193085.pt
#
# Accuracy: 93.08 % (1171 / 1258)
#
# Model: GB_00p_A_2004250401_04490_accr_0.9542_loss_0.142365_val_accr_0.9381_val_loss_0.189268.pt
#
# Accuracy: 93.16 % (1172 / 1258)
#
# Model: GB_00p_A_2004250401_04630_accr_0.9545_loss_0.140613_val_accr_0.9401_val_loss_0.189072.pt
#
# Accuracy: 93.08 % (1171 / 1258)
#
# Model: GB_00p_A_2004250402_05060_accr_0.9558_loss_0.135333_val_accr_0.9441_val_loss_0.192220.pt
#
# Accuracy: 92.93 % (1169 / 1258)
#
# Model: GB_00p_A_2004250403_05820_accr_0.9567_loss_0.127737_val_accr_0.9441_val_loss_0.186482.pt
#
# Accuracy: 93.48 % (1176 / 1258)
#
# Model: GB_00p_A_2004250405_07050_accr_0.9582_loss_0.116471_val_accr_0.9441_val_loss_0.189491.pt
#
# Accuracy: 93.48 % (1176 / 1258)
#
# Model: GB_00p_A_2004250648_01030_accr_0.9540_loss_0.164352_val_accr_0.9461_val_loss_0.232695.pt
#
# Accuracy: 94.91 % (1194 / 1258)
#
# Model: GB_00p_A_2004250649_01140_accr_0.9636_loss_0.099054_val_accr_0.9581_val_loss_0.162330.pt
#
# Accuracy: 95.55 % (1202 / 1258)
#
# Model: GB_00p_A_2004250649_01250_accr_0.9809_loss_0.053218_val_accr_0.9681_val_loss_0.116661.pt
#
# Accuracy: 95.07 % (1196 / 1258)
#
# Model: GB_00p_A_2004250650_01510_accr_0.9916_loss_0.022023_val_accr_0.9681_val_loss_0.142716.pt
#
# Accuracy: 96.42 % (1213 / 1258)
#
# Model: GB_00p_A_2004250650_01530_accr_0.9942_loss_0.017568_val_accr_0.9701_val_loss_0.143242.pt
#
# Accuracy: 96.34 % (1212 / 1258)
#
# Model: GB_00p_A_2004250650_01620_accr_0.9709_loss_0.079704_val_accr_0.9701_val_loss_0.140991.pt
#
# Accuracy: 95.07 % (1196 / 1258)
#
# Model: GB_00p_A_2004250651_01920_accr_0.9909_loss_0.021385_val_accr_0.9721_val_loss_0.193206.pt
#
# Accuracy: 96.58 % (1215 / 1258)
#
# Model: GB_00p_A_2004250651_01930_accr_0.9962_loss_0.010229_val_accr_0.9741_val_loss_0.180379.pt
#
# Accuracy: 97.06 % (1221 / 1258)
#
# Model: GB_00p_A_2004250651_01990_accr_0.9938_loss_0.017217_val_accr_0.9741_val_loss_0.125704.pt
#
# Accuracy: 96.50 % (1214 / 1258)
#
# Model: GB_00p_A_2004250652_02460_accr_0.9996_loss_0.001273_val_accr_0.9741_val_loss_0.102992.pt
#
# Accuracy: 97.54 % (1227 / 1258)
#
# Model: GB_00p_A_2004250652_02480_accr_1.0000_loss_0.000508_val_accr_0.9760_val_loss_0.114774.pt
#
# Accuracy: 97.54 % (1227 / 1258)
#
# Model: GB_00p_A_2004250652_02500_accr_1.0000_loss_0.000467_val_accr_0.9780_val_loss_0.104977.pt
#
# Accuracy: 97.54 % (1227 / 1258)
#
# Model: GB_00p_A_2004250653_02680_accr_1.0000_loss_0.000187_val_accr_0.9780_val_loss_0.152583.pt
#
# Accuracy: 97.46 % (1226 / 1258)
#
# Model: GB_00p_A_2004250653_02690_accr_1.0000_loss_0.000068_val_accr_0.9780_val_loss_0.153212.pt
#
# Accuracy: 97.54 % (1227 / 1258)
#
# Model: GB_00p_A_2004250653_02820_accr_1.0000_loss_0.000095_val_accr_0.9780_val_loss_0.158331.pt
#
# Accuracy: 97.77 % (1230 / 1258)
#
# Model: GB_00p_A_2004250655_03310_accr_0.9998_loss_0.000864_val_accr_0.9780_val_loss_0.181167.pt
#
# Accuracy: 97.46 % (1226 / 1258)
#
# Model: GB_00p_A_2004250655_03320_accr_0.9998_loss_0.001093_val_accr_0.9780_val_loss_0.185344.pt
#
# Accuracy: 97.46 % (1226 / 1258)
#
# Model: GB_00p_A_2004250655_03510_accr_1.0000_loss_0.000369_val_accr_0.9780_val_loss_0.174860.pt
#
# Accuracy: 97.69 % (1229 / 1258)
#
# Model: GB_00p_A_2004250655_03560_accr_1.0000_loss_0.000075_val_accr_0.9780_val_loss_0.158759.pt
#
# Accuracy: 97.69 % (1229 / 1258)
#
# Model: GB_00p_A_2004250655_03580_accr_1.0000_loss_0.000239_val_accr_0.9800_val_loss_0.171506.pt
#
# Accuracy: 97.77 % (1230 / 1258)
#
# Model: GB_00p_A_2004250713_10160_accr_1.0000_loss_0.000162_val_accr_0.9800_val_loss_0.259390.pt
#
# Accuracy: 97.77 % (1230 / 1258)
#
# Model: GB_00p_A_2004250715_10670_accr_1.0000_loss_0.000055_val_accr_0.9800_val_loss_0.257013.pt
#
# Accuracy: 97.77 % (1230 / 1258)
#
# Model: GB_00p_A_2004250715_10890_accr_1.0000_loss_0.000038_val_accr_0.9800_val_loss_0.265691.pt
#
# Accuracy: 97.77 % (1230 / 1258)
#
# Model: GB_00p_A_2004250719_12160_accr_1.0000_loss_0.000215_val_accr_0.9800_val_loss_0.281035.pt
#
# Accuracy: 97.77 % (1230 / 1258)
#
# Model: GB_00p_A_2004250720_12690_accr_1.0000_loss_0.000049_val_accr_0.9800_val_loss_0.280994.pt
#
# Accuracy: 97.85 % (1231 / 1258)
#
# Model: GB_00p_A_2004250722_13240_accr_1.0000_loss_0.000328_val_accr_0.9800_val_loss_0.298190.pt
#
# Accuracy: 97.62 % (1228 / 1258)
#
# Model: GB_00p_A_2004250723_13770_accr_1.0000_loss_0.000009_val_accr_0.9800_val_loss_0.296451.pt
#
# Accuracy: 97.77 % (1230 / 1258)
#
# Model: GB_00p_A_2004250725_14370_accr_1.0000_loss_0.000116_val_accr_0.9800_val_loss_0.315487.pt
#
# Accuracy: 97.54 % (1227 / 1258)
#
# Model: GB_00p_A_2004250726_14830_accr_1.0000_loss_0.000064_val_accr_0.9800_val_loss_0.318714.pt
#
# Accuracy: 97.69 % (1229 / 1258)
#
# Model: GB_00p_A_2004250812_00630_accr_0.9425_loss_0.167995_val_accr_0.9421_val_loss_0.193200.pt
#
# Accuracy: 93.08 % (1171 / 1258)
#
# Model: GB_00p_A_2004250813_00920_accr_0.9560_loss_0.116459_val_accr_0.9421_val_loss_0.183954.pt
#
# Accuracy: 93.24 % (1173 / 1258)
#
# Model: GB_00p_A_2004250813_01100_accr_0.9653_loss_0.096771_val_accr_0.9481_val_loss_0.193303.pt
#
# Accuracy: 94.12 % (1184 / 1258)
#
# Model: GB_00p_A_2004250814_01350_accr_0.9809_loss_0.053426_val_accr_0.9501_val_loss_0.206344.pt
#
# Accuracy: 93.64 % (1178 / 1258)
#
# Model: GB_00p_A_2004250815_01630_accr_0.9893_loss_0.029148_val_accr_0.9521_val_loss_0.185541.pt
#
# Accuracy: 94.20 % (1185 / 1258)
#
# Model: GB_00p_A_2004250815_01720_accr_0.9856_loss_0.031851_val_accr_0.9521_val_loss_0.207454.pt
#
# Accuracy: 93.48 % (1176 / 1258)
#
# Model: GB_00p_A_2004250815_01770_accr_0.9880_loss_0.031882_val_accr_0.9561_val_loss_0.235179.pt
#
# Accuracy: 94.52 % (1189 / 1258)
#
# Model: GB_00p_A_2004250815_01780_accr_0.9922_loss_0.019220_val_accr_0.9601_val_loss_0.222231.pt
#
# Accuracy: 94.44 % (1188 / 1258)
#
# Model: GB_00p_A_2004250832_08200_accr_1.0000_loss_0.000100_val_accr_0.9601_val_loss_0.257186.pt
#
# Accuracy: 95.07 % (1196 / 1258)
#
# Model: GB_00p_A_2004250834_08620_accr_1.0000_loss_0.000107_val_accr_0.9601_val_loss_0.255750.pt
#
# Accuracy: 94.91 % (1194 / 1258)
#
# Model: GB_00p_A_2004250837_09720_accr_0.9989_loss_0.004497_val_accr_0.9621_val_loss_0.218619.pt
# Accuracy: 95.23 % (1198 / 1258)
#
# Model: GB_00p_A_2004250837_09760_accr_0.9969_loss_0.010156_val_accr_0.9661_val_loss_0.197210.pt
#
# Accuracy: 93.80 % (1180 / 1258)

# %%
GB_00p_A_model = SSM_Model(np.expand_dims(GB_test_X[:,0,:,:], axis = 1), GB_test_Y, n_ch = 1, n_cls = 2, 
                           class_name = class_name, model_dir = model_dir, model_name = 'GB_00p_A', batch_size = 200, GPU_idx = 3)

GB_00p_A_model.Evaluation()
GB_00p_A_model.ConfusionMatrix(CM_save_dir, x_angle = 0)
# Out:
# Model: GB_00p_A_2004250655_03580_accr_1.0000_loss_0.000239_val_accr_0.9800_val_loss_0.171506.pt
#
# Accuracy: 97.77 % (1230 / 1258)

# %%
GB_00p_B_model = SSM_Model(np.expand_dims(GB_train_X[:,1,:,:], axis = 1), GB_train_Y, n_ch = 1, n_cls = 2, 
                           class_name = class_name, model_dir = model_dir, model_name = 'GB_00p_B', batch_size = 20, GPU_idx = 3)

GB_00p_B_model.Evaluation()
# Out:
# Model: GB_00p_B_2004250142_00940_accr_0.9829_loss_0.046969_val_accr_0.9601_val_loss_0.104323.pt
#
# Accuracy: 98.06 % (4905 / 5002)
#
# Model: GB_00p_B_2004250142_00950_accr_0.9516_loss_0.136590_val_accr_0.9601_val_loss_0.167247.pt
#
# Accuracy: 95.24 % (4764 / 5002)
#
# Model: GB_00p_B_2004250142_01110_accr_0.9916_loss_0.028663_val_accr_0.9800_val_loss_0.059203.pt
#
# Accuracy: 99.04 % (4954 / 5002)
#
# Model: GB_00p_B_2004250146_03940_accr_0.9987_loss_0.005041_val_accr_0.9800_val_loss_0.049804.pt
#
# Accuracy: 99.68 % (4986 / 5002)
#
# Model: GB_00p_B_2004250147_04290_accr_0.9982_loss_0.008582_val_accr_0.9820_val_loss_0.067888.pt
#
# Accuracy: 99.66 % (4985 / 5002)
#
# Model: GB_00p_B_2004250148_04790_accr_0.9969_loss_0.008159_val_accr_0.9820_val_loss_0.053821.pt
#
# Accuracy: 99.54 % (4979 / 5002)
#
# Model: GB_00p_B_2004250148_05160_accr_0.9998_loss_0.000838_val_accr_0.9940_val_loss_0.020870.pt
#
# Accuracy: 99.92 % (4998 / 5002)
#
# Model: GB_00p_B_2004250148_05170_accr_1.0000_loss_0.000325_val_accr_0.9940_val_loss_0.018372.pt
#
# Accuracy: 99.94 % (4999 / 5002)
#
# Model: GB_00p_B_2004250148_05180_accr_1.0000_loss_0.000228_val_accr_0.9940_val_loss_0.017691.pt
#
# Accuracy: 99.94 % (4999 / 5002)
#
# Model: GB_00p_B_2004250148_05190_accr_1.0000_loss_0.000462_val_accr_0.9940_val_loss_0.020093.pt
#
# Accuracy: 99.94 % (4999 / 5002)
#
# Model: GB_00p_B_2004250148_05200_accr_1.0000_loss_0.000160_val_accr_0.9940_val_loss_0.016891.pt
#
# Accuracy: 99.94 % (4999 / 5002)
#
# Model: GB_00p_B_2004250149_05260_accr_1.0000_loss_0.000273_val_accr_0.9940_val_loss_0.019234.pt
#
# Accuracy: 99.94 % (4999 / 5002)
#
# Model: GB_00p_B_2004250155_09440_accr_1.0000_loss_0.000210_val_accr_0.9940_val_loss_0.023770.pt
#
# Accuracy: 99.94 % (4999 / 5002)
#
# Model: GB_00p_B_2004250155_09450_accr_1.0000_loss_0.000126_val_accr_0.9940_val_loss_0.023216.pt
#
# Accuracy: 99.94 % (4999 / 5002)
#
# Model: GB_00p_B_2004250155_09460_accr_1.0000_loss_0.000183_val_accr_0.9940_val_loss_0.025180.pt
#
# Accuracy: 99.94 % (4999 / 5002)
#
# Model: GB_00p_B_2004250155_09470_accr_1.0000_loss_0.000348_val_accr_0.9940_val_loss_0.025923.pt
#
# Accuracy: 99.94 % (4999 / 5002)
#
# Model: GB_00p_B_2004250155_09950_accr_1.0000_loss_0.000203_val_accr_0.9940_val_loss_0.015955.pt
#
# Accuracy: 99.94 % (4999 / 5002)
#
# Model: GB_00p_B_2004250204_00640_accr_0.9818_loss_0.047030_val_accr_0.9741_val_loss_0.068175.pt
#
# Accuracy: 98.10 % (4907 / 5002)
#
# Model: GB_00p_B_2004250204_00650_accr_0.9802_loss_0.054645_val_accr_0.9760_val_loss_0.070365.pt
#
# Accuracy: 97.98 % (4901 / 5002)
#
# Model: GB_00p_B_2004250205_01360_accr_0.9920_loss_0.021877_val_accr_0.9760_val_loss_0.077368.pt
#
# Accuracy: 99.04 % (4954 / 5002)
#
# Model: GB_00p_B_2004250205_01410_accr_0.9918_loss_0.019037_val_accr_0.9800_val_loss_0.098507.pt
#
# Accuracy: 99.06 % (4955 / 5002)
#
# Model: GB_00p_B_2004250206_01850_accr_0.9849_loss_0.040351_val_accr_0.9820_val_loss_0.086026.pt
#
# Accuracy: 98.46 % (4925 / 5002)
#
# Model: GB_00p_B_2004250207_02280_accr_0.9989_loss_0.002642_val_accr_0.9840_val_loss_0.104507.pt
#
# Accuracy: 99.74 % (4989 / 5002)
#
# Model: GB_00p_B_2004250208_03080_accr_1.0000_loss_0.000646_val_accr_0.9880_val_loss_0.079537.pt
#
# Accuracy: 99.88 % (4996 / 5002)
#
# Model: GB_00p_B_2004250210_04200_accr_1.0000_loss_0.000573_val_accr_0.9900_val_loss_0.042397.pt
#
# Accuracy: 99.90 % (4997 / 5002)
#
# Model: GB_00p_B_2004250210_04310_accr_1.0000_loss_0.000076_val_accr_0.9900_val_loss_0.060181.pt
#
# Accuracy: 99.90 % (4997 / 5002)
#
# Model: GB_00p_B_2004250210_04340_accr_1.0000_loss_0.000076_val_accr_0.9900_val_loss_0.060215.pt
#
# Accuracy: 99.90 % (4997 / 5002)
#
# Model: GB_00p_B_2004250210_04380_accr_1.0000_loss_0.000065_val_accr_0.9900_val_loss_0.060679.pt
#
# Accuracy: 99.90 % (4997 / 5002)
#
# Model: GB_00p_B_2004250210_04390_accr_1.0000_loss_0.000041_val_accr_0.9920_val_loss_0.057217.pt
#
# Accuracy: 99.92 % (4998 / 5002)
#
# Model: GB_00p_B_2004250210_04400_accr_1.0000_loss_0.000042_val_accr_0.9920_val_loss_0.057829.pt
#
# Accuracy: 99.92 % (4998 / 5002)
#
# Model: GB_00p_B_2004250216_07950_accr_1.0000_loss_0.000006_val_accr_0.9920_val_loss_0.071482.pt
#
# Accuracy: 99.92 % (4998 / 5002)
#
# Model: GB_00p_B_2004250216_08000_accr_1.0000_loss_0.000002_val_accr_0.9920_val_loss_0.070028.pt
#
# Accuracy: 99.92 % (4998 / 5002)
#
# Model: GB_00p_B_2004250216_08010_accr_1.0000_loss_0.000002_val_accr_0.9920_val_loss_0.069980.pt
#
# Accuracy: 99.92 % (4998 / 5002)
#
# Model: GB_00p_B_2004250216_08310_accr_1.0000_loss_0.000001_val_accr_0.9920_val_loss_0.072911.pt
#
# Accuracy: 99.92 % (4998 / 5002)
#
# Model: GB_00p_B_2004250356_01710_accr_0.9549_loss_0.121311_val_accr_0.9501_val_loss_0.155230.pt
#
# Accuracy: 95.44 % (4774 / 5002)
#
# Model: GB_00p_B_2004250356_01720_accr_0.9751_loss_0.082644_val_accr_0.9501_val_loss_0.131967.pt
#
# Accuracy: 97.26 % (4865 / 5002)
#
# Model: GB_00p_B_2004250356_01740_accr_0.9718_loss_0.089451_val_accr_0.9561_val_loss_0.133285.pt
#
# Accuracy: 97.02 % (4853 / 5002)
#
# Model: GB_00p_B_2004250356_02010_accr_0.9811_loss_0.063326_val_accr_0.9581_val_loss_0.122689.pt
#
# Accuracy: 97.88 % (4896 / 5002)
#
# Model: GB_00p_B_2004250358_03250_accr_0.9962_loss_0.020769_val_accr_0.9621_val_loss_0.116892.pt
#
# Accuracy: 99.28 % (4966 / 5002)
#
# Model: GB_00p_B_2004250359_03600_accr_0.9982_loss_0.011002_val_accr_0.9621_val_loss_0.113287.pt
#
# Accuracy: 99.46 % (4975 / 5002)
#
# Model: GB_00p_B_2004250402_05490_accr_0.9929_loss_0.021596_val_accr_0.9621_val_loss_0.123778.pt
#
# Accuracy: 98.98 % (4951 / 5002)
#
# Model: GB_00p_B_2004250402_05520_accr_0.9989_loss_0.005487_val_accr_0.9681_val_loss_0.112807.pt
#
# Accuracy: 99.58 % (4981 / 5002)
#
# Model: GB_00p_B_2004250411_11200_accr_0.9998_loss_0.001951_val_accr_0.9681_val_loss_0.127675.pt
#
# Accuracy: 99.66 % (4985 / 5002)
#
# Model: GB_00p_B_2004250648_01020_accr_0.9929_loss_0.019832_val_accr_0.9760_val_loss_0.085876.pt
#
# Accuracy: 99.12 % (4958 / 5002)
#
# Model: GB_00p_B_2004250649_01420_accr_0.9869_loss_0.029929_val_accr_0.9840_val_loss_0.061531.pt
#
# Accuracy: 98.66 % (4935 / 5002)
#
# Model: GB_00p_B_2004250650_01860_accr_0.9951_loss_0.013768_val_accr_0.9840_val_loss_0.044894.pt
#
# Accuracy: 99.40 % (4972 / 5002)
#
# Model: GB_00p_B_2004250650_01880_accr_0.9924_loss_0.018829_val_accr_0.9860_val_loss_0.072133.pt
#
# Accuracy: 99.18 % (4961 / 5002)
#
# Model: GB_00p_B_2004250652_02580_accr_0.9944_loss_0.014527_val_accr_0.9920_val_loss_0.047928.pt
#
# Accuracy: 99.42 % (4973 / 5002)
#
# Model: GB_00p_B_2004250652_02700_accr_0.9984_loss_0.003695_val_accr_0.9940_val_loss_0.030721.pt
#
# Accuracy: 99.80 % (4992 / 5002)

# %%
GB_00p_B_model = SSM_Model(np.expand_dims(GB_test_X[:,1,:,:], axis = 1), GB_test_Y, n_ch = 1, n_cls = 2, 
                           class_name = class_name, model_dir = model_dir, model_name = 'GB_00p_B', batch_size = 20, GPU_idx = 3)

GB_00p_B_model.Evaluation()
# Out:
# Model: GB_00p_B_2004250142_00940_accr_0.9829_loss_0.046969_val_accr_0.9601_val_loss_0.104323.pt
#
# Accuracy: 96.66 % (1216 / 1258)
#
# Model: GB_00p_B_2004250142_00950_accr_0.9516_loss_0.136590_val_accr_0.9601_val_loss_0.167247.pt
#
# Accuracy: 92.77 % (1167 / 1258)
#
# Model: GB_00p_B_2004250142_01110_accr_0.9916_loss_0.028663_val_accr_0.9800_val_loss_0.059203.pt
#
# Accuracy: 96.58 % (1215 / 1258)
#
# Model: GB_00p_B_2004250146_03940_accr_0.9987_loss_0.005041_val_accr_0.9800_val_loss_0.049804.pt
#
# Accuracy: 97.69 % (1229 / 1258)
#
# Model: GB_00p_B_2004250147_04290_accr_0.9982_loss_0.008582_val_accr_0.9820_val_loss_0.067888.pt
#
# Accuracy: 97.30 % (1224 / 1258)
#
# Model: GB_00p_B_2004250148_04790_accr_0.9969_loss_0.008159_val_accr_0.9820_val_loss_0.053821.pt
#
# Accuracy: 97.69 % (1229 / 1258)
#
# Model: GB_00p_B_2004250148_05160_accr_0.9998_loss_0.000838_val_accr_0.9940_val_loss_0.020870.pt
#
# Accuracy: 97.85 % (1231 / 1258)
#
# Model: GB_00p_B_2004250148_05170_accr_1.0000_loss_0.000325_val_accr_0.9940_val_loss_0.018372.pt
#
# Accuracy: 98.09 % (1234 / 1258)
#
# Model: GB_00p_B_2004250148_05180_accr_1.0000_loss_0.000228_val_accr_0.9940_val_loss_0.017691.pt
#
# Accuracy: 98.17 % (1235 / 1258)
#
# Model: GB_00p_B_2004250148_05190_accr_1.0000_loss_0.000462_val_accr_0.9940_val_loss_0.020093.pt
#
# Accuracy: 98.09 % (1234 / 1258)
#
# Model: GB_00p_B_2004250148_05200_accr_1.0000_loss_0.000160_val_accr_0.9940_val_loss_0.016891.pt
#
# Accuracy: 98.17 % (1235 / 1258)
#
# Model: GB_00p_B_2004250149_05260_accr_1.0000_loss_0.000273_val_accr_0.9940_val_loss_0.019234.pt
#
# Accuracy: 98.01 % (1233 / 1258)
#
# Model: GB_00p_B_2004250155_09440_accr_1.0000_loss_0.000210_val_accr_0.9940_val_loss_0.023770.pt
#
# Accuracy: 98.49 % (1239 / 1258)
#
# Model: GB_00p_B_2004250155_09450_accr_1.0000_loss_0.000126_val_accr_0.9940_val_loss_0.023216.pt
#
# Accuracy: 98.49 % (1239 / 1258)
#
# Model: GB_00p_B_2004250155_09460_accr_1.0000_loss_0.000183_val_accr_0.9940_val_loss_0.025180.pt
#
# Accuracy: 98.49 % (1239 / 1258)
#
# Model: GB_00p_B_2004250155_09470_accr_1.0000_loss_0.000348_val_accr_0.9940_val_loss_0.025923.pt
#
# Accuracy: 98.49 % (1239 / 1258)
#
# Model: GB_00p_B_2004250155_09950_accr_1.0000_loss_0.000203_val_accr_0.9940_val_loss_0.015955.pt
#
# Accuracy: 98.65 % (1241 / 1258)
#
# Model: GB_00p_B_2004250204_00640_accr_0.9818_loss_0.047030_val_accr_0.9741_val_loss_0.068175.pt
#
# Accuracy: 96.42 % (1213 / 1258)
#
# Model: GB_00p_B_2004250204_00650_accr_0.9802_loss_0.054645_val_accr_0.9760_val_loss_0.070365.pt
#
# Accuracy: 96.34 % (1212 / 1258)
#
# Model: GB_00p_B_2004250205_01360_accr_0.9920_loss_0.021877_val_accr_0.9760_val_loss_0.077368.pt
#
# Accuracy: 97.46 % (1226 / 1258)
#
# Model: GB_00p_B_2004250205_01410_accr_0.9918_loss_0.019037_val_accr_0.9800_val_loss_0.098507.pt
#
# Accuracy: 97.93 % (1232 / 1258)
#
# Model: GB_00p_B_2004250206_01850_accr_0.9849_loss_0.040351_val_accr_0.9820_val_loss_0.086026.pt
#
# Accuracy: 96.50 % (1214 / 1258)
#
# Model: GB_00p_B_2004250207_02280_accr_0.9989_loss_0.002642_val_accr_0.9840_val_loss_0.104507.pt
#
# Accuracy: 97.69 % (1229 / 1258)
#
# Model: GB_00p_B_2004250208_03080_accr_1.0000_loss_0.000646_val_accr_0.9880_val_loss_0.079537.pt
#
# Accuracy: 98.73 % (1242 / 1258)
#
# Model: GB_00p_B_2004250210_04200_accr_1.0000_loss_0.000573_val_accr_0.9900_val_loss_0.042397.pt
#
# Accuracy: 98.41 % (1238 / 1258)
#
# Model: GB_00p_B_2004250210_04310_accr_1.0000_loss_0.000076_val_accr_0.9900_val_loss_0.060181.pt
#
# Accuracy: 98.57 % (1240 / 1258)
#
# Model: GB_00p_B_2004250210_04340_accr_1.0000_loss_0.000076_val_accr_0.9900_val_loss_0.060215.pt
#
# Accuracy: 98.65 % (1241 / 1258)
#
# Model: GB_00p_B_2004250210_04380_accr_1.0000_loss_0.000065_val_accr_0.9900_val_loss_0.060679.pt
#
# Accuracy: 98.57 % (1240 / 1258)
#
# Model: GB_00p_B_2004250210_04390_accr_1.0000_loss_0.000041_val_accr_0.9920_val_loss_0.057217.pt
#
# Accuracy: 98.57 % (1240 / 1258)
#
# Model: GB_00p_B_2004250210_04400_accr_1.0000_loss_0.000042_val_accr_0.9920_val_loss_0.057829.pt
#
# Accuracy: 98.65 % (1241 / 1258)
#
# Model: GB_00p_B_2004250216_07950_accr_1.0000_loss_0.000006_val_accr_0.9920_val_loss_0.071482.pt
#
# Accuracy: 99.21 % (1248 / 1258)
#
# Model: GB_00p_B_2004250216_08000_accr_1.0000_loss_0.000002_val_accr_0.9920_val_loss_0.070028.pt
#
# Accuracy: 98.97 % (1245 / 1258)
#
# Model: GB_00p_B_2004250216_08010_accr_1.0000_loss_0.000002_val_accr_0.9920_val_loss_0.069980.pt
#
# Accuracy: 98.97 % (1245 / 1258)
#
# Model: GB_00p_B_2004250216_08310_accr_1.0000_loss_0.000001_val_accr_0.9920_val_loss_0.072911.pt
#
# Accuracy: 99.05 % (1246 / 1258)
#
# Model: GB_00p_B_2004250356_01710_accr_0.9549_loss_0.121311_val_accr_0.9501_val_loss_0.155230.pt
#
# Accuracy: 93.56 % (1177 / 1258)
#
# Model: GB_00p_B_2004250356_01720_accr_0.9751_loss_0.082644_val_accr_0.9501_val_loss_0.131967.pt
#
# Accuracy: 94.59 % (1190 / 1258)
#
# Model: GB_00p_B_2004250356_01740_accr_0.9718_loss_0.089451_val_accr_0.9561_val_loss_0.133285.pt
#
# Accuracy: 94.75 % (1192 / 1258)
#
# Model: GB_00p_B_2004250356_02010_accr_0.9811_loss_0.063326_val_accr_0.9581_val_loss_0.122689.pt
#
# Accuracy: 95.71 % (1204 / 1258)
#
# Model: GB_00p_B_2004250358_03250_accr_0.9962_loss_0.020769_val_accr_0.9621_val_loss_0.116892.pt
#
# Accuracy: 95.87 % (1206 / 1258)
#
# Model: GB_00p_B_2004250359_03600_accr_0.9982_loss_0.011002_val_accr_0.9621_val_loss_0.113287.pt
#
# Accuracy: 96.26 % (1211 / 1258)
#
# Model: GB_00p_B_2004250402_05490_accr_0.9929_loss_0.021596_val_accr_0.9621_val_loss_0.123778.pt
#
# Accuracy: 95.39 % (1200 / 1258)
#
# Model: GB_00p_B_2004250402_05520_accr_0.9989_loss_0.005487_val_accr_0.9681_val_loss_0.112807.pt
#
# Accuracy: 95.87 % (1206 / 1258)
#
# Model: GB_00p_B_2004250411_11200_accr_0.9998_loss_0.001951_val_accr_0.9681_val_loss_0.127675.pt
#
# Accuracy: 95.95 % (1207 / 1258)
#
# Model: GB_00p_B_2004250648_01020_accr_0.9929_loss_0.019832_val_accr_0.9760_val_loss_0.085876.pt
#
# Accuracy: 96.58 % (1215 / 1258)
#
# Model: GB_00p_B_2004250649_01420_accr_0.9869_loss_0.029929_val_accr_0.9840_val_loss_0.061531.pt
#
# Accuracy: 96.58 % (1215 / 1258)
#
# Model: GB_00p_B_2004250650_01860_accr_0.9951_loss_0.013768_val_accr_0.9840_val_loss_0.044894.pt
#
# Accuracy: 97.62 % (1228 / 1258)
#
# Model: GB_00p_B_2004250650_01880_accr_0.9924_loss_0.018829_val_accr_0.9860_val_loss_0.072133.pt
#
# Accuracy: 96.66 % (1216 / 1258)
#
# Model: GB_00p_B_2004250652_02580_accr_0.9944_loss_0.014527_val_accr_0.9920_val_loss_0.047928.pt
#
# Accuracy: 97.22 % (1223 / 1258)
#
# Model: GB_00p_B_2004250652_02700_accr_0.9984_loss_0.003695_val_accr_0.9940_val_loss_0.030721.pt
#
# Accuracy: 97.69 % (1229 / 1258)
#
# Model: GB_00p_B_2004250812_00630_accr_0.9976_loss_0.013878_val_accr_0.9760_val_loss_0.068001.pt
#
# Accuracy: 96.03 % (1208 / 1258)
#
# Model: GB_00p_B_2004250821_00310_accr_0.9678_loss_0.083852_val_accr_0.9441_val_loss_0.138587.pt
#
# Accuracy: 94.20 % (1185 / 1258)
#
# Model: GB_00p_B_2004250850_04280_accr_0.9771_loss_0.048586_val_accr_0.9222_val_loss_0.300042.pt
#
# Accuracy: 91.49 % (1151 / 1258)
#
# Model: GB_00p_B_2004250852_05880_accr_0.9725_loss_0.063789_val_accr_0.9222_val_loss_0.296940.pt
#
# Accuracy: 91.34 % (1149 / 1258)
#
# Model: GB_00p_B_2004250853_06500_accr_0.9947_loss_0.015941_val_accr_0.9381_val_loss_0.246480.pt
#
# Accuracy: 92.61 % (1165 / 1258)
#
# Model: GB_00p_B_2004250857_11470_accr_0.9973_loss_0.008804_val_accr_0.9481_val_loss_0.215184.pt
#
# Accuracy: 94.20 % (1185 / 1258)
#
# Model: GB_00p_B_2004250857_11620_accr_0.9907_loss_0.025310_val_accr_0.9501_val_loss_0.140662.pt
#
# Accuracy: 94.52 % (1189 / 1258)

# %%
GB_00p_B_model = SSM_Model(np.expand_dims(GB_test_X[:,1,:,:], axis = 1), GB_test_Y, n_ch = 1, n_cls = 2, 
                           class_name = class_name, model_dir = model_dir, model_name = 'GB_00p_B', batch_size = 20, GPU_idx = 3)

GB_00p_B_model.Evaluation()
GB_00p_B_model.ConfusionMatrix(CM_save_dir, x_angle = 0)
# Out:
# Model: GB_00p_B_2004250210_04390_accr_1.0000_loss_0.000041_val_accr_0.9920_val_loss_0.057217.pt
#
# Accuracy: 98.57 % (1240 / 1258)

# %%
df = pd.DataFrame(columns = ['Accuracy', 'Precision', 'Recall', 'F1 score'])

CMs = [GB_00p_A_model.cm, GB_00p_B_model.cm, GB_00p_AB_model.cm]
model_names = [GB_00p_A_model.model_name, GB_00p_B_model.model_name, GB_00p_AB_model.model_name]

for cm, model_name in zip(CMs, model_names):
    accr = round((cm[0, 0] + cm[1, 1]) / np.sum(cm), 4)
    precision = round(cm[1, 1] / (cm[0, 1] + cm[1, 1]), 4)
    recall = round(cm[1, 1] / (cm[1, 0] + cm[1, 1]), 4)
    f1_score = round(2*precision*recall/(precision + recall), 4)
    df.loc[model_name] = [accr, precision, recall, f1_score]

df.to_csv('./results/GB_00p_cls_performance.csv',encoding='utf-8-sig', index = True)    
    
df
# Out:
#            Accuracy  Precision  Recall  F1 score
# GB_00p_A     0.9777     0.9933  0.9701    0.9816
# GB_00p_B     0.9857     0.9947  0.9818    0.9882
# GB_00p_AB    0.9905     0.9909  0.9935    0.9922

# %%
def ROCplot(test_Y, model, color, model_name = ''):
    fpr, tpr, _ = roc_curve(test_Y, model.score[:, 1])
    roc_auc = auc(fpr, tpr)

    plt.plot(fpr, tpr, color = color, lw=1.2, label='{} (AUC = {:.4f})'.format(model_name, roc_auc))
    # plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')

fig = plt.figure(figsize = (10, 8))

ROCplot(GB_test_Y, GB_00p_A_model, 'g', 'A1')
ROCplot(GB_test_Y, GB_00p_B_model, 'c', 'A2')
ROCplot(GB_test_Y, GB_00p_AB_model, 'r', 'A1 & A2')

plt.xlim([-0.01, 1.0])
plt.ylim([0.0, 1.01])
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.xlabel('False Positive Rate', fontsize = 16)
plt.ylabel('True Positive Rate', fontsize = 16)
# plt.title('Receiver operating characteristic')
plt.legend(loc="lower right", fontsize = 14)
plt.show()

fig.savefig('./results/GB_ROC_curves.png', bbox_inches='tight')

# %% [markdown]
# ```{python}
#
# def ROCplot(test_Y, model, model_name = ''):
#     fpr, tpr, _ = roc_curve(test_Y, model.score[:, 1])
#     roc_auc = auc(fpr, tpr)
#
#     plt.plot(fpr, tpr, lw=2, label='{} (area = {:.2f})'.format(model_name, roc_auc))
#     # plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
#
#
# plt.figure(figsize = (10, 10))
#
# ROCplot(GB_test_Y, GB_00p_AB_model, 'GB_00p_AB')
# ROCplot(GB_test_Y, GB_00p_A_model, 'GB_00p_A')
# ROCplot(GB_test_Y, GB_00p_B_model, 'GB_00p_B')
#
# plt.xlim([-0.01, 1.0])
# plt.ylim([0.0, 1.01])
# plt.xlabel('False Positive Rate', fontsize = 16)
# plt.ylabel('True Positive Rate', fontsize = 16)
# # plt.title('Receiver operating characteristic')
# plt.legend(loc="lower right", fontsize = 14)
# plt.show()
# ```

# %% [markdown]
# # 2. Fault classification

# %%
class_name = ['Heavy Oil', 'Die Punch', 'Scrapped Wire', 'Die Chip', 'Die Internal', 'PIN']

# %%
B6_00p_AB_model = SSM_Model(B6_train_X, B6_train_Y, n_ch = 2, n_cls = 6, class_name = class_name, 
                            model_dir = model_dir, model_name = 'B6_00p_AB', batch_size = 20, GPU_idx = 3)

B6_00p_AB_model.Evaluation()
# Out:
# Model: B6_00p_AB_2005010411_08760_accr_0.9945_loss_0.014556_val_accr_0.8762_val_loss_1.120143.pt
#
# Accuracy: 98.26 % (2997 / 3050)
#
# Model: B6_00p_AB_2005010411_08960_accr_0.9803_loss_0.072975_val_accr_0.8827_val_loss_0.974075.pt
#
# Accuracy: 97.05 % (2960 / 3050)
#
# Model: B6_00p_AB_2005010416_12760_accr_0.9960_loss_0.014255_val_accr_0.8925_val_loss_0.953536.pt
#
# Accuracy: 98.56 % (3006 / 3050)
#
# Model: B6_00p_AB_2005010439_05610_accr_0.9953_loss_0.016913_val_accr_0.8860_val_loss_0.540594.pt
#
# Accuracy: 98.43 % (3002 / 3050)
#
# Model: B6_00p_AB_2005010444_10000_accr_0.9960_loss_0.011617_val_accr_0.8860_val_loss_0.602588.pt
#
# Accuracy: 98.49 % (3004 / 3050)
#
# Model: B6_00p_AB_2005010444_10320_accr_0.9953_loss_0.018672_val_accr_0.8893_val_loss_0.866875.pt
#
# Accuracy: 98.46 % (3003 / 3050)
#
# Model: B6_00p_AB_2005010445_10680_accr_0.9829_loss_0.062033_val_accr_0.8893_val_loss_0.636872.pt
#
# Accuracy: 97.34 % (2969 / 3050)
#
# Model: B6_00p_AB_2005010446_11780_accr_0.9821_loss_0.047484_val_accr_0.9088_val_loss_0.604431.pt
#
# Accuracy: 97.48 % (2973 / 3050)
#
# Model: B6_00p_AB_2005010446_11790_accr_0.9964_loss_0.012460_val_accr_0.9088_val_loss_0.563274.pt
#
# Accuracy: 98.75 % (3012 / 3050)
#
# Model: B6_00p_AB_2005010614_06760_accr_1.0000_loss_0.000054_val_accr_0.9381_val_loss_0.809278.pt
#
# Accuracy: 99.38 % (3031 / 3050)
#
# Model: B6_00p_AB_2005010614_06770_accr_1.0000_loss_0.000023_val_accr_0.9381_val_loss_0.799448.pt
#
# Accuracy: 99.38 % (3031 / 3050)
#
# Model: B6_00p_AB_2005010614_06800_accr_1.0000_loss_0.000003_val_accr_0.9381_val_loss_0.804413.pt
#
# Accuracy: 99.38 % (3031 / 3050)
#
# Model: B6_00p_AB_2005010614_06870_accr_1.0000_loss_0.000005_val_accr_0.9381_val_loss_0.829612.pt
#
# Accuracy: 99.38 % (3031 / 3050)
#
# Model: B6_00p_AB_2005010614_06940_accr_1.0000_loss_0.000004_val_accr_0.9381_val_loss_0.841021.pt
#
# Accuracy: 99.38 % (3031 / 3050)
#
# Model: B6_00p_AB_2005010615_07130_accr_1.0000_loss_0.000001_val_accr_0.9414_val_loss_0.848562.pt
#
# Accuracy: 99.41 % (3032 / 3050)
#
# Model: B6_00p_AB_2005010621_09910_accr_1.0000_loss_0.000044_val_accr_0.9414_val_loss_0.474322.pt
#
# Accuracy: 99.41 % (3032 / 3050)
#
# Model: B6_00p_AB_2005010621_09930_accr_1.0000_loss_0.000022_val_accr_0.9414_val_loss_0.459252.pt
#
# Accuracy: 99.41 % (3032 / 3050)
#
# Model: B6_00p_AB_2005010621_09940_accr_1.0000_loss_0.000007_val_accr_0.9414_val_loss_0.429902.pt
#
# Accuracy: 99.41 % (3032 / 3050)
#
# Model: B6_00p_AB_2005010621_09950_accr_1.0000_loss_0.000004_val_accr_0.9446_val_loss_0.429591.pt
#
# Accuracy: 99.44 % (3033 / 3050)
#
# Model: B6_00p_AB_2005010621_09960_accr_1.0000_loss_0.000007_val_accr_0.9479_val_loss_0.429951.pt
#
# Accuracy: 99.48 % (3034 / 3050)
#
# Model: B6_00p_AB_2005010725_13210_accr_1.0000_loss_0.000115_val_accr_0.9088_val_loss_0.833807.pt
#
# Accuracy: 99.08 % (3022 / 3050)
#
# Model: B6_00p_AB_2005010725_13240_accr_1.0000_loss_0.000439_val_accr_0.9088_val_loss_0.864346.pt
#
# Accuracy: 99.08 % (3022 / 3050)
#
# Model: B6_00p_AB_2005010725_13390_accr_1.0000_loss_0.000050_val_accr_0.9088_val_loss_0.846835.pt
#
# Accuracy: 99.08 % (3022 / 3050)
#
# Model: B6_00p_AB_2005010725_13470_accr_1.0000_loss_0.000003_val_accr_0.9121_val_loss_0.790560.pt
#
# Accuracy: 99.11 % (3023 / 3050)
#
# Model: B6_00p_AB_2005010727_14350_accr_1.0000_loss_0.000008_val_accr_0.9121_val_loss_0.887200.pt
#
# Accuracy: 99.11 % (3023 / 3050)

# %%
B6_00p_AB_model = SSM_Model(B6_test_X, B6_test_Y, n_ch = 2, n_cls = 6, class_name = class_name, 
                            model_dir = model_dir, model_name = 'B6_00p_AB', batch_size = 20, GPU_idx = 3)

B6_00p_AB_model.Evaluation()
# Out:
# Model: B6_00p_AB_2005010411_08760_accr_0.9945_loss_0.014556_val_accr_0.8762_val_loss_1.120143.pt
#
# Accuracy: 88.28 % (678 / 768)
#
# Model: B6_00p_AB_2005010411_08960_accr_0.9803_loss_0.072975_val_accr_0.8827_val_loss_0.974075.pt
#
# Accuracy: 85.81 % (659 / 768)
#
# Model: B6_00p_AB_2005010416_12760_accr_0.9960_loss_0.014255_val_accr_0.8925_val_loss_0.953536.pt
#
# Accuracy: 88.02 % (676 / 768)
#
# Model: B6_00p_AB_2005010439_05610_accr_0.9953_loss_0.016913_val_accr_0.8860_val_loss_0.540594.pt
#
# Accuracy: 89.19 % (685 / 768)
#
# Model: B6_00p_AB_2005010444_10000_accr_0.9960_loss_0.011617_val_accr_0.8860_val_loss_0.602588.pt
#
# Accuracy: 90.10 % (692 / 768)
#
# Model: B6_00p_AB_2005010444_10320_accr_0.9953_loss_0.018672_val_accr_0.8893_val_loss_0.866875.pt
#
# Accuracy: 88.54 % (680 / 768)
#
# Model: B6_00p_AB_2005010445_10680_accr_0.9829_loss_0.062033_val_accr_0.8893_val_loss_0.636872.pt
#
# Accuracy: 85.55 % (657 / 768)
#
# Model: B6_00p_AB_2005010446_11780_accr_0.9821_loss_0.047484_val_accr_0.9088_val_loss_0.604431.pt
#
# Accuracy: 86.59 % (665 / 768)
#
# Model: B6_00p_AB_2005010446_11790_accr_0.9964_loss_0.012460_val_accr_0.9088_val_loss_0.563274.pt
#
# Accuracy: 89.19 % (685 / 768)
#
# Model: B6_00p_AB_2005010614_06760_accr_1.0000_loss_0.000054_val_accr_0.9381_val_loss_0.809278.pt
#
# Accuracy: 91.54 % (703 / 768)
#
# Model: B6_00p_AB_2005010614_06770_accr_1.0000_loss_0.000023_val_accr_0.9381_val_loss_0.799448.pt
#
# Accuracy: 92.45 % (710 / 768)
#
# Model: B6_00p_AB_2005010614_06800_accr_1.0000_loss_0.000003_val_accr_0.9381_val_loss_0.804413.pt
#
# Accuracy: 92.32 % (709 / 768)
#
# Model: B6_00p_AB_2005010614_06870_accr_1.0000_loss_0.000005_val_accr_0.9381_val_loss_0.829612.pt
#
# Accuracy: 90.76 % (697 / 768)
#
# Model: B6_00p_AB_2005010614_06940_accr_1.0000_loss_0.000004_val_accr_0.9381_val_loss_0.841021.pt
#
# Accuracy: 90.49 % (695 / 768)
#
# Model: B6_00p_AB_2005010615_07130_accr_1.0000_loss_0.000001_val_accr_0.9414_val_loss_0.848562.pt
#
# Accuracy: 92.97 % (714 / 768)
#
# Model: B6_00p_AB_2005010621_09910_accr_1.0000_loss_0.000044_val_accr_0.9414_val_loss_0.474322.pt
#
# Accuracy: 91.28 % (701 / 768)
#
# Model: B6_00p_AB_2005010621_09930_accr_1.0000_loss_0.000022_val_accr_0.9414_val_loss_0.459252.pt
#
# Accuracy: 91.80 % (705 / 768)
#
# Model: B6_00p_AB_2005010621_09940_accr_1.0000_loss_0.000007_val_accr_0.9414_val_loss_0.429902.pt
#
# Accuracy: 91.93 % (706 / 768)
#
# Model: B6_00p_AB_2005010621_09950_accr_1.0000_loss_0.000004_val_accr_0.9446_val_loss_0.429591.pt
#
# Accuracy: 91.93 % (706 / 768)
#
# Model: B6_00p_AB_2005010621_09960_accr_1.0000_loss_0.000007_val_accr_0.9479_val_loss_0.429951.pt
#
# Accuracy: 92.06 % (707 / 768)
#
# Model: B6_00p_AB_2005010725_13210_accr_1.0000_loss_0.000115_val_accr_0.9088_val_loss_0.833807.pt
#
# Accuracy: 87.76 % (674 / 768)
#
# Model: B6_00p_AB_2005010725_13240_accr_1.0000_loss_0.000439_val_accr_0.9088_val_loss_0.864346.pt
#
# Accuracy: 87.24 % (670 / 768)
#
# Model: B6_00p_AB_2005010725_13390_accr_1.0000_loss_0.000050_val_accr_0.9088_val_loss_0.846835.pt
#
# Accuracy: 87.50 % (672 / 768)
#
# Model: B6_00p_AB_2005010725_13470_accr_1.0000_loss_0.000003_val_accr_0.9121_val_loss_0.790560.pt
#
# Accuracy: 88.41 % (679 / 768)
#
# Model: B6_00p_AB_2005010727_14350_accr_1.0000_loss_0.000008_val_accr_0.9121_val_loss_0.887200.pt
#
# Accuracy: 89.45 % (687 / 768)

# %%
B6_00p_AB_model = SSM_Model(B6_test_X, B6_test_Y, n_ch = 2, n_cls = 6, class_name = class_name, 
                            model_dir = model_dir, model_name = 'B6_00p_AB', batch_size = 20, GPU_idx = 3)

B6_00p_AB_model.Evaluation()
B6_00p_AB_model.ConfusionMatrix(CM_save_dir, x_angle = 45)
# Out:
# Model: B6_00p_AB_2005010621_09960_accr_1.0000_loss_0.000007_val_accr_0.9479_val_loss_0.429951.pt
#
# Accuracy: 92.06 % (707 / 768)

# %%
B6_00p_A_model = SSM_Model(np.expand_dims(B6_train_X[:,0,:,:], axis = 1), B6_train_Y, n_ch = 1, n_cls = 6, 
                           class_name = class_name, model_dir = model_dir, model_name = 'B6_00p_A', batch_size = 20, GPU_idx = 3)

B6_00p_A_model.Evaluation()
# Out:
# Model: B6_00p_A_2005010413_09380_accr_0.9949_loss_0.012869_val_accr_0.8306_val_loss_1.621114.pt
#
# Accuracy: 97.84 % (2984 / 3050)
#
# Model: B6_00p_A_2005010413_09720_accr_0.9920_loss_0.027848_val_accr_0.8371_val_loss_1.464677.pt
#
# Accuracy: 97.64 % (2978 / 3050)
#
# Model: B6_00p_A_2005010413_09860_accr_0.9978_loss_0.005025_val_accr_0.8436_val_loss_1.431561.pt
#
# Accuracy: 98.23 % (2996 / 3050)
#
# Model: B6_00p_A_2005010416_12680_accr_0.9978_loss_0.005949_val_accr_0.8502_val_loss_1.206021.pt
#
# Accuracy: 98.30 % (2998 / 3050)
#
# Model: B6_00p_A_2005010417_13160_accr_0.9927_loss_0.019277_val_accr_0.8599_val_loss_1.353979.pt
#
# Accuracy: 97.93 % (2987 / 3050)
#
# Model: B6_00p_A_2005010441_07460_accr_0.9573_loss_0.131489_val_accr_0.8241_val_loss_1.354032.pt
#
# Accuracy: 94.39 % (2879 / 3050)
#
# Model: B6_00p_A_2005010442_08650_accr_0.9843_loss_0.040604_val_accr_0.8241_val_loss_1.199151.pt
#
# Accuracy: 96.82 % (2953 / 3050)
#
# Model: B6_00p_A_2005010444_10340_accr_0.9989_loss_0.004908_val_accr_0.8371_val_loss_1.314801.pt
#
# Accuracy: 98.26 % (2997 / 3050)
#
# Model: B6_00p_A_2005010446_11630_accr_0.9938_loss_0.018706_val_accr_0.8632_val_loss_1.086056.pt
#
# Accuracy: 98.07 % (2991 / 3050)
#
# Model: B6_00p_A_2005010604_02250_accr_0.9840_loss_0.048515_val_accr_0.8567_val_loss_1.170911.pt
#
# Accuracy: 97.11 % (2962 / 3050)
#
# Model: B6_00p_A_2005010605_02830_accr_0.9876_loss_0.051301_val_accr_0.8632_val_loss_1.170864.pt
#
# Accuracy: 97.51 % (2974 / 3050)
#
# Model: B6_00p_A_2005010607_03890_accr_0.9938_loss_0.021867_val_accr_0.8632_val_loss_0.867214.pt
#
# Accuracy: 98.07 % (2991 / 3050)
#
# Model: B6_00p_A_2005010612_05900_accr_1.0000_loss_0.000364_val_accr_0.8632_val_loss_1.616242.pt
#
# Accuracy: 98.62 % (3008 / 3050)
#
# Model: B6_00p_A_2005010612_05910_accr_1.0000_loss_0.000092_val_accr_0.8632_val_loss_1.637772.pt
#
# Accuracy: 98.62 % (3008 / 3050)
#
# Model: B6_00p_A_2005010612_06040_accr_0.9909_loss_0.034031_val_accr_0.8762_val_loss_1.641017.pt
#
# Accuracy: 97.93 % (2987 / 3050)
#
# Model: B6_00p_A_2005010613_06600_accr_0.9989_loss_0.003516_val_accr_0.8762_val_loss_1.087946.pt
#
# Accuracy: 98.66 % (3009 / 3050)
#
# Model: B6_00p_A_2005010617_08340_accr_0.9832_loss_0.095915_val_accr_0.8762_val_loss_2.612222.pt
#
# Accuracy: 97.25 % (2966 / 3050)
#
# Model: B6_00p_A_2005010621_10180_accr_1.0000_loss_0.000407_val_accr_0.8795_val_loss_1.615937.pt
#
# Accuracy: 98.79 % (3013 / 3050)
#
# Model: B6_00p_A_2005010629_13780_accr_0.9989_loss_0.003237_val_accr_0.8893_val_loss_1.376374.pt
#
# Accuracy: 98.79 % (3013 / 3050)
#
# Model: B6_00p_A_2005010714_09050_accr_1.0000_loss_0.000001_val_accr_0.8176_val_loss_2.061880.pt
#
# Accuracy: 98.16 % (2994 / 3050)
#
# Model: B6_00p_A_2005010714_09060_accr_1.0000_loss_0.000001_val_accr_0.8241_val_loss_1.986627.pt
#
# Accuracy: 98.23 % (2996 / 3050)
#
# Model: B6_00p_A_2005010719_11170_accr_0.9949_loss_0.012723_val_accr_0.8241_val_loss_1.427058.pt
#
# Accuracy: 97.77 % (2982 / 3050)
#
# Model: B6_00p_A_2005010720_11650_accr_0.9978_loss_0.009413_val_accr_0.8306_val_loss_1.488266.pt
#
# Accuracy: 98.10 % (2992 / 3050)
#
# Model: B6_00p_A_2005010722_12760_accr_1.0000_loss_0.000001_val_accr_0.8404_val_loss_1.885805.pt
#
# Accuracy: 98.39 % (3001 / 3050)
#
# Model: B6_00p_A_2005010725_13890_accr_1.0000_loss_0.000000_val_accr_0.8436_val_loss_1.614684.pt
#
# Accuracy: 98.43 % (3002 / 3050)
#
# Model: B6_00p_A_2005010725_13900_accr_1.0000_loss_0.000000_val_accr_0.8534_val_loss_1.629553.pt
#
# Accuracy: 98.52 % (3005 / 3050)

# %%
B6_00p_A_model = SSM_Model(np.expand_dims(B6_test_X[:,0,:,:], axis = 1), B6_test_Y, n_ch = 1, n_cls = 6, 
                           class_name = class_name, model_dir = model_dir, model_name = 'B6_00p_A', batch_size = 20, GPU_idx = 3)

B6_00p_A_model.Evaluation()
# Out:
# Model: B6_00p_A_2005010413_09380_accr_0.9949_loss_0.012869_val_accr_0.8306_val_loss_1.621114.pt
#
# Accuracy: 81.51 % (626 / 768)
#
# Model: B6_00p_A_2005010413_09720_accr_0.9920_loss_0.027848_val_accr_0.8371_val_loss_1.464677.pt
#
# Accuracy: 79.82 % (613 / 768)
#
# Model: B6_00p_A_2005010413_09860_accr_0.9978_loss_0.005025_val_accr_0.8436_val_loss_1.431561.pt
#
# Accuracy: 79.04 % (607 / 768)
#
# Model: B6_00p_A_2005010416_12680_accr_0.9978_loss_0.005949_val_accr_0.8502_val_loss_1.206021.pt
#
# Accuracy: 81.38 % (625 / 768)
#
# Model: B6_00p_A_2005010417_13160_accr_0.9927_loss_0.019277_val_accr_0.8599_val_loss_1.353979.pt
#
# Accuracy: 80.08 % (615 / 768)
#
# Model: B6_00p_A_2005010441_07460_accr_0.9573_loss_0.131489_val_accr_0.8241_val_loss_1.354032.pt
#
# Accuracy: 80.34 % (617 / 768)
#
# Model: B6_00p_A_2005010442_08650_accr_0.9843_loss_0.040604_val_accr_0.8241_val_loss_1.199151.pt
#
# Accuracy: 81.64 % (627 / 768)
#
# Model: B6_00p_A_2005010444_10340_accr_0.9989_loss_0.004908_val_accr_0.8371_val_loss_1.314801.pt
#
# Accuracy: 82.94 % (637 / 768)
#
# Model: B6_00p_A_2005010446_11630_accr_0.9938_loss_0.018706_val_accr_0.8632_val_loss_1.086056.pt
#
# Accuracy: 81.38 % (625 / 768)
#
# Model: B6_00p_A_2005010604_02250_accr_0.9840_loss_0.048515_val_accr_0.8567_val_loss_1.170911.pt
#
# Accuracy: 84.11 % (646 / 768)
#
# Model: B6_00p_A_2005010605_02830_accr_0.9876_loss_0.051301_val_accr_0.8632_val_loss_1.170864.pt
#
# Accuracy: 83.07 % (638 / 768)
#
# Model: B6_00p_A_2005010607_03890_accr_0.9938_loss_0.021867_val_accr_0.8632_val_loss_0.867214.pt
#
# Accuracy: 86.20 % (662 / 768)
#
# Model: B6_00p_A_2005010612_05900_accr_1.0000_loss_0.000364_val_accr_0.8632_val_loss_1.616242.pt
#
# Accuracy: 85.29 % (655 / 768)
#
# Model: B6_00p_A_2005010612_05910_accr_1.0000_loss_0.000092_val_accr_0.8632_val_loss_1.637772.pt
#
# Accuracy: 86.59 % (665 / 768)
#
# Model: B6_00p_A_2005010612_06040_accr_0.9909_loss_0.034031_val_accr_0.8762_val_loss_1.641017.pt
#
# Accuracy: 85.03 % (653 / 768)
#
# Model: B6_00p_A_2005010613_06600_accr_0.9989_loss_0.003516_val_accr_0.8762_val_loss_1.087946.pt
#
# Accuracy: 86.85 % (667 / 768)
#
# Model: B6_00p_A_2005010617_08340_accr_0.9832_loss_0.095915_val_accr_0.8762_val_loss_2.612222.pt
#
# Accuracy: 84.24 % (647 / 768)
#
# Model: B6_00p_A_2005010621_10180_accr_1.0000_loss_0.000407_val_accr_0.8795_val_loss_1.615937.pt
#
# Accuracy: 87.50 % (672 / 768)
#
# Model: B6_00p_A_2005010629_13780_accr_0.9989_loss_0.003237_val_accr_0.8893_val_loss_1.376374.pt
#
# Accuracy: 85.55 % (657 / 768)
#
# Model: B6_00p_A_2005010714_09050_accr_1.0000_loss_0.000001_val_accr_0.8176_val_loss_2.061880.pt
#
# Accuracy: 81.38 % (625 / 768)
#
# Model: B6_00p_A_2005010714_09060_accr_1.0000_loss_0.000001_val_accr_0.8241_val_loss_1.986627.pt
#
# Accuracy: 81.38 % (625 / 768)
#
# Model: B6_00p_A_2005010719_11170_accr_0.9949_loss_0.012723_val_accr_0.8241_val_loss_1.427058.pt
#
# Accuracy: 82.03 % (630 / 768)
#
# Model: B6_00p_A_2005010720_11650_accr_0.9978_loss_0.009413_val_accr_0.8306_val_loss_1.488266.pt
#
# Accuracy: 82.16 % (631 / 768)
#
# Model: B6_00p_A_2005010722_12760_accr_1.0000_loss_0.000001_val_accr_0.8404_val_loss_1.885805.pt
#
# Accuracy: 83.46 % (641 / 768)
#
# Model: B6_00p_A_2005010725_13890_accr_1.0000_loss_0.000000_val_accr_0.8436_val_loss_1.614684.pt
#
# Accuracy: 83.07 % (638 / 768)
#
# Model: B6_00p_A_2005010725_13900_accr_1.0000_loss_0.000000_val_accr_0.8534_val_loss_1.629553.pt
#
# Accuracy: 83.72 % (643 / 768)

# %%
B6_00p_A_model = SSM_Model(np.expand_dims(B6_test_X[:,0,:,:], axis = 1), B6_test_Y, n_ch = 1, n_cls = 6, 
                           class_name = class_name, model_dir = model_dir, model_name = 'B6_00p_A', batch_size = 20, GPU_idx = 3)

B6_00p_A_model.Evaluation()
B6_00p_A_model.ConfusionMatrix(CM_save_dir, x_angle = 45)
# Out:
# Model: B6_00p_A_2005010629_13780_accr_0.9989_loss_0.003237_val_accr_0.8893_val_loss_1.376374.pt
#
# Accuracy: 85.55 % (657 / 768)

# %%
B6_00p_B_model = SSM_Model(np.expand_dims(B6_train_X[:,1,:,:], axis = 1), B6_train_Y, n_ch = 1, n_cls = 6, 
                           class_name = class_name, model_dir = model_dir, model_name = 'B6_00p_B', batch_size = 20, GPU_idx = 3)

B6_00p_B_model.Evaluation()
# Out:
# Model: B6_00p_B_2005010439_06420_accr_1.0000_loss_0.000713_val_accr_0.9218_val_loss_0.495169.pt
#
# Accuracy: 99.21 % (3026 / 3050)
#
# Model: B6_00p_B_2005010439_06430_accr_1.0000_loss_0.000357_val_accr_0.9251_val_loss_0.515808.pt
#
# Accuracy: 99.25 % (3027 / 3050)
#
# Model: B6_00p_B_2005010439_06440_accr_1.0000_loss_0.000236_val_accr_0.9316_val_loss_0.518386.pt
#
# Accuracy: 99.31 % (3029 / 3050)
#
# Model: B6_00p_B_2005010439_06510_accr_1.0000_loss_0.000455_val_accr_0.9316_val_loss_0.533475.pt
#
# Accuracy: 99.31 % (3029 / 3050)
#
# Model: B6_00p_B_2005010514_11830_accr_1.0000_loss_0.001718_val_accr_0.9088_val_loss_0.320229.pt
#
# Accuracy: 99.08 % (3022 / 3050)
#
# Model: B6_00p_B_2005010515_12440_accr_1.0000_loss_0.001359_val_accr_0.9088_val_loss_0.348866.pt
#
# Accuracy: 99.08 % (3022 / 3050)
#
# Model: B6_00p_B_2005010515_12460_accr_1.0000_loss_0.000506_val_accr_0.9186_val_loss_0.324762.pt
#
# Accuracy: 99.18 % (3025 / 3050)
#
# Model: B6_00p_B_2005010515_12570_accr_1.0000_loss_0.000162_val_accr_0.9186_val_loss_0.357604.pt
#
# Accuracy: 99.18 % (3025 / 3050)
#
# Model: B6_00p_B_2005010516_13640_accr_0.9982_loss_0.004939_val_accr_0.9186_val_loss_0.329401.pt
#
# Accuracy: 99.02 % (3020 / 3050)
#
# Model: B6_00p_B_2005010517_13650_accr_0.9993_loss_0.002759_val_accr_0.9218_val_loss_0.342342.pt
#
# Accuracy: 99.15 % (3024 / 3050)
#
# Model: B6_00p_B_2005010517_13660_accr_1.0000_loss_0.000711_val_accr_0.9283_val_loss_0.327192.pt
#
# Accuracy: 99.28 % (3028 / 3050)
#
# Model: B6_00p_B_2005010604_02290_accr_0.9978_loss_0.006500_val_accr_0.9055_val_loss_0.772192.pt
#
# Accuracy: 98.85 % (3015 / 3050)
#
# Model: B6_00p_B_2005010611_05250_accr_1.0000_loss_0.000052_val_accr_0.9153_val_loss_1.277981.pt
#
# Accuracy: 99.15 % (3024 / 3050)
#
# Model: B6_00p_B_2005010611_05260_accr_1.0000_loss_0.000007_val_accr_0.9153_val_loss_1.308288.pt
#
# Accuracy: 99.15 % (3024 / 3050)
#
# Model: B6_00p_B_2005010613_06200_accr_1.0000_loss_0.000000_val_accr_0.9186_val_loss_1.336733.pt
#
# Accuracy: 99.18 % (3025 / 3050)
#
# Model: B6_00p_B_2005010614_06680_accr_1.0000_loss_0.000005_val_accr_0.9218_val_loss_1.536705.pt
#
# Accuracy: 99.21 % (3026 / 3050)
#
# Model: B6_00p_B_2005010626_12500_accr_1.0000_loss_0.000162_val_accr_0.9218_val_loss_1.351998.pt
#
# Accuracy: 99.21 % (3026 / 3050)
#
# Model: B6_00p_B_2005010626_12540_accr_1.0000_loss_0.000004_val_accr_0.9218_val_loss_1.276075.pt
#
# Accuracy: 99.21 % (3026 / 3050)
#
# Model: B6_00p_B_2005010626_12550_accr_1.0000_loss_0.000002_val_accr_0.9218_val_loss_1.296998.pt
#
# Accuracy: 99.21 % (3026 / 3050)
#
# Model: B6_00p_B_2005010626_12560_accr_1.0000_loss_0.000003_val_accr_0.9251_val_loss_1.337638.pt
#
# Accuracy: 99.25 % (3027 / 3050)
#
# Model: B6_00p_B_2005010626_12570_accr_1.0000_loss_0.000002_val_accr_0.9251_val_loss_1.344183.pt
#
# Accuracy: 99.25 % (3027 / 3050)
#
# Model: B6_00p_B_2005010626_12580_accr_1.0000_loss_0.000002_val_accr_0.9251_val_loss_1.357337.pt
#
# Accuracy: 99.25 % (3027 / 3050)
#
# Model: B6_00p_B_2005010716_10180_accr_1.0000_loss_0.000135_val_accr_0.9055_val_loss_0.645415.pt
#
# Accuracy: 99.05 % (3021 / 3050)
#
# Model: B6_00p_B_2005010717_10510_accr_1.0000_loss_0.000001_val_accr_0.9055_val_loss_0.721574.pt
#
# Accuracy: 99.05 % (3021 / 3050)
#
# Model: B6_00p_B_2005010717_10520_accr_1.0000_loss_0.000001_val_accr_0.9121_val_loss_0.692011.pt
#
# Accuracy: 99.11 % (3023 / 3050)
#
# Model: B6_00p_B_2005010722_12870_accr_1.0000_loss_0.000000_val_accr_0.9121_val_loss_0.971915.pt
#
# Accuracy: 99.11 % (3023 / 3050)

# %%
B6_00p_B_model = SSM_Model(np.expand_dims(B6_test_X[:,1,:,:], axis = 1), B6_test_Y, n_ch = 1, n_cls = 6, 
                           class_name = class_name, model_dir = model_dir, model_name = 'B6_00p_B', batch_size = 20, GPU_idx = 3)

B6_00p_B_model.Evaluation()
# Out:
# Model: B6_00p_B_2005010439_06420_accr_1.0000_loss_0.000713_val_accr_0.9218_val_loss_0.495169.pt
#
# Accuracy: 91.28 % (701 / 768)
#
# Model: B6_00p_B_2005010439_06430_accr_1.0000_loss_0.000357_val_accr_0.9251_val_loss_0.515808.pt
#
# Accuracy: 90.89 % (698 / 768)
#
# Model: B6_00p_B_2005010439_06440_accr_1.0000_loss_0.000236_val_accr_0.9316_val_loss_0.518386.pt
#
# Accuracy: 90.89 % (698 / 768)
#
# Model: B6_00p_B_2005010439_06510_accr_1.0000_loss_0.000455_val_accr_0.9316_val_loss_0.533475.pt
#
# Accuracy: 91.41 % (702 / 768)
#
# Model: B6_00p_B_2005010514_11830_accr_1.0000_loss_0.001718_val_accr_0.9088_val_loss_0.320229.pt
#
# Accuracy: 87.37 % (671 / 768)
#
# Model: B6_00p_B_2005010515_12440_accr_1.0000_loss_0.001359_val_accr_0.9088_val_loss_0.348866.pt
#
# Accuracy: 88.54 % (680 / 768)
#
# Model: B6_00p_B_2005010515_12460_accr_1.0000_loss_0.000506_val_accr_0.9186_val_loss_0.324762.pt
#
# Accuracy: 87.11 % (669 / 768)
#
# Model: B6_00p_B_2005010515_12570_accr_1.0000_loss_0.000162_val_accr_0.9186_val_loss_0.357604.pt
#
# Accuracy: 85.94 % (660 / 768)
#
# Model: B6_00p_B_2005010516_13640_accr_0.9982_loss_0.004939_val_accr_0.9186_val_loss_0.329401.pt
#
# Accuracy: 87.24 % (670 / 768)
#
# Model: B6_00p_B_2005010517_13650_accr_0.9993_loss_0.002759_val_accr_0.9218_val_loss_0.342342.pt
#
# Accuracy: 88.15 % (677 / 768)
#
# Model: B6_00p_B_2005010517_13660_accr_1.0000_loss_0.000711_val_accr_0.9283_val_loss_0.327192.pt
#
# Accuracy: 88.28 % (678 / 768)
#
# Model: B6_00p_B_2005010604_02290_accr_0.9978_loss_0.006500_val_accr_0.9055_val_loss_0.772192.pt
#
# Accuracy: 88.54 % (680 / 768)
#
# Model: B6_00p_B_2005010611_05250_accr_1.0000_loss_0.000052_val_accr_0.9153_val_loss_1.277981.pt
#
# Accuracy: 89.97 % (691 / 768)
#
# Model: B6_00p_B_2005010611_05260_accr_1.0000_loss_0.000007_val_accr_0.9153_val_loss_1.308288.pt
#
# Accuracy: 90.10 % (692 / 768)
#
# Model: B6_00p_B_2005010613_06200_accr_1.0000_loss_0.000000_val_accr_0.9186_val_loss_1.336733.pt
#
# Accuracy: 89.58 % (688 / 768)
#
# Model: B6_00p_B_2005010614_06680_accr_1.0000_loss_0.000005_val_accr_0.9218_val_loss_1.536705.pt
#
# Accuracy: 91.15 % (700 / 768)
#
# Model: B6_00p_B_2005010626_12500_accr_1.0000_loss_0.000162_val_accr_0.9218_val_loss_1.351998.pt
#
# Accuracy: 91.54 % (703 / 768)
#
# Model: B6_00p_B_2005010626_12540_accr_1.0000_loss_0.000004_val_accr_0.9218_val_loss_1.276075.pt
#
# Accuracy: 91.67 % (704 / 768)
#
# Model: B6_00p_B_2005010626_12550_accr_1.0000_loss_0.000002_val_accr_0.9218_val_loss_1.296998.pt
#
# Accuracy: 91.54 % (703 / 768)
#
# Model: B6_00p_B_2005010626_12560_accr_1.0000_loss_0.000003_val_accr_0.9251_val_loss_1.337638.pt
#
# Accuracy: 91.41 % (702 / 768)
#
# Model: B6_00p_B_2005010626_12570_accr_1.0000_loss_0.000002_val_accr_0.9251_val_loss_1.344183.pt
#
# Accuracy: 91.54 % (703 / 768)
#
# Model: B6_00p_B_2005010626_12580_accr_1.0000_loss_0.000002_val_accr_0.9251_val_loss_1.357337.pt
#
# Accuracy: 91.67 % (704 / 768)
#
# Model: B6_00p_B_2005010716_10180_accr_1.0000_loss_0.000135_val_accr_0.9055_val_loss_0.645415.pt
#
# Accuracy: 91.15 % (700 / 768)
#
# Model: B6_00p_B_2005010717_10510_accr_1.0000_loss_0.000001_val_accr_0.9055_val_loss_0.721574.pt
#
# Accuracy: 91.41 % (702 / 768)
#
# Model: B6_00p_B_2005010717_10520_accr_1.0000_loss_0.000001_val_accr_0.9121_val_loss_0.692011.pt
#
# Accuracy: 91.28 % (701 / 768)
#
# Model: B6_00p_B_2005010722_12870_accr_1.0000_loss_0.000000_val_accr_0.9121_val_loss_0.971915.pt
#
# Accuracy: 91.28 % (701 / 768)

# %%
B6_00p_B_model = SSM_Model(np.expand_dims(B6_test_X[:,1,:,:], axis = 1), B6_test_Y, n_ch = 1, n_cls = 6, 
                           class_name = class_name, model_dir = model_dir, model_name = 'B6_00p_B', batch_size = 20, GPU_idx = 3)

B6_00p_B_model.Evaluation()
B6_00p_B_model.ConfusionMatrix(CM_save_dir, x_angle = 45)
# Out:
# Model: B6_00p_B_2005010439_06510_accr_1.0000_loss_0.000455_val_accr_0.9316_val_loss_0.533475.pt
#
# Accuracy: 91.41 % (702 / 768)

# %%
df = pd.DataFrame(columns = ['Accuracy'])

CMs = [B6_00p_A_model.cm, B6_00p_B_model.cm, B6_00p_AB_model.cm]
model_names = [B6_00p_A_model.model_name, B6_00p_B_model.model_name, B6_00p_AB_model.model_name]

for cm, model_name in zip(CMs, model_names):
    accr = round(np.trace(cm) / np.sum(cm), 4)
    df.loc[model_name] = [accr]

df.to_csv('./results/B6_00p_cls_performance_ONLY_accr.csv',encoding='utf-8-sig', index = True)    
    
df
# Out:
#            Accuracy
# B6_00p_A     0.8555
# B6_00p_B     0.9141
# B6_00p_AB    0.9206

# %%
model_names = [B6_00p_A_model.model_name, B6_00p_B_model.model_name, B6_00p_AB_model.model_name]
metrics = ['Accuracy', 'Precision', 'Recall', 'F1 score']
tuples = [i for i in itertools.product(model_names, metrics)]
col = pd.MultiIndex.from_tuples(tuples)
df = pd.DataFrame(columns = col)

CMs = [B6_00p_A_model.cm, B6_00p_B_model.cm, B6_00p_AB_model.cm]
class_names = ['Heavy Oil', 'Die Punch', 'Scrapped Wire', 'Die Chip', 'Die Internal', 'PIN']
for c_n, cm in zip(np.arange(0, 16, 4), CMs):
    accr = round(np.trace(cm) / np.sum(cm), 4)
    for i, cls_name in zip(range(len(class_names)), class_names):
        precision = round(cm[i, i] / np.sum(cm[:, i]), 4)
        recall = round(cm[i, i] / np.sum(cm[i, :]), 4)
        f1_score = round(2*precision*recall/(precision + recall), 4)
        df.loc[cls_name, c_n:c_n+4] = [accr, precision, recall, f1_score]
        
df.to_csv('./results/B6_00p_cls_performance.csv',encoding='utf-8-sig', index = True)    

df
# Out:
#               B6_00p_A                            B6_00p_B                    \
#               Accuracy Precision  Recall F1 score Accuracy Precision  Recall
# Heavy Oil       0.8555    0.9167  0.7021   0.7952   0.9141     0.878   0.766
# Die Punch       0.8555    0.7613  0.8082    0.784   0.9141     0.863   0.863
# Scrapped Wire   0.8555    0.7386  0.7831   0.7602   0.9141    0.8652  0.9277
# Die Chip        0.8555    0.9667  0.9312   0.9486   0.9141     0.986  0.9725
# Die Internal    0.8555    0.8571  0.7727   0.8127   0.9141    0.8722  0.8788
# PIN             0.8555      0.85  0.9577   0.9006   0.9141    0.9375  0.9507
#
#                        B6_00p_AB
#               F1 score  Accuracy Precision  Recall F1 score
# Heavy Oil       0.8182    0.9206      0.86  0.9149   0.8866
# Die Punch        0.863    0.9206    0.8732  0.8493   0.8611
# Scrapped Wire   0.8954    0.9206    0.8681  0.9518    0.908
# Die Chip        0.9792    0.9206    0.9862  0.9817   0.9839
# Die Internal    0.8755    0.9206     0.875  0.8485   0.8615
# PIN             0.9441    0.9206    0.9643  0.9507   0.9575
