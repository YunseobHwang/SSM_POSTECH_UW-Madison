# %%
import sys
sys.path.append('/mnt/disk1/yunseob/Pytorch/SSM/0_modules')
from SSM_utils import B6dataLoad
from SSM_DL_training import CNN_Training

# %%
data_dir = '/mnt/disk1/yunseob/Pytorch/SSM/1_Semblex/06_no_overlap/SemblexData/wt_4040'

B6_Xs, B6_Ys = B6dataLoad(data_dir, ch = [0, 1], data_type = '3_train_data')

# %%
CT = CNN_Training(B6_Xs, B6_Ys, n_ch = 2, n_cls = 6, lr = 0.1, n_batch_per_cls = 30, n_iter = 15000, model_name = 'B6_00p_AB', GPU_idx = 3)

CT.Run(model_dir = './model/', hist_dir = './results/0_train_hist/npy/')
# Out:
# 0 (185, 2, 40, 40) (185,)
# 0 train: (166, 2, 40, 40) (166,) valid: (19, 2, 40, 40) (19,)
# 1 (579, 2, 40, 40) (579,)
# 1 train: (521, 2, 40, 40) (521,) valid: (58, 2, 40, 40) (58,)
# 2 (329, 2, 40, 40) (329,)
# 2 train: (296, 2, 40, 40) (296,) valid: (33, 2, 40, 40) (33,)
# 3 (865, 2, 40, 40) (865,)
# 3 train: (778, 2, 40, 40) (778,) valid: (87, 2, 40, 40) (87,)
# 4 (528, 2, 40, 40) (528,)
# 4 train: (475, 2, 40, 40) (475,) valid: (53, 2, 40, 40) (53,)
# 5 (564, 2, 40, 40) (564,)
# 5 train: (507, 2, 40, 40) (507,) valid: (57, 2, 40, 40) (57,)
#
# Device: GeForce RTX 2080 Ti
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 40, 40]           1,216
#             Conv2d-2           [-1, 64, 40, 40]          36,928
#        BatchNorm2d-3           [-1, 64, 40, 40]             128
#          MaxPool2d-4           [-1, 64, 20, 20]               0
# ...

# %%
CT = CNN_Training(B6_Xs, B6_Ys, n_ch = 2, n_cls = 6, lr = 0.01, n_batch_per_cls = 10, n_iter = 15000, model_name = 'B6_00p_AB', GPU_idx = 3)

CT.Run(model_dir = './model/', hist_dir = './results/0_train_hist/npy/')
# Out:
# 0 (185, 2, 40, 40) (185,)
# 0 train: (166, 2, 40, 40) (166,) valid: (19, 2, 40, 40) (19,)
# 1 (579, 2, 40, 40) (579,)
# 1 train: (521, 2, 40, 40) (521,) valid: (58, 2, 40, 40) (58,)
# 2 (329, 2, 40, 40) (329,)
# 2 train: (296, 2, 40, 40) (296,) valid: (33, 2, 40, 40) (33,)
# 3 (865, 2, 40, 40) (865,)
# 3 train: (778, 2, 40, 40) (778,) valid: (87, 2, 40, 40) (87,)
# 4 (528, 2, 40, 40) (528,)
# 4 train: (475, 2, 40, 40) (475,) valid: (53, 2, 40, 40) (53,)
# 5 (564, 2, 40, 40) (564,)
# 5 train: (507, 2, 40, 40) (507,) valid: (57, 2, 40, 40) (57,)
#
# Device: GeForce RTX 2080 Ti
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 40, 40]           1,216
#             Conv2d-2           [-1, 64, 40, 40]          36,928
#        BatchNorm2d-3           [-1, 64, 40, 40]             128
#          MaxPool2d-4           [-1, 64, 20, 20]               0
# ...

# %%
CT = CNN_Training(B6_Xs, B6_Ys, n_ch = 2, n_cls = 6, lr = 0.01, n_batch_per_cls = 30, n_iter = 15000, model_name = 'B6_00p_AB', GPU_idx = 3)

CT.Run(model_dir = './model/', hist_dir = './results/0_train_hist/npy/')
# Out:
# 0 (185, 2, 40, 40) (185,)
# 0 train: (166, 2, 40, 40) (166,) valid: (19, 2, 40, 40) (19,)
# 1 (579, 2, 40, 40) (579,)
# 1 train: (521, 2, 40, 40) (521,) valid: (58, 2, 40, 40) (58,)
# 2 (329, 2, 40, 40) (329,)
# 2 train: (296, 2, 40, 40) (296,) valid: (33, 2, 40, 40) (33,)
# 3 (865, 2, 40, 40) (865,)
# 3 train: (778, 2, 40, 40) (778,) valid: (87, 2, 40, 40) (87,)
# 4 (528, 2, 40, 40) (528,)
# 4 train: (475, 2, 40, 40) (475,) valid: (53, 2, 40, 40) (53,)
# 5 (564, 2, 40, 40) (564,)
# 5 train: (507, 2, 40, 40) (507,) valid: (57, 2, 40, 40) (57,)
#
# Device: GeForce RTX 2080 Ti
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 40, 40]           1,216
#             Conv2d-2           [-1, 64, 40, 40]          36,928
#        BatchNorm2d-3           [-1, 64, 40, 40]             128
#          MaxPool2d-4           [-1, 64, 20, 20]               0
# ...

# %%
CT = CNN_Training(B6_Xs, B6_Ys, n_ch = 2, n_cls = 6, lr = 0.001, n_batch_per_cls = 10, n_iter = 15000, model_name = 'B6_00p_AB', GPU_idx = 3)

CT.Run(model_dir = './model/', hist_dir = './results/0_train_hist/npy/')
# Out:
# 0 (185, 2, 40, 40) (185,)
# 0 train: (166, 2, 40, 40) (166,) valid: (19, 2, 40, 40) (19,)
# 1 (579, 2, 40, 40) (579,)
# 1 train: (521, 2, 40, 40) (521,) valid: (58, 2, 40, 40) (58,)
# 2 (329, 2, 40, 40) (329,)
# 2 train: (296, 2, 40, 40) (296,) valid: (33, 2, 40, 40) (33,)
# 3 (865, 2, 40, 40) (865,)
# 3 train: (778, 2, 40, 40) (778,) valid: (87, 2, 40, 40) (87,)
# 4 (528, 2, 40, 40) (528,)
# 4 train: (475, 2, 40, 40) (475,) valid: (53, 2, 40, 40) (53,)
# 5 (564, 2, 40, 40) (564,)
# 5 train: (507, 2, 40, 40) (507,) valid: (57, 2, 40, 40) (57,)
#
# Device: GeForce RTX 2080 Ti
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 40, 40]           1,216
#             Conv2d-2           [-1, 64, 40, 40]          36,928
#        BatchNorm2d-3           [-1, 64, 40, 40]             128
#          MaxPool2d-4           [-1, 64, 20, 20]               0
# ...

# %%
CT = CNN_Training(B6_Xs, B6_Ys, n_ch = 2, n_cls = 6, lr = 0.001, n_batch_per_cls = 30, n_iter = 15000, model_name = 'B6_00p_AB', GPU_idx = 3)

CT.Run(model_dir = './model/', hist_dir = './results/0_train_hist/npy/')
# Out:
# 0 (185, 2, 40, 40) (185,)
# 0 train: (166, 2, 40, 40) (166,) valid: (19, 2, 40, 40) (19,)
# 1 (579, 2, 40, 40) (579,)
# 1 train: (521, 2, 40, 40) (521,) valid: (58, 2, 40, 40) (58,)
# 2 (329, 2, 40, 40) (329,)
# 2 train: (296, 2, 40, 40) (296,) valid: (33, 2, 40, 40) (33,)
# 3 (865, 2, 40, 40) (865,)
# 3 train: (778, 2, 40, 40) (778,) valid: (87, 2, 40, 40) (87,)
# 4 (528, 2, 40, 40) (528,)
# 4 train: (475, 2, 40, 40) (475,) valid: (53, 2, 40, 40) (53,)
# 5 (564, 2, 40, 40) (564,)
# 5 train: (507, 2, 40, 40) (507,) valid: (57, 2, 40, 40) (57,)
#
# Device: GeForce RTX 2080 Ti
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 40, 40]           1,216
#             Conv2d-2           [-1, 64, 40, 40]          36,928
#        BatchNorm2d-3           [-1, 64, 40, 40]             128
#          MaxPool2d-4           [-1, 64, 20, 20]               0
# ...

# %%
CT = CNN_Training(B6_Xs, B6_Ys, n_ch = 2, n_cls = 6, lr = 0.0001, n_batch_per_cls = 10, n_iter = 15000, model_name = 'B6_00p_AB', GPU_idx = 3)

CT.Run(model_dir = './model/', hist_dir = './results/0_train_hist/npy/')
# Out:
# 0 (185, 2, 40, 40) (185,)
# 0 train: (166, 2, 40, 40) (166,) valid: (19, 2, 40, 40) (19,)
# 1 (579, 2, 40, 40) (579,)
# 1 train: (521, 2, 40, 40) (521,) valid: (58, 2, 40, 40) (58,)
# 2 (329, 2, 40, 40) (329,)
# 2 train: (296, 2, 40, 40) (296,) valid: (33, 2, 40, 40) (33,)
# 3 (865, 2, 40, 40) (865,)
# 3 train: (778, 2, 40, 40) (778,) valid: (87, 2, 40, 40) (87,)
# 4 (528, 2, 40, 40) (528,)
# 4 train: (475, 2, 40, 40) (475,) valid: (53, 2, 40, 40) (53,)
# 5 (564, 2, 40, 40) (564,)
# 5 train: (507, 2, 40, 40) (507,) valid: (57, 2, 40, 40) (57,)
#
# Device: GeForce RTX 2080 Ti
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 40, 40]           1,216
#             Conv2d-2           [-1, 64, 40, 40]          36,928
#        BatchNorm2d-3           [-1, 64, 40, 40]             128
#          MaxPool2d-4           [-1, 64, 20, 20]               0
# ...

# %%
CT = CNN_Training(B6_Xs, B6_Ys, n_ch = 2, n_cls = 6, lr = 0.0001, n_batch_per_cls = 30, n_iter = 15000, model_name = 'B6_00p_AB', GPU_idx = 3)

CT.Run(model_dir = './model/', hist_dir = './results/0_train_hist/npy/')
# Out:
# 0 (185, 2, 40, 40) (185,)
# 0 train: (166, 2, 40, 40) (166,) valid: (19, 2, 40, 40) (19,)
# 1 (579, 2, 40, 40) (579,)
# 1 train: (521, 2, 40, 40) (521,) valid: (58, 2, 40, 40) (58,)
# 2 (329, 2, 40, 40) (329,)
# 2 train: (296, 2, 40, 40) (296,) valid: (33, 2, 40, 40) (33,)
# 3 (865, 2, 40, 40) (865,)
# 3 train: (778, 2, 40, 40) (778,) valid: (87, 2, 40, 40) (87,)
# 4 (528, 2, 40, 40) (528,)
# 4 train: (475, 2, 40, 40) (475,) valid: (53, 2, 40, 40) (53,)
# 5 (564, 2, 40, 40) (564,)
# 5 train: (507, 2, 40, 40) (507,) valid: (57, 2, 40, 40) (57,)
#
# Device: GeForce RTX 2080 Ti
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 40, 40]           1,216
#             Conv2d-2           [-1, 64, 40, 40]          36,928
#        BatchNorm2d-3           [-1, 64, 40, 40]             128
#          MaxPool2d-4           [-1, 64, 20, 20]               0
# ...
