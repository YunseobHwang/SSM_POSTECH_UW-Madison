# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import pickle
import gzip

import sys
sys.path.append('/mnt/disk1/yunseob/Pytorch/SSM/0_modules')
from SSM_utils import DataConfig, GBdataLoad, B6dataLoad

# %% [markdown]
# # 1. Save Data

# %%
DataConfig('/mnt/disk1/yunseob/Pytorch/SSM/1_Semblex/08_shorten_length/SemblexData/025s')

# %%
DataConfig('/mnt/disk1/yunseob/Pytorch/SSM/1_Semblex/08_shorten_length/SemblexData/050s')

# %%
DataConfig('/mnt/disk1/yunseob/Pytorch/SSM/1_Semblex/08_shorten_length/SemblexData/075s')

# %%
DataConfig('/mnt/disk1/yunseob/Pytorch/SSM/1_Semblex/08_shorten_length/SemblexData/100s')

# %% [markdown]
# # 2. Load Data

# %%
def LoadDataConfig(data_dir):
    with gzip.open(data_dir + '/SemblexData_config.pickle', 'rb') as f:
        data = pickle.load(f)
        
    for cls, data_bunch in data.items():
        for data_i in data_bunch:
            print("{} - {:02d} - {}".format(cls, data_i['0_index'], data_i['1_file']))
            print("Shape of data = total: {}, training: {}, testing: {}\n".format(data_i['2_data'].shape, 
                                                                                        data_i['3_train_data'].shape, 
                                                                                        data_i['4_test_data'].shape))

# %%
LoadDataConfig('/mnt/disk1/yunseob/Pytorch/SSM/1_Semblex/08_shorten_length/SemblexData/025s')
# Out:
# BAD - 01 - SEMBLEX_200211__BAD_CONDITIONS__HEAVY_OIL__WT_0.25s_1650hz__931_40_40.npy
# Shape of data = total: (931, 40, 40, 2), training: (744, 40, 40, 2), testing: (187, 40, 40, 2)
#
# BAD - 02 - SEMBLEX_200211__BAD_TOOLS__CHIPPED_PUNCH__WT_0.25s_1650hz__499_40_40.npy
# Shape of data = total: (499, 40, 40, 2), training: (399, 40, 40, 2), testing: (100, 40, 40, 2)
#
# BAD - 03 - SEMBLEX_200212__BAD_MATERIAL__SCRAPPED__WT_0.25s_1650hz__770_40_40.npy
# Shape of data = total: (770, 40, 40, 2), training: (616, 40, 40, 2), testing: (154, 40, 40, 2)
#
# BAD - 04 - SEMBLEX_200212__BAD_MATERIAL__SCRAPPED__WT_0.25s_1650hz__882_40_40.npy
# Shape of data = total: (882, 40, 40, 2), training: (705, 40, 40, 2), testing: (177, 40, 40, 2)
#
# BAD - 05 - SEMBLEX_200212__BROKEN_TOOLS__BAD_DIE_CHIP_TOP_2__WT_0.25s_1650hz__2823_40_40.npy
# Shape of data = total: (2823, 40, 40, 2), training: (2258, 40, 40, 2), testing: (565, 40, 40, 2)
#
# BAD - 06 - SEMBLEX_200212__BROKEN_TOOLS__BAD_DIE_CHIP_TOP_3__WT_0.25s_1650hz__248_40_40.npy
# Shape of data = total: (248, 40, 40, 2), training: (198, 40, 40, 2), testing: (50, 40, 40, 2)
#
# BAD - 07 - SEMBLEX_200212__BROKEN_TOOLS__BAD_DIE_CHIP_TOP_SHORT_FEED__WT_0.25s_1650hz__1268_40_40.npy
# Shape of data = total: (1268, 40, 40, 2), training: (1014, 40, 40, 2), testing: (254, 40, 40, 2)
#
# BAD - 08 - SEMBLEX_200212__BROKEN_TOOLS__BAD_DIE_INTERNAL__WT_0.25s_1650hz__1465_40_40.npy
# Shape of data = total: (1465, 40, 40, 2), training: (1172, 40, 40, 2), testing: (293, 40, 40, 2)
#
# BAD - 09 - SEMBLEX_200212__BROKEN_TOOLS__BAD_DIE_INTERNAL__WT_0.25s_1650hz__1184_40_40.npy
# Shape of data = total: (1184, 40, 40, 2), training: (947, 40, 40, 2), testing: (237, 40, 40, 2)
#
# BAD - 10 - SEMBLEX_200212__BROKEN_TOOLS__BAD_PIN__WT_0.25s_1650hz__2191_40_40.npy
# Shape of data = total: (2191, 40, 40, 2), training: (1752, 40, 40, 2), testing: (439, 40, 40, 2)
#
# BAD - 11 - SEMBLEX_200212__BROKEN_TOOLS__BAD_PIN_MACHINE_STOPPED__WT_0.25s_1650hz__638_40_40.npy
# Shape of data = total: (638, 40, 40, 2), training: (510, 40, 40, 2), testing: (128, 40, 40, 2)
#
# BAD - 12 - SEMBLEX_200212__BROKEN_TOOLS__BAD_PUNCH__WT_0.25s_1650hz__2409_40_40.npy
# Shape of data = total: (2409, 40, 40, 2), training: (1927, 40, 40, 2), testing: (482, 40, 40, 2)
#
# GOOD - 01 - SEMBLEX_200211__GOOD_DATA__REGULAR__WT_0.25s_1650hz__1579_40_40.npy
# Shape of data = total: (1579, 40, 40, 2), training: (1263, 40, 40, 2), testing: (316, 40, 40, 2)
#
# GOOD - 02 - SEMBLEX_200211__GOOD_DATA__REGULAR__WT_0.25s_1650hz__2392_40_40.npy
# Shape of data = total: (2392, 40, 40, 2), training: (1913, 40, 40, 2), testing: (479, 40, 40, 2)
#
# GOOD - 03 - SEMBLEX_200211__GOOD_DATA__REGULAR__WT_0.25s_1650hz__2702_40_40.npy
# Shape of data = total: (2702, 40, 40, 2), training: (2161, 40, 40, 2), testing: (541, 40, 40, 2)
#
# GOOD - 04 - SEMBLEX_200211__GOOD_DATA__REGULAR__WT_0.25s_1650hz__3112_40_40.npy
# Shape of data = total: (3112, 40, 40, 2), training: (2489, 40, 40, 2), testing: (623, 40, 40, 2)

# %%
LoadDataConfig('/mnt/disk1/yunseob/Pytorch/SSM/1_Semblex/08_shorten_length/SemblexData/050s')
# Out:
# BAD - 01 - SEMBLEX_200211__BAD_CONDITIONS__HEAVY_OIL__WT_0.5s_1650hz__465_40_40.npy
# Shape of data = total: (465, 40, 40, 2), training: (372, 40, 40, 2), testing: (93, 40, 40, 2)
#
# BAD - 02 - SEMBLEX_200211__BAD_TOOLS__CHIPPED_PUNCH__WT_0.5s_1650hz__249_40_40.npy
# Shape of data = total: (249, 40, 40, 2), training: (199, 40, 40, 2), testing: (50, 40, 40, 2)
#
# BAD - 03 - SEMBLEX_200212__BAD_MATERIAL__SCRAPPED__WT_0.5s_1650hz__384_40_40.npy
# Shape of data = total: (384, 40, 40, 2), training: (307, 40, 40, 2), testing: (77, 40, 40, 2)
#
# BAD - 04 - SEMBLEX_200212__BAD_MATERIAL__SCRAPPED__WT_0.5s_1650hz__440_40_40.npy
# Shape of data = total: (440, 40, 40, 2), training: (352, 40, 40, 2), testing: (88, 40, 40, 2)
#
# BAD - 05 - SEMBLEX_200212__BROKEN_TOOLS__BAD_DIE_CHIP_TOP_2__WT_0.5s_1650hz__1410_40_40.npy
# Shape of data = total: (1410, 40, 40, 2), training: (1128, 40, 40, 2), testing: (282, 40, 40, 2)
#
# BAD - 06 - SEMBLEX_200212__BROKEN_TOOLS__BAD_DIE_CHIP_TOP_3__WT_0.5s_1650hz__124_40_40.npy
# Shape of data = total: (124, 40, 40, 2), training: (99, 40, 40, 2), testing: (25, 40, 40, 2)
#
# BAD - 07 - SEMBLEX_200212__BROKEN_TOOLS__BAD_DIE_CHIP_TOP_SHORT_FEED__WT_0.5s_1650hz__633_40_40.npy
# Shape of data = total: (633, 40, 40, 2), training: (506, 40, 40, 2), testing: (127, 40, 40, 2)
#
# BAD - 08 - SEMBLEX_200212__BROKEN_TOOLS__BAD_DIE_INTERNAL__WT_0.5s_1650hz__731_40_40.npy
# Shape of data = total: (731, 40, 40, 2), training: (584, 40, 40, 2), testing: (147, 40, 40, 2)
#
# BAD - 09 - SEMBLEX_200212__BROKEN_TOOLS__BAD_DIE_INTERNAL__WT_0.5s_1650hz__591_40_40.npy
# Shape of data = total: (591, 40, 40, 2), training: (472, 40, 40, 2), testing: (119, 40, 40, 2)
#
# BAD - 10 - SEMBLEX_200212__BROKEN_TOOLS__BAD_PIN__WT_0.5s_1650hz__1094_40_40.npy
# Shape of data = total: (1094, 40, 40, 2), training: (875, 40, 40, 2), testing: (219, 40, 40, 2)
#
# BAD - 11 - SEMBLEX_200212__BROKEN_TOOLS__BAD_PIN_MACHINE_STOPPED__WT_0.5s_1650hz__318_40_40.npy
# Shape of data = total: (318, 40, 40, 2), training: (254, 40, 40, 2), testing: (64, 40, 40, 2)
#
# BAD - 12 - SEMBLEX_200212__BROKEN_TOOLS__BAD_PUNCH__WT_0.5s_1650hz__1203_40_40.npy
# Shape of data = total: (1203, 40, 40, 2), training: (962, 40, 40, 2), testing: (241, 40, 40, 2)
#
# GOOD - 01 - SEMBLEX_200211__GOOD_DATA__REGULAR__WT_0.5s_1650hz__788_40_40.npy
# Shape of data = total: (788, 40, 40, 2), training: (630, 40, 40, 2), testing: (158, 40, 40, 2)
#
# GOOD - 02 - SEMBLEX_200211__GOOD_DATA__REGULAR__WT_0.5s_1650hz__1194_40_40.npy
# Shape of data = total: (1194, 40, 40, 2), training: (955, 40, 40, 2), testing: (239, 40, 40, 2)
#
# GOOD - 03 - SEMBLEX_200211__GOOD_DATA__REGULAR__WT_0.5s_1650hz__1349_40_40.npy
# Shape of data = total: (1349, 40, 40, 2), training: (1079, 40, 40, 2), testing: (270, 40, 40, 2)
#
# GOOD - 04 - SEMBLEX_200211__GOOD_DATA__REGULAR__WT_0.5s_1650hz__1554_40_40.npy
# Shape of data = total: (1554, 40, 40, 2), training: (1243, 40, 40, 2), testing: (311, 40, 40, 2)

# %%
LoadDataConfig('/mnt/disk1/yunseob/Pytorch/SSM/1_Semblex/08_shorten_length/SemblexData/075s')
# Out:
# BAD - 01 - SEMBLEX_200211__BAD_CONDITIONS__HEAVY_OIL__WT_0.75s_1650hz__310_40_40.npy
# Shape of data = total: (310, 40, 40, 2), training: (248, 40, 40, 2), testing: (62, 40, 40, 2)
#
# BAD - 02 - SEMBLEX_200211__BAD_TOOLS__CHIPPED_PUNCH__WT_0.75s_1650hz__166_40_40.npy
# Shape of data = total: (166, 40, 40, 2), training: (132, 40, 40, 2), testing: (34, 40, 40, 2)
#
# BAD - 03 - SEMBLEX_200212__BAD_MATERIAL__SCRAPPED__WT_0.75s_1650hz__256_40_40.npy
# Shape of data = total: (256, 40, 40, 2), training: (204, 40, 40, 2), testing: (52, 40, 40, 2)
#
# BAD - 04 - SEMBLEX_200212__BAD_MATERIAL__SCRAPPED__WT_0.75s_1650hz__293_40_40.npy
# Shape of data = total: (293, 40, 40, 2), training: (234, 40, 40, 2), testing: (59, 40, 40, 2)
#
# BAD - 05 - SEMBLEX_200212__BROKEN_TOOLS__BAD_DIE_CHIP_TOP_2__WT_0.75s_1650hz__940_40_40.npy
# Shape of data = total: (940, 40, 40, 2), training: (752, 40, 40, 2), testing: (188, 40, 40, 2)
#
# BAD - 06 - SEMBLEX_200212__BROKEN_TOOLS__BAD_DIE_CHIP_TOP_3__WT_0.75s_1650hz__82_40_40.npy
# Shape of data = total: (82, 40, 40, 2), training: (65, 40, 40, 2), testing: (17, 40, 40, 2)
#
# BAD - 07 - SEMBLEX_200212__BROKEN_TOOLS__BAD_DIE_CHIP_TOP_SHORT_FEED__WT_0.75s_1650hz__422_40_40.npy
# Shape of data = total: (422, 40, 40, 2), training: (337, 40, 40, 2), testing: (85, 40, 40, 2)
#
# BAD - 08 - SEMBLEX_200212__BROKEN_TOOLS__BAD_DIE_INTERNAL__WT_0.75s_1650hz__488_40_40.npy
# Shape of data = total: (488, 40, 40, 2), training: (390, 40, 40, 2), testing: (98, 40, 40, 2)
#
# BAD - 09 - SEMBLEX_200212__BROKEN_TOOLS__BAD_DIE_INTERNAL__WT_0.75s_1650hz__394_40_40.npy
# Shape of data = total: (394, 40, 40, 2), training: (315, 40, 40, 2), testing: (79, 40, 40, 2)
#
# BAD - 10 - SEMBLEX_200212__BROKEN_TOOLS__BAD_PIN__WT_0.75s_1650hz__729_40_40.npy
# Shape of data = total: (729, 40, 40, 2), training: (583, 40, 40, 2), testing: (146, 40, 40, 2)
#
# BAD - 11 - SEMBLEX_200212__BROKEN_TOOLS__BAD_PIN_MACHINE_STOPPED__WT_0.75s_1650hz__212_40_40.npy
# Shape of data = total: (212, 40, 40, 2), training: (169, 40, 40, 2), testing: (43, 40, 40, 2)
#
# BAD - 12 - SEMBLEX_200212__BROKEN_TOOLS__BAD_PUNCH__WT_0.75s_1650hz__802_40_40.npy
# Shape of data = total: (802, 40, 40, 2), training: (641, 40, 40, 2), testing: (161, 40, 40, 2)
#
# GOOD - 01 - SEMBLEX_200211__GOOD_DATA__REGULAR__WT_0.75s_1650hz__526_40_40.npy
# Shape of data = total: (526, 40, 40, 2), training: (420, 40, 40, 2), testing: (106, 40, 40, 2)
#
# GOOD - 02 - SEMBLEX_200211__GOOD_DATA__REGULAR__WT_0.75s_1650hz__796_40_40.npy
# Shape of data = total: (796, 40, 40, 2), training: (636, 40, 40, 2), testing: (160, 40, 40, 2)
#
# GOOD - 03 - SEMBLEX_200211__GOOD_DATA__REGULAR__WT_0.75s_1650hz__900_40_40.npy
# Shape of data = total: (900, 40, 40, 2), training: (720, 40, 40, 2), testing: (180, 40, 40, 2)
#
# GOOD - 04 - SEMBLEX_200211__GOOD_DATA__REGULAR__WT_0.75s_1650hz__1036_40_40.npy
# Shape of data = total: (1036, 40, 40, 2), training: (828, 40, 40, 2), testing: (208, 40, 40, 2)

# %%
LoadDataConfig('/mnt/disk1/yunseob/Pytorch/SSM/1_Semblex/08_shorten_length/SemblexData/100s')
# Out:
# BAD - 01 - SEMBLEX_200211__BAD_CONDITIONS__HEAVY_OIL__WT_1.0s_1650hz__232_40_40.npy
# Shape of data = total: (232, 40, 40, 2), training: (185, 40, 40, 2), testing: (47, 40, 40, 2)
#
# BAD - 02 - SEMBLEX_200211__BAD_TOOLS__CHIPPED_PUNCH__WT_1.0s_1650hz__124_40_40.npy
# Shape of data = total: (124, 40, 40, 2), training: (99, 40, 40, 2), testing: (25, 40, 40, 2)
#
# BAD - 03 - SEMBLEX_200212__BAD_MATERIAL__SCRAPPED__WT_1.0s_1650hz__192_40_40.npy
# Shape of data = total: (192, 40, 40, 2), training: (153, 40, 40, 2), testing: (39, 40, 40, 2)
#
# BAD - 04 - SEMBLEX_200212__BAD_MATERIAL__SCRAPPED__WT_1.0s_1650hz__220_40_40.npy
# Shape of data = total: (220, 40, 40, 2), training: (176, 40, 40, 2), testing: (44, 40, 40, 2)
#
# BAD - 05 - SEMBLEX_200212__BROKEN_TOOLS__BAD_DIE_CHIP_TOP_2__WT_1.0s_1650hz__705_40_40.npy
# Shape of data = total: (705, 40, 40, 2), training: (564, 40, 40, 2), testing: (141, 40, 40, 2)
#
# BAD - 06 - SEMBLEX_200212__BROKEN_TOOLS__BAD_DIE_CHIP_TOP_3__WT_1.0s_1650hz__62_40_40.npy
# Shape of data = total: (62, 40, 40, 2), training: (49, 40, 40, 2), testing: (13, 40, 40, 2)
#
# BAD - 07 - SEMBLEX_200212__BROKEN_TOOLS__BAD_DIE_CHIP_TOP_SHORT_FEED__WT_1.0s_1650hz__316_40_40.npy
# Shape of data = total: (316, 40, 40, 2), training: (252, 40, 40, 2), testing: (64, 40, 40, 2)
#
# BAD - 08 - SEMBLEX_200212__BROKEN_TOOLS__BAD_DIE_INTERNAL__WT_1.0s_1650hz__365_40_40.npy
# Shape of data = total: (365, 40, 40, 2), training: (292, 40, 40, 2), testing: (73, 40, 40, 2)
#
# BAD - 09 - SEMBLEX_200212__BROKEN_TOOLS__BAD_DIE_INTERNAL__WT_1.0s_1650hz__295_40_40.npy
# Shape of data = total: (295, 40, 40, 2), training: (236, 40, 40, 2), testing: (59, 40, 40, 2)
#
# BAD - 10 - SEMBLEX_200212__BROKEN_TOOLS__BAD_PIN__WT_1.0s_1650hz__547_40_40.npy
# Shape of data = total: (547, 40, 40, 2), training: (437, 40, 40, 2), testing: (110, 40, 40, 2)
#
# BAD - 11 - SEMBLEX_200212__BROKEN_TOOLS__BAD_PIN_MACHINE_STOPPED__WT_1.0s_1650hz__159_40_40.npy
# Shape of data = total: (159, 40, 40, 2), training: (127, 40, 40, 2), testing: (32, 40, 40, 2)
#
# BAD - 12 - SEMBLEX_200212__BROKEN_TOOLS__BAD_PUNCH__WT_1.0s_1650hz__601_40_40.npy
# Shape of data = total: (601, 40, 40, 2), training: (480, 40, 40, 2), testing: (121, 40, 40, 2)
#
# GOOD - 01 - SEMBLEX_200211__GOOD_DATA__REGULAR__WT_1.0s_1650hz__394_40_40.npy
# Shape of data = total: (394, 40, 40, 2), training: (315, 40, 40, 2), testing: (79, 40, 40, 2)
#
# GOOD - 02 - SEMBLEX_200211__GOOD_DATA__REGULAR__WT_1.0s_1650hz__597_40_40.npy
# Shape of data = total: (597, 40, 40, 2), training: (477, 40, 40, 2), testing: (120, 40, 40, 2)
#
# GOOD - 03 - SEMBLEX_200211__GOOD_DATA__REGULAR__WT_1.0s_1650hz__674_40_40.npy
# Shape of data = total: (674, 40, 40, 2), training: (539, 40, 40, 2), testing: (135, 40, 40, 2)
#
# GOOD - 04 - SEMBLEX_200211__GOOD_DATA__REGULAR__WT_1.0s_1650hz__777_40_40.npy
# Shape of data = total: (777, 40, 40, 2), training: (621, 40, 40, 2), testing: (156, 40, 40, 2)

# %% [markdown]
# # 3. Data plot

# %%
def PlotWTs(test_X, test_Y, class_name, cls_num = 0):

    idx = np.random.choice(np.where(test_Y == cls_num)[0])

    plt.figure(figsize = (10, 5))
    plt.suptitle('idx: {} / label: {}'.format(idx, class_name[int(test_Y[idx])]), y = 0.94)
    plt.subplot(121)
    plt.title('Sensor A (Die side)')
    plt.imshow(test_X[idx, 0, :, :])
    plt.axis('off')
    plt.subplot(122)
    plt.title('Sensor B (Material side)')
    plt.imshow(test_X[idx, 1, :, :])
    plt.axis('off')
    plt.show()

# %% [markdown]
# ## 3.1. 0.25 sec

# %%
data_dir = '/mnt/disk1/yunseob/Pytorch/SSM/1_Semblex/08_shorten_length/SemblexData/025s'

GB_test_X, GB_test_Y = GBdataLoad(data_dir, data_type = '4_test_data')
B6_test_X, B6_test_Y = B6dataLoad(data_dir, data_type = '4_test_data')

# %%
class_name = ['Good', 'Bad']

for i in range(len(class_name)):
    PlotWTs(GB_test_X, GB_test_Y, class_name, cls_num = i)

# %%
class_name = ['Heavy Oil', 'Die Punch', 'Scrapped Wire', 'Die Chip', 'Die Internal', 'PIN']

for i in range(len(class_name)):
    PlotWTs(B6_test_X, B6_test_Y, class_name, cls_num = i)

# %% [markdown]
# ## 3.2. 0.50 sec

# %%
data_dir = '/mnt/disk1/yunseob/Pytorch/SSM/1_Semblex/08_shorten_length/SemblexData/050s'

GB_test_X, GB_test_Y = GBdataLoad(data_dir, data_type = '4_test_data')
B6_test_X, B6_test_Y = B6dataLoad(data_dir, data_type = '4_test_data')

# %%
class_name = ['Good', 'Bad']

for i in range(len(class_name)):
    PlotWTs(GB_test_X, GB_test_Y, class_name, cls_num = i)

# %%
class_name = ['Heavy Oil', 'Die Punch', 'Scrapped Wire', 'Die Chip', 'Die Internal', 'PIN']

for i in range(len(class_name)):
    PlotWTs(B6_test_X, B6_test_Y, class_name, cls_num = i)

# %% [markdown]
# ## 3.3. 0.75 sec

# %%
data_dir = '/mnt/disk1/yunseob/Pytorch/SSM/1_Semblex/08_shorten_length/SemblexData/075s'

GB_test_X, GB_test_Y = GBdataLoad(data_dir, data_type = '4_test_data')
B6_test_X, B6_test_Y = B6dataLoad(data_dir, data_type = '4_test_data')

# %%
class_name = ['Good', 'Bad']

for i in range(len(class_name)):
    PlotWTs(GB_test_X, GB_test_Y, class_name, cls_num = i)

# %%
class_name = ['Heavy Oil', 'Die Punch', 'Scrapped Wire', 'Die Chip', 'Die Internal', 'PIN']

for i in range(len(class_name)):
    PlotWTs(B6_test_X, B6_test_Y, class_name, cls_num = i)

# %% [markdown]
# ## 3.3. 1.00 sec

# %%
data_dir = '/mnt/disk1/yunseob/Pytorch/SSM/1_Semblex/08_shorten_length/SemblexData/100s'

GB_test_X, GB_test_Y = GBdataLoad(data_dir, data_type = '4_test_data')
B6_test_X, B6_test_Y = B6dataLoad(data_dir, data_type = '4_test_data')

# %%
class_name = ['Good', 'Bad']

for i in range(len(class_name)):
    PlotWTs(GB_test_X, GB_test_Y, class_name, cls_num = i)

# %%
class_name = ['Heavy Oil', 'Die Punch', 'Scrapped Wire', 'Die Chip', 'Die Internal', 'PIN']

for i in range(len(class_name)):
    PlotWTs(B6_test_X, B6_test_Y, class_name, cls_num = i)

# %%
data_dir = '/mnt/disk1/yunseob/Pytorch/SSM/1_Semblex/08_shorten_length/SemblexData'

def npy_data(data_dir, segment_length = '100s', condition = 'HEAVY_OIL'):
    npy = [i for i in os.listdir(os.path.join(data_dir, segment_length)) if condition in i][0]
    data = np.load(os.path.join(data_dir, segment_length, npy))
    return data

# %%
HO_025 = npy_data(data_dir, segment_length = '025s')
HO_050 = npy_data(data_dir, segment_length = '050s')  
HO_075 = npy_data(data_dir, segment_length = '075s')
HO_100 = npy_data(data_dir, segment_length = '100s')

# %%
HO_025.shape
# Out:
# (931, 40, 40, 2)

# %%
fig = plt.figure(figsize = (8, 8))
# plt.suptitle('idx: {} / label: {}'.format(idx, class_name[int(test_Y[idx])]), y = 0.94)
# plt.title('Sensor B (Material side)')
plt.imshow(HO_100[0, :, :, 1])
plt.axis('off')
fig.savefig('./HO_100_1.png', bbox_inches='tight')
plt.close(fig)

fig = plt.figure(figsize = (8, 8))
# plt.suptitle('idx: {} / label: {}'.format(idx, class_name[int(test_Y[idx])]), y = 0.94)
# plt.title('Sensor B (Material side)')
plt.imshow(HO_075[0, :, :, 1])
plt.axis('off')
fig.savefig('./HO_075_1.png', bbox_inches='tight')
plt.close(fig)

fig = plt.figure(figsize = (8, 8))
# plt.suptitle('idx: {} / label: {}'.format(idx, class_name[int(test_Y[idx])]), y = 0.94)
# plt.title('Sensor B (Material side)')
plt.imshow(HO_050[0, :, :, 1])
plt.axis('off')
fig.savefig('./HO_050_1.png', bbox_inches='tight')
plt.close(fig)
fig = plt.figure(figsize = (8, 8))
# plt.title('Sensor B (Material side)')
plt.imshow(HO_050[1, :, :, 1])
plt.axis('off')
fig.savefig('./HO_050_2.png', bbox_inches='tight')
plt.close(fig)

fig = plt.figure(figsize = (8, 8))
plt.imshow(HO_025[0, :, :, 1])
plt.axis('off')
fig.savefig('./HO_025_1.png', bbox_inches='tight')
plt.close(fig)
fig = plt.figure(figsize = (8, 8))
plt.imshow(HO_025[1, :, :, 1])
plt.axis('off')
fig.savefig('./HO_025_2.png', bbox_inches='tight')
plt.close(fig)
fig = plt.figure(figsize = (8, 8))
plt.imshow(HO_025[2, :, :, 1])
plt.axis('off')
fig.savefig('./HO_025_3.png', bbox_inches='tight')
plt.close(fig)
fig = plt.figure(figsize = (8, 8))
plt.imshow(HO_025[3, :, :, 1])
plt.axis('off')
fig.savefig('./HO_025_4.png', bbox_inches='tight')
plt.close(fig)

# %%
plt.figure(figsize = (10, 5))
# plt.suptitle('idx: {} / label: {}'.format(idx, class_name[int(test_Y[idx])]), y = 0.94)
plt.subplot(121)
plt.title('Sensor A (Die side)')
plt.imshow(HO_100[0, :, :, 0])
plt.axis('off')
plt.subplot(122)
plt.title('Sensor B (Material side)')
plt.imshow(HO_100[0, :, :, 1])
plt.axis('off')
plt.show()

# %%
plt.figure(figsize = (10, 5))
# plt.suptitle('idx: {} / label: {}'.format(idx, class_name[int(test_Y[idx])]), y = 0.94)
plt.subplot(121)
plt.title('Sensor A (Die side)')
plt.imshow(HO_075[0, :, :, 0])
plt.axis('off')
plt.subplot(122)
plt.title('Sensor B (Material side)')
plt.imshow(HO_075[0, :, :, 1])
plt.axis('off')
plt.show()

# %%
plt.figure(figsize = (10, 5))
# plt.suptitle('idx: {} / label: {}'.format(idx, class_name[int(test_Y[idx])]), y = 0.94)
plt.subplot(121)
plt.title('Sensor A (Die side)')
plt.imshow(HO_050[0, :, :, 0])
plt.axis('off')
plt.subplot(122)
plt.title('Sensor B (Material side)')
plt.imshow(HO_050[0, :, :, 1])
plt.axis('off')
plt.show()

# %%
plt.figure(figsize = (10, 5))
# plt.suptitle('idx: {} / label: {}'.format(idx, class_name[int(test_Y[idx])]), y = 0.94)
plt.subplot(121)
plt.title('Sensor A (Die side)')
plt.imshow(HO_025[0, :, :, 0])
plt.axis('off')
plt.subplot(122)
plt.title('Sensor B (Material side)')
plt.imshow(HO_025[0, :, :, 1])
plt.axis('off')
plt.show()
