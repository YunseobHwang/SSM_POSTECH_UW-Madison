# %%
import sys
sys.path.append('/mnt/disk1/yunseob/Pytorch/SSM/0_modules')
from SSM_utils import B6dataLoad
from SSM_DL_training import CNN_Training

# %%
data_dir = '/mnt/disk1/yunseob/Pytorch/SSM/1_Semblex/05_10p_overlap/SemblexData/wt_4040'

B6_Xs, B6_Ys = B6dataLoad(data_dir, ch = 0, data_type = '3_train_data')

# %%
CT = CNN_Training(B6_Xs, B6_Ys, n_ch = 1, n_cls = 6, lr = 0.01, n_batch_per_cls = 10, n_iter = 15000, model_name = 'B6_10p_A', GPU_idx = 3)

CT.Run(model_dir = './model/', hist_dir = './results/0_train_hist/npy/')
# Out:
# 0 (206, 1, 40, 40) (206,)
# 0 train: (185, 1, 40, 40) (185,) valid: (21, 1, 40, 40) (21,)
# 1 (644, 1, 40, 40) (644,)
# 1 train: (579, 1, 40, 40) (579,) valid: (65, 1, 40, 40) (65,)
# 2 (365, 1, 40, 40) (365,)
# 2 train: (328, 1, 40, 40) (328,) valid: (37, 1, 40, 40) (37,)
# 3 (960, 1, 40, 40) (960,)
# 3 train: (864, 1, 40, 40) (864,) valid: (96, 1, 40, 40) (96,)
# 4 (586, 1, 40, 40) (586,)
# 4 train: (527, 1, 40, 40) (527,) valid: (59, 1, 40, 40) (59,)
# 5 (625, 1, 40, 40) (625,)
# 5 train: (562, 1, 40, 40) (562,) valid: (63, 1, 40, 40) (63,)
#
# Device: GeForce RTX 2080 Ti
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 40, 40]             640
#             Conv2d-2           [-1, 64, 40, 40]          36,928
#        BatchNorm2d-3           [-1, 64, 40, 40]             128
#          MaxPool2d-4           [-1, 64, 20, 20]               0
# ...

# %%
CT = CNN_Training(B6_Xs, B6_Ys, n_ch = 1, n_cls = 6, lr = 0.01, n_batch_per_cls = 30, n_iter = 15000, model_name = 'B6_10p_A', GPU_idx = 3)

CT.Run(model_dir = './model/', hist_dir = './results/0_train_hist/npy/')
# Out:
# 0 (206, 1, 40, 40) (206,)
# 0 train: (185, 1, 40, 40) (185,) valid: (21, 1, 40, 40) (21,)
# 1 (644, 1, 40, 40) (644,)
# 1 train: (579, 1, 40, 40) (579,) valid: (65, 1, 40, 40) (65,)
# 2 (365, 1, 40, 40) (365,)
# 2 train: (328, 1, 40, 40) (328,) valid: (37, 1, 40, 40) (37,)
# 3 (960, 1, 40, 40) (960,)
# 3 train: (864, 1, 40, 40) (864,) valid: (96, 1, 40, 40) (96,)
# 4 (586, 1, 40, 40) (586,)
# 4 train: (527, 1, 40, 40) (527,) valid: (59, 1, 40, 40) (59,)
# 5 (625, 1, 40, 40) (625,)
# 5 train: (562, 1, 40, 40) (562,) valid: (63, 1, 40, 40) (63,)
#
# Device: GeForce RTX 2080 Ti
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 40, 40]             640
#             Conv2d-2           [-1, 64, 40, 40]          36,928
#        BatchNorm2d-3           [-1, 64, 40, 40]             128
#          MaxPool2d-4           [-1, 64, 20, 20]               0
# ...

# %%
CT = CNN_Training(B6_Xs, B6_Ys, n_ch = 1, n_cls = 6, lr = 0.001, n_batch_per_cls = 10, n_iter = 15000, model_name = 'B6_10p_A', GPU_idx = 3)

CT.Run(model_dir = './model/', hist_dir = './results/0_train_hist/npy/')
# Out:
# 0 (206, 1, 40, 40) (206,)
# 0 train: (185, 1, 40, 40) (185,) valid: (21, 1, 40, 40) (21,)
# 1 (644, 1, 40, 40) (644,)
# 1 train: (579, 1, 40, 40) (579,) valid: (65, 1, 40, 40) (65,)
# 2 (365, 1, 40, 40) (365,)
# 2 train: (328, 1, 40, 40) (328,) valid: (37, 1, 40, 40) (37,)
# 3 (960, 1, 40, 40) (960,)
# 3 train: (864, 1, 40, 40) (864,) valid: (96, 1, 40, 40) (96,)
# 4 (586, 1, 40, 40) (586,)
# 4 train: (527, 1, 40, 40) (527,) valid: (59, 1, 40, 40) (59,)
# 5 (625, 1, 40, 40) (625,)
# 5 train: (562, 1, 40, 40) (562,) valid: (63, 1, 40, 40) (63,)
#
# Device: GeForce RTX 2080 Ti
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 40, 40]             640
#             Conv2d-2           [-1, 64, 40, 40]          36,928
#        BatchNorm2d-3           [-1, 64, 40, 40]             128
#          MaxPool2d-4           [-1, 64, 20, 20]               0
# ...

# %%
CT = CNN_Training(B6_Xs, B6_Ys, n_ch = 1, n_cls = 6, lr = 0.001, n_batch_per_cls = 10, n_iter = 15000, model_name = 'B6_10p_A', GPU_idx = 3)

CT.Run(model_dir = './model/', hist_dir = './results/0_train_hist/npy/')
# Out:
# 0 (206, 1, 40, 40) (206,)
# 0 train: (185, 1, 40, 40) (185,) valid: (21, 1, 40, 40) (21,)
# 1 (644, 1, 40, 40) (644,)
# 1 train: (579, 1, 40, 40) (579,) valid: (65, 1, 40, 40) (65,)
# 2 (365, 1, 40, 40) (365,)
# 2 train: (328, 1, 40, 40) (328,) valid: (37, 1, 40, 40) (37,)
# 3 (960, 1, 40, 40) (960,)
# 3 train: (864, 1, 40, 40) (864,) valid: (96, 1, 40, 40) (96,)
# 4 (586, 1, 40, 40) (586,)
# 4 train: (527, 1, 40, 40) (527,) valid: (59, 1, 40, 40) (59,)
# 5 (625, 1, 40, 40) (625,)
# 5 train: (562, 1, 40, 40) (562,) valid: (63, 1, 40, 40) (63,)
#
# Device: GeForce RTX 2080 Ti
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 40, 40]             640
#             Conv2d-2           [-1, 64, 40, 40]          36,928
#        BatchNorm2d-3           [-1, 64, 40, 40]             128
#          MaxPool2d-4           [-1, 64, 20, 20]               0
# ...

# %%
CT = CNN_Training(B6_Xs, B6_Ys, n_ch = 1, n_cls = 6, lr = 0.0001, n_batch_per_cls = 30, n_iter = 5000, model_name = 'B6_10p_A', GPU_idx = 3)

CT.Run(model_dir = './model/', hist_dir = './results/0_train_hist/npy/')
# Out:
# 0 (206, 1, 40, 40) (206,)
# 0 train: (185, 1, 40, 40) (185,) valid: (21, 1, 40, 40) (21,)
# 1 (644, 1, 40, 40) (644,)
# 1 train: (579, 1, 40, 40) (579,) valid: (65, 1, 40, 40) (65,)
# 2 (365, 1, 40, 40) (365,)
# 2 train: (328, 1, 40, 40) (328,) valid: (37, 1, 40, 40) (37,)
# 3 (960, 1, 40, 40) (960,)
# 3 train: (864, 1, 40, 40) (864,) valid: (96, 1, 40, 40) (96,)
# 4 (586, 1, 40, 40) (586,)
# 4 train: (527, 1, 40, 40) (527,) valid: (59, 1, 40, 40) (59,)
# 5 (625, 1, 40, 40) (625,)
# 5 train: (562, 1, 40, 40) (562,) valid: (63, 1, 40, 40) (63,)
#
# Device: GeForce RTX 2080 Ti
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 40, 40]             640
#             Conv2d-2           [-1, 64, 40, 40]          36,928
#        BatchNorm2d-3           [-1, 64, 40, 40]             128
#          MaxPool2d-4           [-1, 64, 20, 20]               0
# ...

# %%
CT = CNN_Training(B6_Xs, B6_Ys, n_ch = 1, n_cls = 6, lr = 0.001, n_batch_per_cls = 5, n_iter = 15000, model_name = 'B6_10p_A', GPU_idx = 3)

CT.Run(model_dir = './model/', hist_dir = './results/0_train_hist/npy/')
# Out:
# 0 (206, 1, 40, 40) (206,)
# 0 train: (185, 1, 40, 40) (185,) valid: (21, 1, 40, 40) (21,)
# 1 (644, 1, 40, 40) (644,)
# 1 train: (579, 1, 40, 40) (579,) valid: (65, 1, 40, 40) (65,)
# 2 (365, 1, 40, 40) (365,)
# 2 train: (328, 1, 40, 40) (328,) valid: (37, 1, 40, 40) (37,)
# 3 (960, 1, 40, 40) (960,)
# 3 train: (864, 1, 40, 40) (864,) valid: (96, 1, 40, 40) (96,)
# 4 (586, 1, 40, 40) (586,)
# 4 train: (527, 1, 40, 40) (527,) valid: (59, 1, 40, 40) (59,)
# 5 (625, 1, 40, 40) (625,)
# 5 train: (562, 1, 40, 40) (562,) valid: (63, 1, 40, 40) (63,)
#
# Device: GeForce RTX 2080 Ti
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 40, 40]             640
#             Conv2d-2           [-1, 64, 40, 40]          36,928
#        BatchNorm2d-3           [-1, 64, 40, 40]             128
#          MaxPool2d-4           [-1, 64, 20, 20]               0
# ...

# %%
CT = CNN_Training(B6_Xs, B6_Ys, n_ch = 1, n_cls = 6, lr = 0.01, n_batch_per_cls = 10, n_iter = 10000, model_name = 'B6_10p_A', GPU_idx = 3)

CT.Run(model_dir = './model/', hist_dir = './results/0_train_hist/npy/')
# Out:
# 0 (206, 1, 40, 40) (206,)
# 0 train: (185, 1, 40, 40) (185,) valid: (21, 1, 40, 40) (21,)
# 1 (644, 1, 40, 40) (644,)
# 1 train: (579, 1, 40, 40) (579,) valid: (65, 1, 40, 40) (65,)
# 2 (365, 1, 40, 40) (365,)
# 2 train: (328, 1, 40, 40) (328,) valid: (37, 1, 40, 40) (37,)
# 3 (960, 1, 40, 40) (960,)
# 3 train: (864, 1, 40, 40) (864,) valid: (96, 1, 40, 40) (96,)
# 4 (586, 1, 40, 40) (586,)
# 4 train: (527, 1, 40, 40) (527,) valid: (59, 1, 40, 40) (59,)
# 5 (625, 1, 40, 40) (625,)
# 5 train: (562, 1, 40, 40) (562,) valid: (63, 1, 40, 40) (63,)
#
# Device: GeForce RTX 2080 Ti
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 40, 40]             640
#             Conv2d-2           [-1, 64, 40, 40]          36,928
#        BatchNorm2d-3           [-1, 64, 40, 40]             128
#          MaxPool2d-4           [-1, 64, 20, 20]               0
# ...

# %%
CT = CNN_Training(B6_Xs, B6_Ys, n_ch = 1, n_cls = 6, lr = 0.001, n_batch_per_cls = 10, n_iter = 10000, model_name = 'B6_10p_A', GPU_idx = 3)

CT.Run(model_dir = './model/', hist_dir = './results/0_train_hist/npy/')
# Out:
# 0 (206, 1, 40, 40) (206,)
# 0 train: (185, 1, 40, 40) (185,) valid: (21, 1, 40, 40) (21,)
# 1 (644, 1, 40, 40) (644,)
# 1 train: (579, 1, 40, 40) (579,) valid: (65, 1, 40, 40) (65,)
# 2 (365, 1, 40, 40) (365,)
# 2 train: (328, 1, 40, 40) (328,) valid: (37, 1, 40, 40) (37,)
# 3 (960, 1, 40, 40) (960,)
# 3 train: (864, 1, 40, 40) (864,) valid: (96, 1, 40, 40) (96,)
# 4 (586, 1, 40, 40) (586,)
# 4 train: (527, 1, 40, 40) (527,) valid: (59, 1, 40, 40) (59,)
# 5 (625, 1, 40, 40) (625,)
# 5 train: (562, 1, 40, 40) (562,) valid: (63, 1, 40, 40) (63,)
#
# Device: GeForce RTX 2080 Ti
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 40, 40]             640
#             Conv2d-2           [-1, 64, 40, 40]          36,928
#        BatchNorm2d-3           [-1, 64, 40, 40]             128
#          MaxPool2d-4           [-1, 64, 20, 20]               0
# ...

# %%
CT = CNN_Training(B6_Xs, B6_Ys, n_ch = 1, n_cls = 6, lr = 0.001, n_batch_per_cls = 10, n_iter = 5000, model_name = 'B6_10p_A', GPU_idx = 3)

CT.Run(model_dir = './model/', hist_dir = './results/0_train_hist/npy/')
# Out:
# 0 (206, 1, 40, 40) (206,)
# 0 train: (185, 1, 40, 40) (185,) valid: (21, 1, 40, 40) (21,)
# 1 (644, 1, 40, 40) (644,)
# 1 train: (579, 1, 40, 40) (579,) valid: (65, 1, 40, 40) (65,)
# 2 (365, 1, 40, 40) (365,)
# 2 train: (328, 1, 40, 40) (328,) valid: (37, 1, 40, 40) (37,)
# 3 (960, 1, 40, 40) (960,)
# 3 train: (864, 1, 40, 40) (864,) valid: (96, 1, 40, 40) (96,)
# 4 (586, 1, 40, 40) (586,)
# 4 train: (527, 1, 40, 40) (527,) valid: (59, 1, 40, 40) (59,)
# 5 (625, 1, 40, 40) (625,)
# 5 train: (562, 1, 40, 40) (562,) valid: (63, 1, 40, 40) (63,)
#
# Device: GeForce RTX 2080 Ti
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 40, 40]             640
#             Conv2d-2           [-1, 64, 40, 40]          36,928
#        BatchNorm2d-3           [-1, 64, 40, 40]             128
#          MaxPool2d-4           [-1, 64, 20, 20]               0
# ...

# %%
CT = CNN_Training(B6_Xs, B6_Ys, n_ch = 1, n_cls = 6, lr = 0.001, n_batch_per_cls = 10, n_iter = 7000, model_name = 'B6_10p_A', GPU_idx = 3)

CT.Run(model_dir = './model/', hist_dir = './results/0_train_hist/npy/')
# Out:
# 0 (206, 1, 40, 40) (206,)
# 0 train: (185, 1, 40, 40) (185,) valid: (21, 1, 40, 40) (21,)
# 1 (644, 1, 40, 40) (644,)
# 1 train: (579, 1, 40, 40) (579,) valid: (65, 1, 40, 40) (65,)
# 2 (365, 1, 40, 40) (365,)
# 2 train: (328, 1, 40, 40) (328,) valid: (37, 1, 40, 40) (37,)
# 3 (960, 1, 40, 40) (960,)
# 3 train: (864, 1, 40, 40) (864,) valid: (96, 1, 40, 40) (96,)
# 4 (586, 1, 40, 40) (586,)
# 4 train: (527, 1, 40, 40) (527,) valid: (59, 1, 40, 40) (59,)
# 5 (625, 1, 40, 40) (625,)
# 5 train: (562, 1, 40, 40) (562,) valid: (63, 1, 40, 40) (63,)
#
# Device: GeForce RTX 2080 Ti
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 40, 40]             640
#             Conv2d-2           [-1, 64, 40, 40]          36,928
#        BatchNorm2d-3           [-1, 64, 40, 40]             128
#          MaxPool2d-4           [-1, 64, 20, 20]               0
# ...
