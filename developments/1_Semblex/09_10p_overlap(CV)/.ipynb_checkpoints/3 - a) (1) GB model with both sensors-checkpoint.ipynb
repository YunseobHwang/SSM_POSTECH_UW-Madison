# %%
import sys
sys.path.append('/mnt/disk1/yunseob/Pytorch/2_SSM/0_modules')
from SSM_utils import GBdataLoad
from SSM_DL_training import CNN_Training

# %%
data_dir = '/mnt/disk1/yunseob/Pytorch/2_SSM/1_Semblex/05_10p_overlap/SemblexData/wt_4040'

GB_Xs, GB_Ys = GBdataLoad(data_dir, ch = [0, 1], data_type = '2_total_data')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-1a69cb932d21> in <module>
#       1 data_dir = '/mnt/disk1/yunseob/Pytorch/2_SSM/1_Semblex/05_10p_overlap/SemblexData/wt_4040'
#       2
# ----> 3 GB_Xs, GB_Ys = GBdataLoad(data_dir, ch = [0, 1], data_type = '2_total_data')
#
# /mnt/disk1/yunseob/Pytorch/2_SSM/0_modules/SSM_utils.py in GBdataLoad(data_dir, ch, data_type)
#      90                 G_X.append(data_i[data_type][:, :, :, ch])
#      91             elif cls == 'BAD':
# ---> 92                 B_X.append(data_i[data_type][:, :, :, ch])
#      93
#      94     G_X, B_X = concat(G_X), concat(B_X)
#
# KeyError: '2_total_data'

# %%
CT = CNN_Training(GB_Xs, GB_Ys, n_ch = 2, n_cls = 2, lr = 0.0001, n_batch_per_cls = 100, n_iter = 10000, model_name = 'GB_10p_AB', GPU_idx = 3)

CT.Run(model_dir = './model/', hist_dir = './results/0_train_hist/npy/')
# Out:
# 0 (2169, 2, 40, 40) (2169,)
# 0 train: (1952, 2, 40, 40) (1952,) valid: (217, 2, 40, 40) (217,)
# 1 (3386, 2, 40, 40) (3386,)
# 1 train: (3047, 2, 40, 40) (3047,) valid: (339, 2, 40, 40) (339,)
#
# Device: GeForce RTX 2080 Ti
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 40, 40]           1,216
#             Conv2d-2           [-1, 64, 40, 40]          36,928
#        BatchNorm2d-3           [-1, 64, 40, 40]             128
#          MaxPool2d-4           [-1, 64, 20, 20]               0
#             Conv2d-5           [-1, 64, 20, 20]          36,928
#             Conv2d-6           [-1, 64, 20, 20]          36,928
#        BatchNorm2d-7           [-1, 64, 20, 20]             128
#          MaxPool2d-8           [-1, 64, 10, 10]               0
#             Conv2d-9           [-1, 64, 10, 10]          36,928
# ...

# %%
CT = CNN_Training(GB_Xs, GB_Ys, n_ch = 2, n_cls = 2, lr = 0.0001, n_batch_per_cls = 30, n_iter = 10000, model_name = 'GB_10p_AB', GPU_idx = 3)

CT.Run(model_dir = './model/', hist_dir = './results/0_train_hist/npy/')
# Out:
# 0 (2169, 2, 40, 40) (2169,)
# 0 train: (1952, 2, 40, 40) (1952,) valid: (217, 2, 40, 40) (217,)
# 1 (3386, 2, 40, 40) (3386,)
# 1 train: (3047, 2, 40, 40) (3047,) valid: (339, 2, 40, 40) (339,)
#
# Device: GeForce RTX 2080 Ti
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 40, 40]           1,216
#             Conv2d-2           [-1, 64, 40, 40]          36,928
#        BatchNorm2d-3           [-1, 64, 40, 40]             128
#          MaxPool2d-4           [-1, 64, 20, 20]               0
#             Conv2d-5           [-1, 64, 20, 20]          36,928
#             Conv2d-6           [-1, 64, 20, 20]          36,928
#        BatchNorm2d-7           [-1, 64, 20, 20]             128
#          MaxPool2d-8           [-1, 64, 10, 10]               0
#             Conv2d-9           [-1, 64, 10, 10]          36,928
# ...

# %%
CT = CNN_Training(GB_Xs, GB_Ys, n_ch = 2, n_cls = 2, lr = 0.001, n_batch_per_cls = 30, n_iter = 5000, model_name = 'GB_10p_AB', GPU_idx = 3)

CT.Run(model_dir = './model/', hist_dir = './results/0_train_hist/npy/')
# Out:
# 0 (2169, 2, 40, 40) (2169,)
# 0 train: (1952, 2, 40, 40) (1952,) valid: (217, 2, 40, 40) (217,)
# 1 (3386, 2, 40, 40) (3386,)
# 1 train: (3047, 2, 40, 40) (3047,) valid: (339, 2, 40, 40) (339,)
#
# Device: GeForce RTX 2080 Ti
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 40, 40]           1,216
#             Conv2d-2           [-1, 64, 40, 40]          36,928
#        BatchNorm2d-3           [-1, 64, 40, 40]             128
#          MaxPool2d-4           [-1, 64, 20, 20]               0
#             Conv2d-5           [-1, 64, 20, 20]          36,928
#             Conv2d-6           [-1, 64, 20, 20]          36,928
#        BatchNorm2d-7           [-1, 64, 20, 20]             128
#          MaxPool2d-8           [-1, 64, 10, 10]               0
#             Conv2d-9           [-1, 64, 10, 10]          36,928
# ...

# %%
CT = CNN_Training(GB_Xs, GB_Ys, n_ch = 2, n_cls = 2, lr = 0.00001, n_batch_per_cls = 100, n_iter = 5000, model_name = 'GB_10p_AB', GPU_idx = 3)

CT.Run(model_dir = './model/', hist_dir = './results/0_train_hist/npy/')
# Out:
# 0 (2169, 2, 40, 40) (2169,)
# 0 train: (1952, 2, 40, 40) (1952,) valid: (217, 2, 40, 40) (217,)
# 1 (3386, 2, 40, 40) (3386,)
# 1 train: (3047, 2, 40, 40) (3047,) valid: (339, 2, 40, 40) (339,)
#
# Device: GeForce RTX 2080 Ti
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 40, 40]           1,216
#             Conv2d-2           [-1, 64, 40, 40]          36,928
#        BatchNorm2d-3           [-1, 64, 40, 40]             128
#          MaxPool2d-4           [-1, 64, 20, 20]               0
#             Conv2d-5           [-1, 64, 20, 20]          36,928
#             Conv2d-6           [-1, 64, 20, 20]          36,928
#        BatchNorm2d-7           [-1, 64, 20, 20]             128
#          MaxPool2d-8           [-1, 64, 10, 10]               0
#             Conv2d-9           [-1, 64, 10, 10]          36,928
# ...
