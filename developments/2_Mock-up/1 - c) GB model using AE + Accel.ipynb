# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import os
import time, datetime

import torch
from torch import nn
from torch.nn import functional as F
from torchsummary import summary

# %%
device = torch.device("cuda:3" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Load Data

# %%
AE_dir = '/mnt/disk2/data/private_data/SSM/2_Mockup/1_AE_Accel_Data/1_Die_Fixture/AE'
Accel_dir = '/mnt/disk2/data/private_data/SSM/2_Mockup/1_AE_Accel_Data/1_Die_Fixture/Acceleration'

def GBdataLoad(data_dir, phase = 'train'):
    for i in os.listdir(data_dir):
        if 'good' in i and phase in i:
            G_train_X = np.load(os.path.join(data_dir, i))
        elif 'bad' in i and phase in i:
            B_train_X = np.load(os.path.join(data_dir, i))
            
    def add_ch(img):
        """
        (sample #, height, width,) -> (sample #, height, width, channel)
        """
        return np.expand_dims(img, axis = -1)

    return add_ch(G_train_X), add_ch(B_train_X)

AE_G_train_X, AE_B_train_X = GBdataLoad(AE_dir)
print('AE data', AE_G_train_X.shape, AE_B_train_X.shape, '\n')

Accel_G_train_X, Accel_B_train_X = GBdataLoad(Accel_dir)
print('Accel data', Accel_G_train_X.shape, Accel_B_train_X.shape, '\n')

G_train_X = np.concatenate((AE_G_train_X, Accel_G_train_X), axis = -1)
B_train_X = np.concatenate((AE_B_train_X, Accel_B_train_X), axis = -1)

print('GOOD:', G_train_X.shape, 'BAD', B_train_X.shape)
# Out:
# AE data (2822, 40, 40, 1) (2510, 40, 40, 1)
#
# Accel data (2822, 40, 40, 1) (2510, 40, 40, 1)
#
# GOOD: (2822, 40, 40, 2) BAD (2510, 40, 40, 2)

# %%
def input_for_Pytorch(img):
    """
    (sample #, height, width, channel) -> (sample #, channel, height, width)
    """
    img = np.transpose(img, (0, 3, 1, 2))
    return img

G_train_X = input_for_Pytorch(G_train_X)
B_train_X = input_for_Pytorch(B_train_X)

G_train_X.shape, B_train_X.shape
# Out:
# ((2822, 2, 40, 40), (2510, 2, 40, 40))

# %%
def CreateLabel(data, cls):
    label = cls*np.ones([data.shape[0]])
    return label

G_train_Y, B_train_Y = CreateLabel(G_train_X, 0), CreateLabel(B_train_X, 1)

G_train_X.shape, G_train_Y.shape, B_train_X.shape, B_train_Y.shape
# Out:
# ((2822, 2, 40, 40), (2822,), (2510, 2, 40, 40), (2510,))

# %%
def train_valid_split(data, label, rate_t_v = 0.9):
    data_num = len(data)
    train_idx = np.random.choice(data_num, int(rate_t_v*data_num), replace = False)
    valid_idx = np.setdiff1d(np.arange(data_num), train_idx)
    return data[train_idx], label[train_idx], data[valid_idx], label[valid_idx]

G_train_X, G_train_Y, G_valid_X, G_valid_Y = train_valid_split(G_train_X, G_train_Y)
B_train_X, B_train_Y, B_valid_X, B_valid_Y = train_valid_split(B_train_X, B_train_Y)

print("Training:", G_train_X.shape, G_train_Y.shape, B_train_X.shape, B_train_Y.shape)
print("Validation:", G_valid_X.shape, G_valid_Y.shape, B_valid_X.shape, B_valid_Y.shape)
# Out:
# Training: (2539, 2, 40, 40) (2539,) (2259, 2, 40, 40) (2259,)
# Validation: (283, 2, 40, 40) (283,) (251, 2, 40, 40) (251,)

# %% [markdown]
# # Model

# %%
class ConvNet(nn.Module):
    def __init__(self):
        super().__init__()
        # RGB세개 1채널, 20개 특징 추출, filter 크기, stride 1
        self.conv1_1 = nn.Conv2d(2, 64, 3, 1, padding=1)
        self.conv1_2 = nn.Conv2d(64, 64, 3, 1, padding=1)
        self.conv1_bn = nn.BatchNorm2d(64)
        
        self.conv2_1 = nn.Conv2d(64, 64, 3, 1, padding=1)
        self.conv2_2 = nn.Conv2d(64, 64, 3, 1, padding=1)
        self.conv2_bn = nn.BatchNorm2d(64)
        
        self.conv3_1 = nn.Conv2d(64, 64, 3, 1, padding=1)
        self.conv3_2 = nn.Conv2d(64, 64, 3, 1, padding=1)
        self.conv3_bn = nn.BatchNorm2d(64)
        
        self.conv4_1 = nn.Conv2d(64, 64, 3, 1, padding=1)
        self.conv4_2 = nn.Conv2d(64, 64, 3, 1, padding=1)
        self.conv4_bn = nn.BatchNorm2d(64)
        
        self.dense1 = nn.Linear(2*2*64, 128)
        # 0.5 가 권장 할 만하대
        self.dropout1 = nn.Dropout(0.5)
        self.dense2 = nn.Linear(128, 2)  
        
    def forward(self, x):
        x = F.relu(self.conv1_1(x))
        x = F.relu(self.conv1_bn(self.conv1_2(x)))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv2_1(x))
        x = F.relu(self.conv2_bn(self.conv2_2(x)))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv3_1(x))
        x = F.relu(self.conv3_bn(self.conv3_2(x)))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv4_1(x))
        x = F.relu(self.conv4_bn(self.conv4_2(x)))
        x = F.max_pool2d(x, 2, 2)
        # flatten
        x = x.view(-1, 2*2*64)
        x = F.relu(self.dense1(x))
        x = self.dropout1(x)
        x = self.dense2(x)
        return x

# %%
model = ConvNet()
# model = model.cuda()
model = model.to(device)
# if device == 'cuda':
#     net = torch.nn.DataParallel(net)
#     cudnn.benchmark = True
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.00001)

summary(model, (2, 40, 40), device = device)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 40, 40]           1,216
#             Conv2d-2           [-1, 64, 40, 40]          36,928
#        BatchNorm2d-3           [-1, 64, 40, 40]             128
#             Conv2d-4           [-1, 64, 20, 20]          36,928
#             Conv2d-5           [-1, 64, 20, 20]          36,928
#        BatchNorm2d-6           [-1, 64, 20, 20]             128
#             Conv2d-7           [-1, 64, 10, 10]          36,928
#             Conv2d-8           [-1, 64, 10, 10]          36,928
#        BatchNorm2d-9           [-1, 64, 10, 10]             128
#            Conv2d-10             [-1, 64, 5, 5]          36,928
#            Conv2d-11             [-1, 64, 5, 5]          36,928
#       BatchNorm2d-12             [-1, 64, 5, 5]             128
#            Linear-13                  [-1, 128]          32,896
#           Dropout-14                  [-1, 128]               0
#            Linear-15                    [-1, 2]             258
#           ConvNet-16                    [-1, 2]               0
# ================================================================
# Total params: 293,378
# Trainable params: 293,378
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 3.11
# Params size (MB): 1.12
# Estimated Total Size (MB): 4.25
# ----------------------------------------------------------------
# (tensor(293378), tensor(293378))

# %% [markdown]
# # Training

# %%
def RandomMinibatch(data, label, n_batch = 100):
    batch_idx = np.random.choice(len(data), n_batch, replace = False)
    return data[batch_idx], label[batch_idx]

G_train_x, G_train_y = RandomMinibatch(G_train_X, G_train_Y, 100)
B_train_x, B_train_y = RandomMinibatch(B_train_X, B_train_Y, 100)

G_valid_x, G_valid_y = RandomMinibatch(G_valid_X, G_valid_Y, 100)
B_valid_x, B_valid_y = RandomMinibatch(B_valid_X, B_valid_Y, 100)

print("Training:", G_train_x.shape, G_train_y.shape, B_train_x.shape, B_train_y.shape)
print("Validation:", G_valid_x.shape, G_valid_y.shape, B_valid_x.shape, B_valid_y.shape)
# Out:
# Training: (100, 2, 40, 40) (100,) (100, 2, 40, 40) (100,)
# Validation: (100, 2, 40, 40) (100,) (100, 2, 40, 40) (100,)

# %%
def shuffle(x, y):
    """
    random shuffle of two paired data -> x, y = shuffle(x, y)
    but, available of one data -> x = shuffle(x, None)
    """
    idx = np.arange(len(x))
    np.random.shuffle(idx)
    if type(x) == type(y):
        return x[idx], y[idx] 
    else:
        return x[idx]
    
G_train_x, G_train_y = RandomMinibatch(G_train_X, G_train_Y, 100)
B_train_x, B_train_y = RandomMinibatch(B_train_X, B_train_Y, 100)
    
train_x, train_y = np.vstack([G_train_x, B_train_x]), np.hstack([G_train_y, B_train_y])
train_x, train_y = shuffle(train_x, train_y)

print("Training", train_x.shape, train_y.shape)
# Out:
# Training (200, 2, 40, 40) (200,)

# %%
loss_history, accr_history = [], []
val_loss_history, val_accr_history = [], []

iter_i = 0

while True:
    iter_i += 1
    
    G_train_x, G_train_y = RandomMinibatch(G_train_X, G_train_Y, 100)
    B_train_x, B_train_y = RandomMinibatch(B_train_X, B_train_Y, 100)
    
    train_x, train_y = np.vstack([G_train_x, B_train_x]), np.hstack([G_train_y, B_train_y])

    train_x, train_y = shuffle(train_x, train_y)
    
#     train_x, train_y = train_x.to(device), train_y.to(device)
    train_x, train_y = torch.tensor(train_x, device=device).float(), torch.tensor(train_y, device=device).long()
    
    output = model(train_x)
    loss = criterion(output, train_y)
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    if iter_i % 10 == 0:
        
        _, pred = torch.max(output, 1)
        
        loss_history.append(loss.tolist())
        accr_history.append((torch.sum(pred == train_y.data).tolist() / len(train_y)))
        
        with torch.no_grad():
    
            G_valid_x, G_valid_y = RandomMinibatch(G_valid_X, G_valid_Y, 100)
            B_valid_x, B_valid_y = RandomMinibatch(B_valid_X, B_valid_Y, 100)

            valid_x, valid_y = np.vstack([G_valid_x, B_valid_x]), np.hstack([G_valid_y, B_valid_y])
#             valid_x, valid_y = valid_x.to(device), valid_y.to(device)
            valid_x, valid_y = torch.tensor(valid_x, device=device).float(), torch.tensor(valid_y, device=device).long()

            valid_output = model(valid_x)
            valid_loss = criterion(valid_output, valid_y)
            
            _, valid_pred = torch.max(valid_output, 1)
        
            val_loss_history.append(valid_loss.tolist())
            val_accr_history.append((torch.sum(valid_pred == valid_y.data).tolist() / len(valid_y)))
        
        
        print("{:05d} | train_loss: {:.5f}, train_accr: {:.3f} | val_loss: {:.5f}, val_accr: {:.3f}".format(iter_i, 
                                                                                                            loss_history[-1], 
                                                                                                            accr_history[-1], 
                                                                                                            val_loss_history[-1], 
                                                                                                            val_accr_history[-1]))
        
        if iter_i >= 100:  
#             if np.mean(val_loss_history[-5 :]) >= np.mean(val_loss_history[-10:]):
#                 print('')
#                 print('Early stopping!!')
#                 print('..val_loss (avg. within 5): {:.5f} >= val_loss (avg. within 10) {:.5f}'.format(np.mean(val_loss_history[-5 :]),
#                                                                                                   np.mean(val_loss_history[-10:])))
                
            if val_loss_history[-1] == np.min(val_loss_history):

                now = datetime.datetime.now()
                nowDatetime = now.strftime('%y%m%d%H%M')
                model_name = 'A2_GB_{}_{:05d}_loss_{:.6f}_val_loss_{:.6f}.pt'.format(nowDatetime, iter_i, 
                                                                                     np.mean(loss_history[-3:]),
                                                                                     np.mean(val_loss_history[-3:]))
                torch.save(model.state_dict(), './model/' + model_name)
#                 break                   
        if iter_i == 5000:
            break
# Out:
# 00010 | train_loss: 0.69461, train_accr: 0.515 | val_loss: 0.69259, val_accr: 0.510
# 00020 | train_loss: 0.64470, train_accr: 0.640 | val_loss: 0.61825, val_accr: 0.680
# 00030 | train_loss: 0.62037, train_accr: 0.670 | val_loss: 0.60607, val_accr: 0.705
# 00040 | train_loss: 0.57900, train_accr: 0.765 | val_loss: 0.56694, val_accr: 0.805
# 00050 | train_loss: 0.50195, train_accr: 0.860 | val_loss: 0.52950, val_accr: 0.805
# 00060 | train_loss: 0.49425, train_accr: 0.835 | val_loss: 0.45328, val_accr: 0.920
# 00070 | train_loss: 0.39977, train_accr: 0.940 | val_loss: 0.41033, val_accr: 0.915
# 00080 | train_loss: 0.39494, train_accr: 0.930 | val_loss: 0.36908, val_accr: 0.935
# 00090 | train_loss: 0.34817, train_accr: 0.935 | val_loss: 0.31837, val_accr: 0.965
# 00100 | train_loss: 0.30624, train_accr: 0.960 | val_loss: 0.29391, val_accr: 0.970
# 00110 | train_loss: 0.27545, train_accr: 0.975 | val_loss: 0.28181, val_accr: 0.965
# 00120 | train_loss: 0.23645, train_accr: 0.955 | val_loss: 0.23645, val_accr: 0.975
# 00130 | train_loss: 0.20720, train_accr: 0.975 | val_loss: 0.21423, val_accr: 0.975
# 00140 | train_loss: 0.17030, train_accr: 0.995 | val_loss: 0.18620, val_accr: 0.985
# 00150 | train_loss: 0.16219, train_accr: 0.985 | val_loss: 0.15274, val_accr: 0.995
# 00160 | train_loss: 0.15947, train_accr: 0.970 | val_loss: 0.15646, val_accr: 0.985
# 00170 | train_loss: 0.12521, train_accr: 0.990 | val_loss: 0.12293, val_accr: 0.995
# 00180 | train_loss: 0.11792, train_accr: 0.985 | val_loss: 0.10804, val_accr: 0.995
# 00190 | train_loss: 0.09698, train_accr: 1.000 | val_loss: 0.12918, val_accr: 0.985
# 00200 | train_loss: 0.10718, train_accr: 0.985 | val_loss: 0.10361, val_accr: 0.990
# 00210 | train_loss: 0.09442, train_accr: 1.000 | val_loss: 0.08492, val_accr: 0.980
# 00220 | train_loss: 0.08816, train_accr: 0.985 | val_loss: 0.07854, val_accr: 0.990
# 00230 | train_loss: 0.06698, train_accr: 1.000 | val_loss: 0.07173, val_accr: 0.995
# 00240 | train_loss: 0.06683, train_accr: 1.000 | val_loss: 0.08046, val_accr: 0.985
# 00250 | train_loss: 0.07488, train_accr: 0.990 | val_loss: 0.06327, val_accr: 0.995
# 00260 | train_loss: 0.06469, train_accr: 0.995 | val_loss: 0.05722, val_accr: 0.995
# 00270 | train_loss: 0.05365, train_accr: 1.000 | val_loss: 0.05180, val_accr: 0.995
# 00280 | train_loss: 0.04949, train_accr: 1.000 | val_loss: 0.04484, val_accr: 1.000
# 00290 | train_loss: 0.04082, train_accr: 1.000 | val_loss: 0.04841, val_accr: 1.000
# 00300 | train_loss: 0.04714, train_accr: 1.000 | val_loss: 0.04851, val_accr: 0.995
# 00310 | train_loss: 0.04622, train_accr: 0.995 | val_loss: 0.04015, val_accr: 0.995
# 00320 | train_loss: 0.04329, train_accr: 0.995 | val_loss: 0.04276, val_accr: 0.995
# 00330 | train_loss: 0.04637, train_accr: 0.995 | val_loss: 0.03752, val_accr: 0.995
# 00340 | train_loss: 0.05675, train_accr: 0.985 | val_loss: 0.03249, val_accr: 1.000
# 00350 | train_loss: 0.03387, train_accr: 1.000 | val_loss: 0.03482, val_accr: 1.000
# 00360 | train_loss: 0.03379, train_accr: 1.000 | val_loss: 0.03002, val_accr: 1.000
# 00370 | train_loss: 0.02454, train_accr: 1.000 | val_loss: 0.03200, val_accr: 1.000
# 00380 | train_loss: 0.03392, train_accr: 1.000 | val_loss: 0.02903, val_accr: 1.000
# 00390 | train_loss: 0.02662, train_accr: 0.995 | val_loss: 0.02265, val_accr: 1.000
# 00400 | train_loss: 0.03481, train_accr: 1.000 | val_loss: 0.03099, val_accr: 0.995
# 00410 | train_loss: 0.02258, train_accr: 1.000 | val_loss: 0.02386, val_accr: 1.000
# 00420 | train_loss: 0.02318, train_accr: 1.000 | val_loss: 0.02307, val_accr: 1.000
# 00430 | train_loss: 0.01976, train_accr: 1.000 | val_loss: 0.01917, val_accr: 1.000
# 00440 | train_loss: 0.02192, train_accr: 1.000 | val_loss: 0.02022, val_accr: 1.000
# 00450 | train_loss: 0.02136, train_accr: 1.000 | val_loss: 0.02284, val_accr: 0.995
# 00460 | train_loss: 0.02369, train_accr: 1.000 | val_loss: 0.02127, val_accr: 0.995
# 00470 | train_loss: 0.02248, train_accr: 1.000 | val_loss: 0.02441, val_accr: 0.995
# 00480 | train_loss: 0.02005, train_accr: 0.995 | val_loss: 0.02127, val_accr: 1.000
# 00490 | train_loss: 0.02742, train_accr: 0.995 | val_loss: 0.02163, val_accr: 0.995
# 00500 | train_loss: 0.01861, train_accr: 1.000 | val_loss: 0.02338, val_accr: 0.995
# 00510 | train_loss: 0.02906, train_accr: 0.990 | val_loss: 0.01181, val_accr: 1.000
# 00520 | train_loss: 0.01749, train_accr: 0.995 | val_loss: 0.01634, val_accr: 1.000
# 00530 | train_loss: 0.01357, train_accr: 1.000 | val_loss: 0.01769, val_accr: 1.000
# 00540 | train_loss: 0.01834, train_accr: 1.000 | val_loss: 0.01233, val_accr: 1.000
# 00550 | train_loss: 0.01582, train_accr: 1.000 | val_loss: 0.01898, val_accr: 0.995
# 00560 | train_loss: 0.02374, train_accr: 0.995 | val_loss: 0.01210, val_accr: 1.000
# 00570 | train_loss: 0.01910, train_accr: 0.995 | val_loss: 0.00925, val_accr: 1.000
# 00580 | train_loss: 0.01681, train_accr: 0.990 | val_loss: 0.01647, val_accr: 1.000
# 00590 | train_loss: 0.01533, train_accr: 0.995 | val_loss: 0.01153, val_accr: 1.000
# 00600 | train_loss: 0.01584, train_accr: 1.000 | val_loss: 0.01091, val_accr: 1.000
# 00610 | train_loss: 0.01536, train_accr: 0.995 | val_loss: 0.01497, val_accr: 0.995
# 00620 | train_loss: 0.01180, train_accr: 1.000 | val_loss: 0.01275, val_accr: 1.000
# 00630 | train_loss: 0.00836, train_accr: 1.000 | val_loss: 0.01053, val_accr: 1.000
# 00640 | train_loss: 0.01116, train_accr: 1.000 | val_loss: 0.01013, val_accr: 1.000
# 00650 | train_loss: 0.01953, train_accr: 1.000 | val_loss: 0.01418, val_accr: 0.995
# 00660 | train_loss: 0.01124, train_accr: 1.000 | val_loss: 0.01464, val_accr: 0.995
# 00670 | train_loss: 0.01287, train_accr: 1.000 | val_loss: 0.00920, val_accr: 1.000
# 00680 | train_loss: 0.00767, train_accr: 1.000 | val_loss: 0.00787, val_accr: 1.000
# 00690 | train_loss: 0.01261, train_accr: 0.995 | val_loss: 0.00814, val_accr: 1.000
# 00700 | train_loss: 0.01355, train_accr: 0.995 | val_loss: 0.00769, val_accr: 1.000
# 00710 | train_loss: 0.01162, train_accr: 1.000 | val_loss: 0.01011, val_accr: 1.000
# 00720 | train_loss: 0.00648, train_accr: 1.000 | val_loss: 0.01307, val_accr: 1.000
# 00730 | train_loss: 0.00826, train_accr: 1.000 | val_loss: 0.00769, val_accr: 1.000
# 00740 | train_loss: 0.00820, train_accr: 1.000 | val_loss: 0.00676, val_accr: 1.000
# 00750 | train_loss: 0.00474, train_accr: 1.000 | val_loss: 0.01035, val_accr: 1.000
# 00760 | train_loss: 0.00642, train_accr: 1.000 | val_loss: 0.01384, val_accr: 0.995
# 00770 | train_loss: 0.01075, train_accr: 1.000 | val_loss: 0.00805, val_accr: 1.000
# 00780 | train_loss: 0.00844, train_accr: 1.000 | val_loss: 0.00692, val_accr: 1.000
# 00790 | train_loss: 0.00813, train_accr: 1.000 | val_loss: 0.00774, val_accr: 1.000
# 00800 | train_loss: 0.00732, train_accr: 1.000 | val_loss: 0.00522, val_accr: 1.000
# 00810 | train_loss: 0.00587, train_accr: 1.000 | val_loss: 0.00994, val_accr: 0.995
# 00820 | train_loss: 0.00578, train_accr: 1.000 | val_loss: 0.01094, val_accr: 0.995
# 00830 | train_loss: 0.00585, train_accr: 1.000 | val_loss: 0.00678, val_accr: 1.000
# 00840 | train_loss: 0.00696, train_accr: 1.000 | val_loss: 0.01063, val_accr: 0.995
# 00850 | train_loss: 0.00607, train_accr: 1.000 | val_loss: 0.01186, val_accr: 0.995
# 00860 | train_loss: 0.00531, train_accr: 1.000 | val_loss: 0.00452, val_accr: 1.000
# 00870 | train_loss: 0.00620, train_accr: 1.000 | val_loss: 0.00860, val_accr: 1.000
# 00880 | train_loss: 0.00647, train_accr: 1.000 | val_loss: 0.00405, val_accr: 1.000
# 00890 | train_loss: 0.00618, train_accr: 1.000 | val_loss: 0.00707, val_accr: 1.000
# 00900 | train_loss: 0.00750, train_accr: 1.000 | val_loss: 0.00473, val_accr: 1.000
# 00910 | train_loss: 0.00702, train_accr: 1.000 | val_loss: 0.00456, val_accr: 1.000
# 00920 | train_loss: 0.00500, train_accr: 1.000 | val_loss: 0.00508, val_accr: 1.000
# 00930 | train_loss: 0.00617, train_accr: 1.000 | val_loss: 0.00870, val_accr: 0.995
# 00940 | train_loss: 0.00402, train_accr: 1.000 | val_loss: 0.00585, val_accr: 1.000
# 00950 | train_loss: 0.00506, train_accr: 1.000 | val_loss: 0.00815, val_accr: 1.000
# 00960 | train_loss: 0.00480, train_accr: 1.000 | val_loss: 0.01343, val_accr: 0.995
# 00970 | train_loss: 0.00576, train_accr: 1.000 | val_loss: 0.00805, val_accr: 0.995
# 00980 | train_loss: 0.00403, train_accr: 1.000 | val_loss: 0.00859, val_accr: 1.000
# 00990 | train_loss: 0.00615, train_accr: 1.000 | val_loss: 0.00474, val_accr: 1.000
# 01000 | train_loss: 0.00498, train_accr: 1.000 | val_loss: 0.00491, val_accr: 1.000
# 01010 | train_loss: 0.00378, train_accr: 1.000 | val_loss: 0.00974, val_accr: 0.995
# 01020 | train_loss: 0.00639, train_accr: 1.000 | val_loss: 0.00431, val_accr: 1.000
# 01030 | train_loss: 0.00411, train_accr: 1.000 | val_loss: 0.00287, val_accr: 1.000
# 01040 | train_loss: 0.00425, train_accr: 1.000 | val_loss: 0.00635, val_accr: 1.000
# 01050 | train_loss: 0.00588, train_accr: 1.000 | val_loss: 0.00322, val_accr: 1.000
# 01060 | train_loss: 0.00533, train_accr: 1.000 | val_loss: 0.00435, val_accr: 1.000
# 01070 | train_loss: 0.00264, train_accr: 1.000 | val_loss: 0.01236, val_accr: 0.995
# 01080 | train_loss: 0.00659, train_accr: 1.000 | val_loss: 0.00595, val_accr: 1.000
# 01090 | train_loss: 0.00342, train_accr: 1.000 | val_loss: 0.00310, val_accr: 1.000
# 01100 | train_loss: 0.00330, train_accr: 1.000 | val_loss: 0.00815, val_accr: 0.995
# 01110 | train_loss: 0.00281, train_accr: 1.000 | val_loss: 0.00689, val_accr: 0.995
# 01120 | train_loss: 0.00288, train_accr: 1.000 | val_loss: 0.00263, val_accr: 1.000
# 01130 | train_loss: 0.00391, train_accr: 1.000 | val_loss: 0.00356, val_accr: 1.000
# 01140 | train_loss: 0.00222, train_accr: 1.000 | val_loss: 0.00339, val_accr: 1.000
# 01150 | train_loss: 0.00323, train_accr: 1.000 | val_loss: 0.00726, val_accr: 0.995
# 01160 | train_loss: 0.00251, train_accr: 1.000 | val_loss: 0.00349, val_accr: 1.000
# 01170 | train_loss: 0.00337, train_accr: 1.000 | val_loss: 0.00449, val_accr: 1.000
# 01180 | train_loss: 0.00477, train_accr: 1.000 | val_loss: 0.00423, val_accr: 1.000
# 01190 | train_loss: 0.00360, train_accr: 1.000 | val_loss: 0.00347, val_accr: 1.000
# 01200 | train_loss: 0.00251, train_accr: 1.000 | val_loss: 0.00891, val_accr: 0.995
# 01210 | train_loss: 0.00265, train_accr: 1.000 | val_loss: 0.00309, val_accr: 1.000
# 01220 | train_loss: 0.00240, train_accr: 1.000 | val_loss: 0.00594, val_accr: 0.995
# 01230 | train_loss: 0.00212, train_accr: 1.000 | val_loss: 0.00250, val_accr: 1.000
# 01240 | train_loss: 0.00318, train_accr: 1.000 | val_loss: 0.00813, val_accr: 0.995
# 01250 | train_loss: 0.00220, train_accr: 1.000 | val_loss: 0.00413, val_accr: 1.000
# 01260 | train_loss: 0.00264, train_accr: 1.000 | val_loss: 0.00323, val_accr: 1.000
# 01270 | train_loss: 0.00279, train_accr: 1.000 | val_loss: 0.00555, val_accr: 1.000
# 01280 | train_loss: 0.00154, train_accr: 1.000 | val_loss: 0.00250, val_accr: 1.000
# 01290 | train_loss: 0.00329, train_accr: 1.000 | val_loss: 0.00214, val_accr: 1.000
# 01300 | train_loss: 0.00212, train_accr: 1.000 | val_loss: 0.00250, val_accr: 1.000
# 01310 | train_loss: 0.00262, train_accr: 1.000 | val_loss: 0.00394, val_accr: 1.000
# 01320 | train_loss: 0.00345, train_accr: 1.000 | val_loss: 0.00594, val_accr: 1.000
# 01330 | train_loss: 0.00274, train_accr: 1.000 | val_loss: 0.00268, val_accr: 1.000
# 01340 | train_loss: 0.00194, train_accr: 1.000 | val_loss: 0.00254, val_accr: 1.000
# 01350 | train_loss: 0.00310, train_accr: 1.000 | val_loss: 0.00248, val_accr: 1.000
# 01360 | train_loss: 0.00274, train_accr: 1.000 | val_loss: 0.00282, val_accr: 1.000
# 01370 | train_loss: 0.00233, train_accr: 1.000 | val_loss: 0.00133, val_accr: 1.000
# 01380 | train_loss: 0.00172, train_accr: 1.000 | val_loss: 0.00154, val_accr: 1.000
# 01390 | train_loss: 0.00257, train_accr: 1.000 | val_loss: 0.00210, val_accr: 1.000
# 01400 | train_loss: 0.00211, train_accr: 1.000 | val_loss: 0.00280, val_accr: 1.000
# 01410 | train_loss: 0.00170, train_accr: 1.000 | val_loss: 0.00180, val_accr: 1.000
# 01420 | train_loss: 0.00251, train_accr: 1.000 | val_loss: 0.00226, val_accr: 1.000
# 01430 | train_loss: 0.00221, train_accr: 1.000 | val_loss: 0.00152, val_accr: 1.000
# 01440 | train_loss: 0.00221, train_accr: 1.000 | val_loss: 0.00216, val_accr: 1.000
# 01450 | train_loss: 0.00169, train_accr: 1.000 | val_loss: 0.00196, val_accr: 1.000
# 01460 | train_loss: 0.00251, train_accr: 1.000 | val_loss: 0.00191, val_accr: 1.000
# 01470 | train_loss: 0.00225, train_accr: 1.000 | val_loss: 0.00258, val_accr: 1.000
# 01480 | train_loss: 0.00185, train_accr: 1.000 | val_loss: 0.00156, val_accr: 1.000
# 01490 | train_loss: 0.00220, train_accr: 1.000 | val_loss: 0.00138, val_accr: 1.000
# 01500 | train_loss: 0.00268, train_accr: 1.000 | val_loss: 0.00381, val_accr: 1.000
# 01510 | train_loss: 0.00154, train_accr: 1.000 | val_loss: 0.00220, val_accr: 1.000
# 01520 | train_loss: 0.00229, train_accr: 1.000 | val_loss: 0.00262, val_accr: 1.000
# 01530 | train_loss: 0.00183, train_accr: 1.000 | val_loss: 0.00132, val_accr: 1.000
# 01540 | train_loss: 0.00163, train_accr: 1.000 | val_loss: 0.00240, val_accr: 1.000
# 01550 | train_loss: 0.00160, train_accr: 1.000 | val_loss: 0.00261, val_accr: 1.000
# 01560 | train_loss: 0.00189, train_accr: 1.000 | val_loss: 0.00198, val_accr: 1.000
# 01570 | train_loss: 0.00199, train_accr: 1.000 | val_loss: 0.00123, val_accr: 1.000
# 01580 | train_loss: 0.00143, train_accr: 1.000 | val_loss: 0.00255, val_accr: 1.000
# 01590 | train_loss: 0.00151, train_accr: 1.000 | val_loss: 0.00412, val_accr: 1.000
# 01600 | train_loss: 0.00124, train_accr: 1.000 | val_loss: 0.00333, val_accr: 1.000
# 01610 | train_loss: 0.00171, train_accr: 1.000 | val_loss: 0.00133, val_accr: 1.000
# 01620 | train_loss: 0.00150, train_accr: 1.000 | val_loss: 0.00102, val_accr: 1.000
# 01630 | train_loss: 0.00170, train_accr: 1.000 | val_loss: 0.00244, val_accr: 1.000
# 01640 | train_loss: 0.00126, train_accr: 1.000 | val_loss: 0.00183, val_accr: 1.000
# 01650 | train_loss: 0.00182, train_accr: 1.000 | val_loss: 0.00161, val_accr: 1.000
# 01660 | train_loss: 0.00102, train_accr: 1.000 | val_loss: 0.00533, val_accr: 0.995
# 01670 | train_loss: 0.00125, train_accr: 1.000 | val_loss: 0.00889, val_accr: 0.995
# 01680 | train_loss: 0.00146, train_accr: 1.000 | val_loss: 0.00370, val_accr: 1.000
# 01690 | train_loss: 0.00097, train_accr: 1.000 | val_loss: 0.00281, val_accr: 1.000
# 01700 | train_loss: 0.00091, train_accr: 1.000 | val_loss: 0.00264, val_accr: 1.000
# 01710 | train_loss: 0.00227, train_accr: 1.000 | val_loss: 0.00165, val_accr: 1.000
# 01720 | train_loss: 0.00116, train_accr: 1.000 | val_loss: 0.00198, val_accr: 1.000
# 01730 | train_loss: 0.00148, train_accr: 1.000 | val_loss: 0.00360, val_accr: 1.000
# 01740 | train_loss: 0.00149, train_accr: 1.000 | val_loss: 0.00341, val_accr: 1.000
# 01750 | train_loss: 0.00143, train_accr: 1.000 | val_loss: 0.00297, val_accr: 1.000
# 01760 | train_loss: 0.00115, train_accr: 1.000 | val_loss: 0.00112, val_accr: 1.000
# 01770 | train_loss: 0.00107, train_accr: 1.000 | val_loss: 0.00107, val_accr: 1.000
# 01780 | train_loss: 0.00201, train_accr: 1.000 | val_loss: 0.00160, val_accr: 1.000
# 01790 | train_loss: 0.00093, train_accr: 1.000 | val_loss: 0.00228, val_accr: 1.000
# 01800 | train_loss: 0.00158, train_accr: 1.000 | val_loss: 0.00138, val_accr: 1.000
# 01810 | train_loss: 0.00114, train_accr: 1.000 | val_loss: 0.00130, val_accr: 1.000
# 01820 | train_loss: 0.00105, train_accr: 1.000 | val_loss: 0.00496, val_accr: 1.000
# 01830 | train_loss: 0.00099, train_accr: 1.000 | val_loss: 0.00134, val_accr: 1.000
# 01840 | train_loss: 0.00109, train_accr: 1.000 | val_loss: 0.00154, val_accr: 1.000
# 01850 | train_loss: 0.00121, train_accr: 1.000 | val_loss: 0.00134, val_accr: 1.000
# 01860 | train_loss: 0.00076, train_accr: 1.000 | val_loss: 0.00130, val_accr: 1.000
# 01870 | train_loss: 0.00129, train_accr: 1.000 | val_loss: 0.00204, val_accr: 1.000
# 01880 | train_loss: 0.00110, train_accr: 1.000 | val_loss: 0.00125, val_accr: 1.000
# 01890 | train_loss: 0.00115, train_accr: 1.000 | val_loss: 0.00109, val_accr: 1.000
# 01900 | train_loss: 0.00081, train_accr: 1.000 | val_loss: 0.00098, val_accr: 1.000
# 01910 | train_loss: 0.00085, train_accr: 1.000 | val_loss: 0.00125, val_accr: 1.000
# 01920 | train_loss: 0.00098, train_accr: 1.000 | val_loss: 0.00095, val_accr: 1.000
# 01930 | train_loss: 0.00117, train_accr: 1.000 | val_loss: 0.00336, val_accr: 1.000
# 01940 | train_loss: 0.00116, train_accr: 1.000 | val_loss: 0.00240, val_accr: 1.000
# 01950 | train_loss: 0.00115, train_accr: 1.000 | val_loss: 0.00323, val_accr: 1.000
# 01960 | train_loss: 0.00110, train_accr: 1.000 | val_loss: 0.00113, val_accr: 1.000
# 01970 | train_loss: 0.00073, train_accr: 1.000 | val_loss: 0.00154, val_accr: 1.000
# 01980 | train_loss: 0.00126, train_accr: 1.000 | val_loss: 0.00282, val_accr: 1.000
# 01990 | train_loss: 0.00111, train_accr: 1.000 | val_loss: 0.00726, val_accr: 0.995
# 02000 | train_loss: 0.00060, train_accr: 1.000 | val_loss: 0.00220, val_accr: 1.000
# 02010 | train_loss: 0.00069, train_accr: 1.000 | val_loss: 0.00108, val_accr: 1.000
# 02020 | train_loss: 0.00070, train_accr: 1.000 | val_loss: 0.00107, val_accr: 1.000
# 02030 | train_loss: 0.00132, train_accr: 1.000 | val_loss: 0.00065, val_accr: 1.000
# 02040 | train_loss: 0.00168, train_accr: 1.000 | val_loss: 0.00372, val_accr: 1.000
# 02050 | train_loss: 0.00081, train_accr: 1.000 | val_loss: 0.00135, val_accr: 1.000
# 02060 | train_loss: 0.00115, train_accr: 1.000 | val_loss: 0.00169, val_accr: 1.000
# 02070 | train_loss: 0.00087, train_accr: 1.000 | val_loss: 0.00140, val_accr: 1.000
# 02080 | train_loss: 0.00054, train_accr: 1.000 | val_loss: 0.00356, val_accr: 1.000
# 02090 | train_loss: 0.00059, train_accr: 1.000 | val_loss: 0.00077, val_accr: 1.000
# 02100 | train_loss: 0.00065, train_accr: 1.000 | val_loss: 0.00233, val_accr: 1.000
# 02110 | train_loss: 0.00071, train_accr: 1.000 | val_loss: 0.00106, val_accr: 1.000
# 02120 | train_loss: 0.00087, train_accr: 1.000 | val_loss: 0.00285, val_accr: 1.000
# 02130 | train_loss: 0.00057, train_accr: 1.000 | val_loss: 0.00144, val_accr: 1.000
# 02140 | train_loss: 0.00106, train_accr: 1.000 | val_loss: 0.00284, val_accr: 1.000
# 02150 | train_loss: 0.00102, train_accr: 1.000 | val_loss: 0.00155, val_accr: 1.000
# 02160 | train_loss: 0.00081, train_accr: 1.000 | val_loss: 0.00075, val_accr: 1.000
# 02170 | train_loss: 0.00072, train_accr: 1.000 | val_loss: 0.00049, val_accr: 1.000
# 02180 | train_loss: 0.00106, train_accr: 1.000 | val_loss: 0.00156, val_accr: 1.000
# 02190 | train_loss: 0.00092, train_accr: 1.000 | val_loss: 0.00102, val_accr: 1.000
# 02200 | train_loss: 0.00053, train_accr: 1.000 | val_loss: 0.00142, val_accr: 1.000
# 02210 | train_loss: 0.00107, train_accr: 1.000 | val_loss: 0.00075, val_accr: 1.000
# 02220 | train_loss: 0.00085, train_accr: 1.000 | val_loss: 0.00206, val_accr: 1.000
# 02230 | train_loss: 0.00090, train_accr: 1.000 | val_loss: 0.00097, val_accr: 1.000
# 02240 | train_loss: 0.00047, train_accr: 1.000 | val_loss: 0.00208, val_accr: 1.000
# 02250 | train_loss: 0.00107, train_accr: 1.000 | val_loss: 0.00139, val_accr: 1.000
# 02260 | train_loss: 0.00050, train_accr: 1.000 | val_loss: 0.00065, val_accr: 1.000
# 02270 | train_loss: 0.00052, train_accr: 1.000 | val_loss: 0.00123, val_accr: 1.000
# 02280 | train_loss: 0.00069, train_accr: 1.000 | val_loss: 0.00110, val_accr: 1.000
# 02290 | train_loss: 0.00089, train_accr: 1.000 | val_loss: 0.00106, val_accr: 1.000
# 02300 | train_loss: 0.00066, train_accr: 1.000 | val_loss: 0.00153, val_accr: 1.000
# 02310 | train_loss: 0.00071, train_accr: 1.000 | val_loss: 0.00058, val_accr: 1.000
# 02320 | train_loss: 0.00068, train_accr: 1.000 | val_loss: 0.00093, val_accr: 1.000
# 02330 | train_loss: 0.00103, train_accr: 1.000 | val_loss: 0.00366, val_accr: 1.000
# 02340 | train_loss: 0.00088, train_accr: 1.000 | val_loss: 0.00229, val_accr: 1.000
# 02350 | train_loss: 0.00054, train_accr: 1.000 | val_loss: 0.00071, val_accr: 1.000
# 02360 | train_loss: 0.00044, train_accr: 1.000 | val_loss: 0.00121, val_accr: 1.000
# 02370 | train_loss: 0.00072, train_accr: 1.000 | val_loss: 0.00103, val_accr: 1.000
# 02380 | train_loss: 0.00052, train_accr: 1.000 | val_loss: 0.00553, val_accr: 0.995
# 02390 | train_loss: 0.00079, train_accr: 1.000 | val_loss: 0.00093, val_accr: 1.000
# 02400 | train_loss: 0.00071, train_accr: 1.000 | val_loss: 0.00087, val_accr: 1.000
# 02410 | train_loss: 0.00055, train_accr: 1.000 | val_loss: 0.00050, val_accr: 1.000
# 02420 | train_loss: 0.00063, train_accr: 1.000 | val_loss: 0.00053, val_accr: 1.000
# 02430 | train_loss: 0.00070, train_accr: 1.000 | val_loss: 0.00090, val_accr: 1.000
# 02440 | train_loss: 0.00083, train_accr: 1.000 | val_loss: 0.00056, val_accr: 1.000
# 02450 | train_loss: 0.00060, train_accr: 1.000 | val_loss: 0.00043, val_accr: 1.000
# 02460 | train_loss: 0.00044, train_accr: 1.000 | val_loss: 0.00123, val_accr: 1.000
# 02470 | train_loss: 0.00053, train_accr: 1.000 | val_loss: 0.00205, val_accr: 1.000
# 02480 | train_loss: 0.00071, train_accr: 1.000 | val_loss: 0.00123, val_accr: 1.000
# 02490 | train_loss: 0.00043, train_accr: 1.000 | val_loss: 0.00087, val_accr: 1.000
# 02500 | train_loss: 0.00078, train_accr: 1.000 | val_loss: 0.00096, val_accr: 1.000
# 02510 | train_loss: 0.00051, train_accr: 1.000 | val_loss: 0.00195, val_accr: 1.000
# 02520 | train_loss: 0.00045, train_accr: 1.000 | val_loss: 0.00207, val_accr: 1.000
# 02530 | train_loss: 0.00039, train_accr: 1.000 | val_loss: 0.00105, val_accr: 1.000
# 02540 | train_loss: 0.00040, train_accr: 1.000 | val_loss: 0.00163, val_accr: 1.000
# 02550 | train_loss: 0.00053, train_accr: 1.000 | val_loss: 0.00046, val_accr: 1.000
# 02560 | train_loss: 0.00051, train_accr: 1.000 | val_loss: 0.00056, val_accr: 1.000
# 02570 | train_loss: 0.00045, train_accr: 1.000 | val_loss: 0.00065, val_accr: 1.000
# 02580 | train_loss: 0.00061, train_accr: 1.000 | val_loss: 0.00051, val_accr: 1.000
# 02590 | train_loss: 0.00045, train_accr: 1.000 | val_loss: 0.00043, val_accr: 1.000
# 02600 | train_loss: 0.00044, train_accr: 1.000 | val_loss: 0.00295, val_accr: 1.000
# 02610 | train_loss: 0.00033, train_accr: 1.000 | val_loss: 0.00311, val_accr: 1.000
# 02620 | train_loss: 0.00051, train_accr: 1.000 | val_loss: 0.00053, val_accr: 1.000
# 02630 | train_loss: 0.00052, train_accr: 1.000 | val_loss: 0.00130, val_accr: 1.000
# 02640 | train_loss: 0.00039, train_accr: 1.000 | val_loss: 0.00087, val_accr: 1.000
# 02650 | train_loss: 0.00043, train_accr: 1.000 | val_loss: 0.00051, val_accr: 1.000
# 02660 | train_loss: 0.00031, train_accr: 1.000 | val_loss: 0.00028, val_accr: 1.000
# 02670 | train_loss: 0.00046, train_accr: 1.000 | val_loss: 0.00049, val_accr: 1.000
# 02680 | train_loss: 0.00054, train_accr: 1.000 | val_loss: 0.00049, val_accr: 1.000
# 02690 | train_loss: 0.00049, train_accr: 1.000 | val_loss: 0.00193, val_accr: 1.000
# 02700 | train_loss: 0.00037, train_accr: 1.000 | val_loss: 0.00093, val_accr: 1.000
# 02710 | train_loss: 0.00062, train_accr: 1.000 | val_loss: 0.00060, val_accr: 1.000
# 02720 | train_loss: 0.00054, train_accr: 1.000 | val_loss: 0.00108, val_accr: 1.000
# 02730 | train_loss: 0.00032, train_accr: 1.000 | val_loss: 0.00069, val_accr: 1.000
# 02740 | train_loss: 0.00036, train_accr: 1.000 | val_loss: 0.00035, val_accr: 1.000
# 02750 | train_loss: 0.00045, train_accr: 1.000 | val_loss: 0.00253, val_accr: 1.000
# 02760 | train_loss: 0.00107, train_accr: 1.000 | val_loss: 0.00074, val_accr: 1.000
# 02770 | train_loss: 0.00041, train_accr: 1.000 | val_loss: 0.00571, val_accr: 0.995
# 02780 | train_loss: 0.00036, train_accr: 1.000 | val_loss: 0.00061, val_accr: 1.000
# 02790 | train_loss: 0.00040, train_accr: 1.000 | val_loss: 0.00195, val_accr: 1.000
# 02800 | train_loss: 0.00070, train_accr: 1.000 | val_loss: 0.00041, val_accr: 1.000
# 02810 | train_loss: 0.00048, train_accr: 1.000 | val_loss: 0.00226, val_accr: 1.000
# 02820 | train_loss: 0.00057, train_accr: 1.000 | val_loss: 0.00321, val_accr: 1.000
# 02830 | train_loss: 0.00039, train_accr: 1.000 | val_loss: 0.00076, val_accr: 1.000
# 02840 | train_loss: 0.00036, train_accr: 1.000 | val_loss: 0.00035, val_accr: 1.000
# 02850 | train_loss: 0.00023, train_accr: 1.000 | val_loss: 0.00064, val_accr: 1.000
# 02860 | train_loss: 0.00035, train_accr: 1.000 | val_loss: 0.00030, val_accr: 1.000
# 02870 | train_loss: 0.00041, train_accr: 1.000 | val_loss: 0.00042, val_accr: 1.000
# 02880 | train_loss: 0.00051, train_accr: 1.000 | val_loss: 0.00033, val_accr: 1.000
# 02890 | train_loss: 0.00036, train_accr: 1.000 | val_loss: 0.00110, val_accr: 1.000
# 02900 | train_loss: 0.00107, train_accr: 1.000 | val_loss: 0.00186, val_accr: 1.000
# 02910 | train_loss: 0.00054, train_accr: 1.000 | val_loss: 0.00027, val_accr: 1.000
# 02920 | train_loss: 0.00036, train_accr: 1.000 | val_loss: 0.00030, val_accr: 1.000
# 02930 | train_loss: 0.00055, train_accr: 1.000 | val_loss: 0.00039, val_accr: 1.000
# 02940 | train_loss: 0.00055, train_accr: 1.000 | val_loss: 0.00298, val_accr: 1.000
# 02950 | train_loss: 0.00036, train_accr: 1.000 | val_loss: 0.00073, val_accr: 1.000
# 02960 | train_loss: 0.00034, train_accr: 1.000 | val_loss: 0.00143, val_accr: 1.000
# 02970 | train_loss: 0.00050, train_accr: 1.000 | val_loss: 0.00037, val_accr: 1.000
# 02980 | train_loss: 0.00045, train_accr: 1.000 | val_loss: 0.00049, val_accr: 1.000
# 02990 | train_loss: 0.00035, train_accr: 1.000 | val_loss: 0.00048, val_accr: 1.000
# 03000 | train_loss: 0.00036, train_accr: 1.000 | val_loss: 0.00051, val_accr: 1.000
# 03010 | train_loss: 0.00024, train_accr: 1.000 | val_loss: 0.00024, val_accr: 1.000
# 03020 | train_loss: 0.00025, train_accr: 1.000 | val_loss: 0.00040, val_accr: 1.000
# 03030 | train_loss: 0.00050, train_accr: 1.000 | val_loss: 0.00030, val_accr: 1.000
# 03040 | train_loss: 0.00033, train_accr: 1.000 | val_loss: 0.00034, val_accr: 1.000
# 03050 | train_loss: 0.00026, train_accr: 1.000 | val_loss: 0.00032, val_accr: 1.000
# 03060 | train_loss: 0.00046, train_accr: 1.000 | val_loss: 0.00032, val_accr: 1.000
# 03070 | train_loss: 0.00032, train_accr: 1.000 | val_loss: 0.00036, val_accr: 1.000
# 03080 | train_loss: 0.00037, train_accr: 1.000 | val_loss: 0.00063, val_accr: 1.000
# 03090 | train_loss: 0.00059, train_accr: 1.000 | val_loss: 0.00038, val_accr: 1.000
# 03100 | train_loss: 0.00026, train_accr: 1.000 | val_loss: 0.00037, val_accr: 1.000
# 03110 | train_loss: 0.00034, train_accr: 1.000 | val_loss: 0.00044, val_accr: 1.000
# 03120 | train_loss: 0.00048, train_accr: 1.000 | val_loss: 0.00032, val_accr: 1.000
# 03130 | train_loss: 0.00038, train_accr: 1.000 | val_loss: 0.00025, val_accr: 1.000
# 03140 | train_loss: 0.00029, train_accr: 1.000 | val_loss: 0.00021, val_accr: 1.000
# 03150 | train_loss: 0.00030, train_accr: 1.000 | val_loss: 0.00085, val_accr: 1.000
# 03160 | train_loss: 0.00026, train_accr: 1.000 | val_loss: 0.00034, val_accr: 1.000
# 03170 | train_loss: 0.00031, train_accr: 1.000 | val_loss: 0.00044, val_accr: 1.000
# 03180 | train_loss: 0.00026, train_accr: 1.000 | val_loss: 0.00032, val_accr: 1.000
# 03190 | train_loss: 0.00029, train_accr: 1.000 | val_loss: 0.00069, val_accr: 1.000
# 03200 | train_loss: 0.00030, train_accr: 1.000 | val_loss: 0.00279, val_accr: 1.000
# 03210 | train_loss: 0.00021, train_accr: 1.000 | val_loss: 0.00048, val_accr: 1.000
# 03220 | train_loss: 0.00048, train_accr: 1.000 | val_loss: 0.00080, val_accr: 1.000
# 03230 | train_loss: 0.00032, train_accr: 1.000 | val_loss: 0.00021, val_accr: 1.000
# 03240 | train_loss: 0.00019, train_accr: 1.000 | val_loss: 0.00194, val_accr: 1.000
# 03250 | train_loss: 0.00078, train_accr: 1.000 | val_loss: 0.00028, val_accr: 1.000
# 03260 | train_loss: 0.00027, train_accr: 1.000 | val_loss: 0.00032, val_accr: 1.000
# 03270 | train_loss: 0.00022, train_accr: 1.000 | val_loss: 0.00052, val_accr: 1.000
# 03280 | train_loss: 0.00027, train_accr: 1.000 | val_loss: 0.00500, val_accr: 0.995
# 03290 | train_loss: 0.00019, train_accr: 1.000 | val_loss: 0.00043, val_accr: 1.000
# 03300 | train_loss: 0.00028, train_accr: 1.000 | val_loss: 0.00040, val_accr: 1.000
# 03310 | train_loss: 0.00019, train_accr: 1.000 | val_loss: 0.00042, val_accr: 1.000
# 03320 | train_loss: 0.00023, train_accr: 1.000 | val_loss: 0.00322, val_accr: 1.000
# 03330 | train_loss: 0.00018, train_accr: 1.000 | val_loss: 0.00051, val_accr: 1.000
# 03340 | train_loss: 0.00023, train_accr: 1.000 | val_loss: 0.00080, val_accr: 1.000
# 03350 | train_loss: 0.00018, train_accr: 1.000 | val_loss: 0.00044, val_accr: 1.000
# 03360 | train_loss: 0.00024, train_accr: 1.000 | val_loss: 0.00019, val_accr: 1.000
# 03370 | train_loss: 0.00021, train_accr: 1.000 | val_loss: 0.00124, val_accr: 1.000
# 03380 | train_loss: 0.00026, train_accr: 1.000 | val_loss: 0.00035, val_accr: 1.000
# 03390 | train_loss: 0.00021, train_accr: 1.000 | val_loss: 0.00030, val_accr: 1.000
# 03400 | train_loss: 0.00031, train_accr: 1.000 | val_loss: 0.00023, val_accr: 1.000
# 03410 | train_loss: 0.00023, train_accr: 1.000 | val_loss: 0.00037, val_accr: 1.000
# 03420 | train_loss: 0.00026, train_accr: 1.000 | val_loss: 0.00024, val_accr: 1.000
# 03430 | train_loss: 0.00034, train_accr: 1.000 | val_loss: 0.00022, val_accr: 1.000
# 03440 | train_loss: 0.00035, train_accr: 1.000 | val_loss: 0.00322, val_accr: 1.000
# 03450 | train_loss: 0.00014, train_accr: 1.000 | val_loss: 0.00016, val_accr: 1.000
# 03460 | train_loss: 0.00020, train_accr: 1.000 | val_loss: 0.00019, val_accr: 1.000
# 03470 | train_loss: 0.00020, train_accr: 1.000 | val_loss: 0.00036, val_accr: 1.000
# 03480 | train_loss: 0.00028, train_accr: 1.000 | val_loss: 0.00027, val_accr: 1.000
# 03490 | train_loss: 0.00020, train_accr: 1.000 | val_loss: 0.00038, val_accr: 1.000
# 03500 | train_loss: 0.00026, train_accr: 1.000 | val_loss: 0.00054, val_accr: 1.000
# 03510 | train_loss: 0.00020, train_accr: 1.000 | val_loss: 0.00017, val_accr: 1.000
# 03520 | train_loss: 0.00017, train_accr: 1.000 | val_loss: 0.00041, val_accr: 1.000
# 03530 | train_loss: 0.00036, train_accr: 1.000 | val_loss: 0.00036, val_accr: 1.000
# 03540 | train_loss: 0.00020, train_accr: 1.000 | val_loss: 0.00149, val_accr: 1.000
# 03550 | train_loss: 0.00027, train_accr: 1.000 | val_loss: 0.00140, val_accr: 1.000
# 03560 | train_loss: 0.00028, train_accr: 1.000 | val_loss: 0.00044, val_accr: 1.000
# 03570 | train_loss: 0.00023, train_accr: 1.000 | val_loss: 0.00017, val_accr: 1.000
# 03580 | train_loss: 0.00021, train_accr: 1.000 | val_loss: 0.00017, val_accr: 1.000
# 03590 | train_loss: 0.00016, train_accr: 1.000 | val_loss: 0.00031, val_accr: 1.000
# 03600 | train_loss: 0.00023, train_accr: 1.000 | val_loss: 0.00014, val_accr: 1.000
# 03610 | train_loss: 0.00034, train_accr: 1.000 | val_loss: 0.00038, val_accr: 1.000
# 03620 | train_loss: 0.00027, train_accr: 1.000 | val_loss: 0.00380, val_accr: 0.995
# 03630 | train_loss: 0.00018, train_accr: 1.000 | val_loss: 0.00114, val_accr: 1.000
# 03640 | train_loss: 0.00044, train_accr: 1.000 | val_loss: 0.00323, val_accr: 1.000
# 03650 | train_loss: 0.00028, train_accr: 1.000 | val_loss: 0.00025, val_accr: 1.000
# 03660 | train_loss: 0.00026, train_accr: 1.000 | val_loss: 0.00103, val_accr: 1.000
# 03670 | train_loss: 0.00020, train_accr: 1.000 | val_loss: 0.00019, val_accr: 1.000
# 03680 | train_loss: 0.00014, train_accr: 1.000 | val_loss: 0.00012, val_accr: 1.000
# 03690 | train_loss: 0.00019, train_accr: 1.000 | val_loss: 0.00021, val_accr: 1.000
# 03700 | train_loss: 0.00014, train_accr: 1.000 | val_loss: 0.00031, val_accr: 1.000
# 03710 | train_loss: 0.00015, train_accr: 1.000 | val_loss: 0.00230, val_accr: 1.000
# 03720 | train_loss: 0.00018, train_accr: 1.000 | val_loss: 0.00029, val_accr: 1.000
# 03730 | train_loss: 0.00023, train_accr: 1.000 | val_loss: 0.00055, val_accr: 1.000
# 03740 | train_loss: 0.00017, train_accr: 1.000 | val_loss: 0.00030, val_accr: 1.000
# 03750 | train_loss: 0.00018, train_accr: 1.000 | val_loss: 0.00025, val_accr: 1.000
# 03760 | train_loss: 0.00019, train_accr: 1.000 | val_loss: 0.00030, val_accr: 1.000
# 03770 | train_loss: 0.00016, train_accr: 1.000 | val_loss: 0.00082, val_accr: 1.000
# 03780 | train_loss: 0.00012, train_accr: 1.000 | val_loss: 0.00023, val_accr: 1.000
# 03790 | train_loss: 0.00014, train_accr: 1.000 | val_loss: 0.00025, val_accr: 1.000
# 03800 | train_loss: 0.00026, train_accr: 1.000 | val_loss: 0.00029, val_accr: 1.000
# 03810 | train_loss: 0.00023, train_accr: 1.000 | val_loss: 0.00010, val_accr: 1.000
# 03820 | train_loss: 0.00024, train_accr: 1.000 | val_loss: 0.00018, val_accr: 1.000
# 03830 | train_loss: 0.00019, train_accr: 1.000 | val_loss: 0.00010, val_accr: 1.000
# 03840 | train_loss: 0.00015, train_accr: 1.000 | val_loss: 0.00019, val_accr: 1.000
# 03850 | train_loss: 0.00019, train_accr: 1.000 | val_loss: 0.00036, val_accr: 1.000
# 03860 | train_loss: 0.00013, train_accr: 1.000 | val_loss: 0.00105, val_accr: 1.000
# 03870 | train_loss: 0.00032, train_accr: 1.000 | val_loss: 0.00111, val_accr: 1.000
# 03880 | train_loss: 0.00020, train_accr: 1.000 | val_loss: 0.00135, val_accr: 1.000
# 03890 | train_loss: 0.00011, train_accr: 1.000 | val_loss: 0.00455, val_accr: 0.995
# 03900 | train_loss: 0.00020, train_accr: 1.000 | val_loss: 0.00022, val_accr: 1.000
# 03910 | train_loss: 0.00015, train_accr: 1.000 | val_loss: 0.00013, val_accr: 1.000
# 03920 | train_loss: 0.00015, train_accr: 1.000 | val_loss: 0.00050, val_accr: 1.000
# 03930 | train_loss: 0.00011, train_accr: 1.000 | val_loss: 0.00010, val_accr: 1.000
# 03940 | train_loss: 0.00017, train_accr: 1.000 | val_loss: 0.00139, val_accr: 1.000
# 03950 | train_loss: 0.00012, train_accr: 1.000 | val_loss: 0.00533, val_accr: 0.995
# 03960 | train_loss: 0.00010, train_accr: 1.000 | val_loss: 0.00019, val_accr: 1.000
# 03970 | train_loss: 0.00017, train_accr: 1.000 | val_loss: 0.00023, val_accr: 1.000
# 03980 | train_loss: 0.00020, train_accr: 1.000 | val_loss: 0.00025, val_accr: 1.000
# 03990 | train_loss: 0.00016, train_accr: 1.000 | val_loss: 0.00163, val_accr: 1.000
# 04000 | train_loss: 0.00015, train_accr: 1.000 | val_loss: 0.00036, val_accr: 1.000
# 04010 | train_loss: 0.00017, train_accr: 1.000 | val_loss: 0.00331, val_accr: 1.000
# 04020 | train_loss: 0.00011, train_accr: 1.000 | val_loss: 0.00066, val_accr: 1.000
# 04030 | train_loss: 0.00030, train_accr: 1.000 | val_loss: 0.00007, val_accr: 1.000
# 04040 | train_loss: 0.00020, train_accr: 1.000 | val_loss: 0.00012, val_accr: 1.000
# 04050 | train_loss: 0.00011, train_accr: 1.000 | val_loss: 0.00017, val_accr: 1.000
# 04060 | train_loss: 0.00012, train_accr: 1.000 | val_loss: 0.00034, val_accr: 1.000
# 04070 | train_loss: 0.00016, train_accr: 1.000 | val_loss: 0.00023, val_accr: 1.000
# 04080 | train_loss: 0.00021, train_accr: 1.000 | val_loss: 0.00269, val_accr: 1.000
# 04090 | train_loss: 0.00011, train_accr: 1.000 | val_loss: 0.00013, val_accr: 1.000
# 04100 | train_loss: 0.00012, train_accr: 1.000 | val_loss: 0.00012, val_accr: 1.000
# 04110 | train_loss: 0.00011, train_accr: 1.000 | val_loss: 0.00049, val_accr: 1.000
# 04120 | train_loss: 0.00014, train_accr: 1.000 | val_loss: 0.00177, val_accr: 1.000
# 04130 | train_loss: 0.00007, train_accr: 1.000 | val_loss: 0.00763, val_accr: 0.995
# 04140 | train_loss: 0.00014, train_accr: 1.000 | val_loss: 0.00231, val_accr: 1.000
# 04150 | train_loss: 0.00027, train_accr: 1.000 | val_loss: 0.00069, val_accr: 1.000
# 04160 | train_loss: 0.00012, train_accr: 1.000 | val_loss: 0.00016, val_accr: 1.000
# 04170 | train_loss: 0.00023, train_accr: 1.000 | val_loss: 0.00020, val_accr: 1.000
# 04180 | train_loss: 0.00021, train_accr: 1.000 | val_loss: 0.00016, val_accr: 1.000
# 04190 | train_loss: 0.00010, train_accr: 1.000 | val_loss: 0.00009, val_accr: 1.000
# 04200 | train_loss: 0.00018, train_accr: 1.000 | val_loss: 0.00251, val_accr: 1.000
# 04210 | train_loss: 0.00015, train_accr: 1.000 | val_loss: 0.00025, val_accr: 1.000
# 04220 | train_loss: 0.00007, train_accr: 1.000 | val_loss: 0.00034, val_accr: 1.000
# 04230 | train_loss: 0.00009, train_accr: 1.000 | val_loss: 0.00051, val_accr: 1.000
# 04240 | train_loss: 0.00009, train_accr: 1.000 | val_loss: 0.00014, val_accr: 1.000
# 04250 | train_loss: 0.00010, train_accr: 1.000 | val_loss: 0.00013, val_accr: 1.000
# 04260 | train_loss: 0.00013, train_accr: 1.000 | val_loss: 0.00019, val_accr: 1.000
# 04270 | train_loss: 0.00009, train_accr: 1.000 | val_loss: 0.00009, val_accr: 1.000
# 04280 | train_loss: 0.00016, train_accr: 1.000 | val_loss: 0.00049, val_accr: 1.000
# 04290 | train_loss: 0.00015, train_accr: 1.000 | val_loss: 0.00014, val_accr: 1.000
# 04300 | train_loss: 0.00009, train_accr: 1.000 | val_loss: 0.00060, val_accr: 1.000
# 04310 | train_loss: 0.00013, train_accr: 1.000 | val_loss: 0.00027, val_accr: 1.000
# 04320 | train_loss: 0.00018, train_accr: 1.000 | val_loss: 0.00009, val_accr: 1.000
# 04330 | train_loss: 0.00021, train_accr: 1.000 | val_loss: 0.00053, val_accr: 1.000
# 04340 | train_loss: 0.00014, train_accr: 1.000 | val_loss: 0.00027, val_accr: 1.000
# 04350 | train_loss: 0.00011, train_accr: 1.000 | val_loss: 0.00085, val_accr: 1.000
# 04360 | train_loss: 0.00010, train_accr: 1.000 | val_loss: 0.00033, val_accr: 1.000
# 04370 | train_loss: 0.00009, train_accr: 1.000 | val_loss: 0.00050, val_accr: 1.000
# 04380 | train_loss: 0.00013, train_accr: 1.000 | val_loss: 0.00012, val_accr: 1.000
# 04390 | train_loss: 0.00018, train_accr: 1.000 | val_loss: 0.00078, val_accr: 1.000
# 04400 | train_loss: 0.00011, train_accr: 1.000 | val_loss: 0.00009, val_accr: 1.000
# 04410 | train_loss: 0.00007, train_accr: 1.000 | val_loss: 0.00158, val_accr: 1.000
# 04420 | train_loss: 0.00033, train_accr: 1.000 | val_loss: 0.00011, val_accr: 1.000
# 04430 | train_loss: 0.00017, train_accr: 1.000 | val_loss: 0.00025, val_accr: 1.000
# 04440 | train_loss: 0.00013, train_accr: 1.000 | val_loss: 0.00011, val_accr: 1.000
# 04450 | train_loss: 0.00007, train_accr: 1.000 | val_loss: 0.00080, val_accr: 1.000
# 04460 | train_loss: 0.00011, train_accr: 1.000 | val_loss: 0.00012, val_accr: 1.000
# 04470 | train_loss: 0.00010, train_accr: 1.000 | val_loss: 0.00010, val_accr: 1.000
# 04480 | train_loss: 0.00018, train_accr: 1.000 | val_loss: 0.00018, val_accr: 1.000
# 04490 | train_loss: 0.00018, train_accr: 1.000 | val_loss: 0.00010, val_accr: 1.000
# 04500 | train_loss: 0.00018, train_accr: 1.000 | val_loss: 0.00022, val_accr: 1.000
# 04510 | train_loss: 0.00013, train_accr: 1.000 | val_loss: 0.00011, val_accr: 1.000
# 04520 | train_loss: 0.00012, train_accr: 1.000 | val_loss: 0.00009, val_accr: 1.000
# 04530 | train_loss: 0.00014, train_accr: 1.000 | val_loss: 0.00009, val_accr: 1.000
# 04540 | train_loss: 0.00012, train_accr: 1.000 | val_loss: 0.00140, val_accr: 1.000
# 04550 | train_loss: 0.00013, train_accr: 1.000 | val_loss: 0.00014, val_accr: 1.000
# 04560 | train_loss: 0.00010, train_accr: 1.000 | val_loss: 0.00013, val_accr: 1.000
# 04570 | train_loss: 0.00006, train_accr: 1.000 | val_loss: 0.00140, val_accr: 1.000
# 04580 | train_loss: 0.00011, train_accr: 1.000 | val_loss: 0.00012, val_accr: 1.000
# 04590 | train_loss: 0.00009, train_accr: 1.000 | val_loss: 0.00009, val_accr: 1.000
# 04600 | train_loss: 0.00010, train_accr: 1.000 | val_loss: 0.00219, val_accr: 1.000
# 04610 | train_loss: 0.00011, train_accr: 1.000 | val_loss: 0.00123, val_accr: 1.000
# 04620 | train_loss: 0.00009, train_accr: 1.000 | val_loss: 0.00016, val_accr: 1.000
# 04630 | train_loss: 0.00008, train_accr: 1.000 | val_loss: 0.00010, val_accr: 1.000
# 04640 | train_loss: 0.00012, train_accr: 1.000 | val_loss: 0.00008, val_accr: 1.000
# 04650 | train_loss: 0.00012, train_accr: 1.000 | val_loss: 0.00135, val_accr: 1.000
# 04660 | train_loss: 0.00012, train_accr: 1.000 | val_loss: 0.00006, val_accr: 1.000
# 04670 | train_loss: 0.00010, train_accr: 1.000 | val_loss: 0.00042, val_accr: 1.000
# 04680 | train_loss: 0.00011, train_accr: 1.000 | val_loss: 0.00015, val_accr: 1.000
# 04690 | train_loss: 0.00016, train_accr: 1.000 | val_loss: 0.00061, val_accr: 1.000
# 04700 | train_loss: 0.00011, train_accr: 1.000 | val_loss: 0.00016, val_accr: 1.000
# 04710 | train_loss: 0.00005, train_accr: 1.000 | val_loss: 0.00007, val_accr: 1.000
# 04720 | train_loss: 0.00012, train_accr: 1.000 | val_loss: 0.00061, val_accr: 1.000
# 04730 | train_loss: 0.00010, train_accr: 1.000 | val_loss: 0.00031, val_accr: 1.000
# 04740 | train_loss: 0.00008, train_accr: 1.000 | val_loss: 0.00042, val_accr: 1.000
# 04750 | train_loss: 0.00007, train_accr: 1.000 | val_loss: 0.00005, val_accr: 1.000
# 04760 | train_loss: 0.00008, train_accr: 1.000 | val_loss: 0.00149, val_accr: 1.000
# 04770 | train_loss: 0.00007, train_accr: 1.000 | val_loss: 0.00049, val_accr: 1.000
# 04780 | train_loss: 0.00007, train_accr: 1.000 | val_loss: 0.00014, val_accr: 1.000
# 04790 | train_loss: 0.00012, train_accr: 1.000 | val_loss: 0.00008, val_accr: 1.000
# 04800 | train_loss: 0.00010, train_accr: 1.000 | val_loss: 0.00395, val_accr: 0.995
# 04810 | train_loss: 0.00007, train_accr: 1.000 | val_loss: 0.00088, val_accr: 1.000
# 04820 | train_loss: 0.00008, train_accr: 1.000 | val_loss: 0.00011, val_accr: 1.000
# 04830 | train_loss: 0.00009, train_accr: 1.000 | val_loss: 0.00016, val_accr: 1.000
# 04840 | train_loss: 0.00008, train_accr: 1.000 | val_loss: 0.00014, val_accr: 1.000
# 04850 | train_loss: 0.00007, train_accr: 1.000 | val_loss: 0.00025, val_accr: 1.000
# 04860 | train_loss: 0.00015, train_accr: 1.000 | val_loss: 0.00030, val_accr: 1.000
# 04870 | train_loss: 0.00007, train_accr: 1.000 | val_loss: 0.00009, val_accr: 1.000
# 04880 | train_loss: 0.00006, train_accr: 1.000 | val_loss: 0.00026, val_accr: 1.000
# 04890 | train_loss: 0.00009, train_accr: 1.000 | val_loss: 0.00504, val_accr: 0.995
# 04900 | train_loss: 0.00019, train_accr: 1.000 | val_loss: 0.00009, val_accr: 1.000
# 04910 | train_loss: 0.00010, train_accr: 1.000 | val_loss: 0.00042, val_accr: 1.000
# 04920 | train_loss: 0.00025, train_accr: 1.000 | val_loss: 0.00016, val_accr: 1.000
# 04930 | train_loss: 0.00008, train_accr: 1.000 | val_loss: 0.00014, val_accr: 1.000
# 04940 | train_loss: 0.00007, train_accr: 1.000 | val_loss: 0.00065, val_accr: 1.000
# 04950 | train_loss: 0.00005, train_accr: 1.000 | val_loss: 0.00006, val_accr: 1.000
# 04960 | train_loss: 0.00007, train_accr: 1.000 | val_loss: 0.00007, val_accr: 1.000
# 04970 | train_loss: 0.00009, train_accr: 1.000 | val_loss: 0.00015, val_accr: 1.000
# 04980 | train_loss: 0.00009, train_accr: 1.000 | val_loss: 0.00012, val_accr: 1.000
# 04990 | train_loss: 0.00006, train_accr: 1.000 | val_loss: 0.00039, val_accr: 1.000
# 05000 | train_loss: 0.00007, train_accr: 1.000 | val_loss: 0.00051, val_accr: 1.000

# %%
fig = plt.figure(figsize = (15,17))
plt.suptitle('Training History', y = 0.92, fontsize = 20)

# x_axis = range(1, 10*len(accr_history)+1, 10)
x_axis = np.arange(10, 10*len(accr_history)+1, 10)

plt.subplot(2, 1, 1)
plt.plot(x_axis, accr_history, 'b-', label = 'Training Accuracy')
plt.plot(x_axis, val_accr_history, 'r-', label = 'Validation Accuracy')
plt.xlabel('Iteration', fontsize = 15)
plt.ylabel('Accuracy', fontsize = 15)
plt.legend(fontsize = 10)
plt.grid('on')
plt.subplot(2, 1, 2)
plt.plot(x_axis, loss_history, 'b-', label = 'Training Loss')
plt.plot(x_axis, val_loss_history, 'r-', label = 'Validation Loss')
plt.xlabel('Iteration', fontsize = 15)
plt.ylabel('Loss', fontsize = 15)
# plt.yticks(np.arange(0, 0.25, step=0.025))
plt.legend(fontsize = 12)
plt.grid('on')
plt.show()

# if save == True:
#     fig.savefig(hist_path + filename)
#     plt.close(fig)
# Out:
# /home/yunseob/Pytorch/lib/python3.5/site-packages/matplotlib/cbook/__init__.py:424: MatplotlibDeprecationWarning:
# Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warn_deprecated("2.2", "Passing one of 'on', 'true', 'off', 'false' as a "

# %%
np.save('./results/0_train_hist/A2_GB_accr_history', accr_history)
np.save('./results/0_train_hist/A2_GB_val_accr_history', val_accr_history)
np.save('./results/0_train_hist/A2_GB_loss_history', loss_history)
np.save('./results/0_train_hist/A2_GB_val_loss_history', val_loss_history)
