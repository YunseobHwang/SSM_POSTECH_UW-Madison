# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import os
import time, datetime

import torch
from torch import nn
from torch.nn import functional as F
from torchsummary import summary

# %%
device = torch.device("cuda:3" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Load Data

# %%
data_dir = '/mnt/disk2/data/private_data/SSM/2_Mockup/1_AE_Accel_Data/3_Loc1_2'

def GBdataLoad2(data_dir, phase = 'train', data = 'AE'):
    for i in os.listdir(data_dir):
        if 'good' in i and phase in i and data in i:
            G_train_X = np.load(os.path.join(data_dir, i))
        elif 'bad' in i and phase in i and data in i:
            B_train_X = np.load(os.path.join(data_dir, i))
            
    def add_ch(img):
        """
        (sample #, height, width,) -> (sample #, height, width, channel)
        """
        return np.expand_dims(img, axis = -1)

    return add_ch(G_train_X), add_ch(B_train_X)

AE_G_train_X, AE_B_train_X = GBdataLoad2(data_dir, phase = 'train', data = 'AE')
print('AE data', AE_G_train_X.shape, AE_B_train_X.shape, '\n')

Accel_G_train_X, Accel_B_train_X = GBdataLoad2(data_dir, phase = 'train', data = 'accel')
print('Accel data', Accel_G_train_X.shape, Accel_B_train_X.shape, '\n')

G_train_X = np.concatenate((AE_G_train_X, Accel_G_train_X), axis = -1)
B_train_X = np.concatenate((AE_B_train_X, Accel_B_train_X), axis = -1)

print('GOOD:', G_train_X.shape, 'BAD', B_train_X.shape)
# Out:
# AE data (1224, 40, 40, 1) (1028, 40, 40, 1)
#
# Accel data (1224, 40, 40, 1) (1028, 40, 40, 1)
#
# GOOD: (1224, 40, 40, 2) BAD (1028, 40, 40, 2)

# %%
def input_for_Pytorch(img):
    """
    (sample #, height, width, channel) -> (sample #, channel, height, width)
    """
    img = np.transpose(img, (0, 3, 1, 2))
    return img

G_train_X = input_for_Pytorch(G_train_X)
B_train_X = input_for_Pytorch(B_train_X)

G_train_X.shape, B_train_X.shape
# Out:
# ((1224, 2, 40, 40), (1028, 2, 40, 40))

# %%
def CreateLabel(data, cls):
    label = cls*np.ones([data.shape[0]])
    return label

G_train_Y, B_train_Y = CreateLabel(G_train_X, 0), CreateLabel(B_train_X, 1)

G_train_X.shape, G_train_Y.shape, B_train_X.shape, B_train_Y.shape
# Out:
# ((1224, 2, 40, 40), (1224,), (1028, 2, 40, 40), (1028,))

# %%
def train_valid_split(data, label, rate_t_v = 0.9):
    data_num = len(data)
    train_idx = np.random.choice(data_num, int(rate_t_v*data_num), replace = False)
    valid_idx = np.setdiff1d(np.arange(data_num), train_idx)
    return data[train_idx], label[train_idx], data[valid_idx], label[valid_idx]

G_train_X, G_train_Y, G_valid_X, G_valid_Y = train_valid_split(G_train_X, G_train_Y)
B_train_X, B_train_Y, B_valid_X, B_valid_Y = train_valid_split(B_train_X, B_train_Y)

print("Training:", G_train_X.shape, G_train_Y.shape, B_train_X.shape, B_train_Y.shape)
print("Validation:", G_valid_X.shape, G_valid_Y.shape, B_valid_X.shape, B_valid_Y.shape)
# Out:
# Training: (1101, 2, 40, 40) (1101,) (925, 2, 40, 40) (925,)
# Validation: (123, 2, 40, 40) (123,) (103, 2, 40, 40) (103,)

# %% [markdown]
# # Model

# %%
class ConvNet(nn.Module):
    def __init__(self):
        super().__init__()
        # RGB세개 1채널, 20개 특징 추출, filter 크기, stride 1
        self.conv1_1 = nn.Conv2d(2, 64, 3, 1, padding=1)
        self.conv1_2 = nn.Conv2d(64, 64, 3, 1, padding=1)
        self.conv1_bn = nn.BatchNorm2d(64)
        
        self.conv2_1 = nn.Conv2d(64, 64, 3, 1, padding=1)
        self.conv2_2 = nn.Conv2d(64, 64, 3, 1, padding=1)
        self.conv2_bn = nn.BatchNorm2d(64)
        
        self.conv3_1 = nn.Conv2d(64, 64, 3, 1, padding=1)
        self.conv3_2 = nn.Conv2d(64, 64, 3, 1, padding=1)
        self.conv3_bn = nn.BatchNorm2d(64)
        
        self.conv4_1 = nn.Conv2d(64, 64, 3, 1, padding=1)
        self.conv4_2 = nn.Conv2d(64, 64, 3, 1, padding=1)
        self.conv4_bn = nn.BatchNorm2d(64)
        
        self.dense1 = nn.Linear(2*2*64, 128)
        # 0.5 가 권장 할 만하대
        self.dropout1 = nn.Dropout(0.5)
        self.dense2 = nn.Linear(128, 2)  
        
    def forward(self, x):
        x = F.relu(self.conv1_1(x))
        x = F.relu(self.conv1_bn(self.conv1_2(x)))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv2_1(x))
        x = F.relu(self.conv2_bn(self.conv2_2(x)))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv3_1(x))
        x = F.relu(self.conv3_bn(self.conv3_2(x)))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv4_1(x))
        x = F.relu(self.conv4_bn(self.conv4_2(x)))
        x = F.max_pool2d(x, 2, 2)
        # flatten
        x = x.view(-1, 2*2*64)
        x = F.relu(self.dense1(x))
        x = self.dropout1(x)
        x = self.dense2(x)
        return x

# %%
model = ConvNet()
# model = model.cuda()
model = model.to(device)
# if device == 'cuda':
#     net = torch.nn.DataParallel(net)
#     cudnn.benchmark = True
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.00001)

summary(model, (2, 40, 40), device = device)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 40, 40]           1,216
#             Conv2d-2           [-1, 64, 40, 40]          36,928
#        BatchNorm2d-3           [-1, 64, 40, 40]             128
#             Conv2d-4           [-1, 64, 20, 20]          36,928
#             Conv2d-5           [-1, 64, 20, 20]          36,928
#        BatchNorm2d-6           [-1, 64, 20, 20]             128
#             Conv2d-7           [-1, 64, 10, 10]          36,928
#             Conv2d-8           [-1, 64, 10, 10]          36,928
#        BatchNorm2d-9           [-1, 64, 10, 10]             128
#            Conv2d-10             [-1, 64, 5, 5]          36,928
#            Conv2d-11             [-1, 64, 5, 5]          36,928
#       BatchNorm2d-12             [-1, 64, 5, 5]             128
#            Linear-13                  [-1, 128]          32,896
#           Dropout-14                  [-1, 128]               0
#            Linear-15                    [-1, 2]             258
#           ConvNet-16                    [-1, 2]               0
# ================================================================
# Total params: 293,378
# Trainable params: 293,378
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 3.11
# Params size (MB): 1.12
# Estimated Total Size (MB): 4.25
# ----------------------------------------------------------------
# (tensor(293378), tensor(293378))

# %% [markdown]
# # Training

# %%
def RandomMinibatch(data, label, n_batch = 100):
    batch_idx = np.random.choice(len(data), n_batch, replace = False)
    return data[batch_idx], label[batch_idx]

G_train_x, G_train_y = RandomMinibatch(G_train_X, G_train_Y, 100)
B_train_x, B_train_y = RandomMinibatch(B_train_X, B_train_Y, 100)

G_valid_x, G_valid_y = RandomMinibatch(G_valid_X, G_valid_Y, 100)
B_valid_x, B_valid_y = RandomMinibatch(B_valid_X, B_valid_Y, 100)

print("Training:", G_train_x.shape, G_train_y.shape, B_train_x.shape, B_train_y.shape)
print("Validation:", G_valid_x.shape, G_valid_y.shape, B_valid_x.shape, B_valid_y.shape)
# Out:
# Training: (100, 2, 40, 40) (100,) (100, 2, 40, 40) (100,)
# Validation: (100, 2, 40, 40) (100,) (100, 2, 40, 40) (100,)

# %%
def shuffle(x, y):
    """
    random shuffle of two paired data -> x, y = shuffle(x, y)
    but, available of one data -> x = shuffle(x, None)
    """
    idx = np.arange(len(x))
    np.random.shuffle(idx)
    if type(x) == type(y):
        return x[idx], y[idx] 
    else:
        return x[idx]
    
G_train_x, G_train_y = RandomMinibatch(G_train_X, G_train_Y, 100)
B_train_x, B_train_y = RandomMinibatch(B_train_X, B_train_Y, 100)
    
train_x, train_y = np.vstack([G_train_x, B_train_x]), np.hstack([G_train_y, B_train_y])
train_x, train_y = shuffle(train_x, train_y)

print("Training", train_x.shape, train_y.shape)
# Out:
# Training (200, 2, 40, 40) (200,)

# %%
loss_history, accr_history = [], []
val_loss_history, val_accr_history = [], []

iter_i = 0

while True:
    iter_i += 1
    
    G_train_x, G_train_y = RandomMinibatch(G_train_X, G_train_Y, 100)
    B_train_x, B_train_y = RandomMinibatch(B_train_X, B_train_Y, 100)
    
    train_x, train_y = np.vstack([G_train_x, B_train_x]), np.hstack([G_train_y, B_train_y])

    train_x, train_y = shuffle(train_x, train_y)
    
#     train_x, train_y = train_x.to(device), train_y.to(device)
    train_x, train_y = torch.tensor(train_x, device=device).float(), torch.tensor(train_y, device=device).long()
    
    output = model(train_x)
    loss = criterion(output, train_y)
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    if iter_i % 10 == 0:
        
        _, pred = torch.max(output, 1)
        
        loss_history.append(loss.tolist())
        accr_history.append((torch.sum(pred == train_y.data).tolist() / len(train_y)))
        
        with torch.no_grad():
    
            G_valid_x, G_valid_y = RandomMinibatch(G_valid_X, G_valid_Y, 100)
            B_valid_x, B_valid_y = RandomMinibatch(B_valid_X, B_valid_Y, 100)

            valid_x, valid_y = np.vstack([G_valid_x, B_valid_x]), np.hstack([G_valid_y, B_valid_y])
#             valid_x, valid_y = valid_x.to(device), valid_y.to(device)
            valid_x, valid_y = torch.tensor(valid_x, device=device).float(), torch.tensor(valid_y, device=device).long()

            valid_output = model(valid_x)
            valid_loss = criterion(valid_output, valid_y)
            
            _, valid_pred = torch.max(valid_output, 1)
        
            val_loss_history.append(valid_loss.tolist())
            val_accr_history.append((torch.sum(valid_pred == valid_y.data).tolist() / len(valid_y)))
        
        
        print("{:05d} | train_loss: {:.5f}, train_accr: {:.3f} | val_loss: {:.5f}, val_accr: {:.3f}".format(iter_i, 
                                                                                                            loss_history[-1], 
                                                                                                            accr_history[-1], 
                                                                                                            val_loss_history[-1], 
                                                                                                            val_accr_history[-1]))
        
        if iter_i >= 100:  
#             if np.mean(val_loss_history[-5 :]) >= np.mean(val_loss_history[-10:]):
#                 print('')
#                 print('Early stopping!!')
#                 print('..val_loss (avg. within 5): {:.5f} >= val_loss (avg. within 10) {:.5f}'.format(np.mean(val_loss_history[-5 :]),
#                                                                                                   np.mean(val_loss_history[-10:])))
                
            if val_loss_history[-1] == np.min(val_loss_history):

                now = datetime.datetime.now()
                nowDatetime = now.strftime('%y%m%d%H%M')
                model_name = 'A2_1_GB_{}_{:05d}_loss_{:.6f}_val_loss_{:.6f}.pt'.format(nowDatetime, iter_i, 
                                                                                     np.mean(loss_history[-3:]),
                                                                                     np.mean(val_loss_history[-3:]))
                torch.save(model.state_dict(), './model/3_Loc1/' + model_name)
#                 break                   
        if iter_i == 5000:
            break
# Out:
# 00010 | train_loss: 0.67810, train_accr: 0.595 | val_loss: 0.65941, val_accr: 0.625
# 00020 | train_loss: 0.60908, train_accr: 0.675 | val_loss: 0.61272, val_accr: 0.660
# 00030 | train_loss: 0.61326, train_accr: 0.670 | val_loss: 0.59408, val_accr: 0.715
# 00040 | train_loss: 0.55214, train_accr: 0.740 | val_loss: 0.55357, val_accr: 0.725
# 00050 | train_loss: 0.50262, train_accr: 0.805 | val_loss: 0.49118, val_accr: 0.815
# 00060 | train_loss: 0.47989, train_accr: 0.785 | val_loss: 0.46194, val_accr: 0.820
# 00070 | train_loss: 0.43034, train_accr: 0.835 | val_loss: 0.42158, val_accr: 0.830
# 00080 | train_loss: 0.40904, train_accr: 0.865 | val_loss: 0.41898, val_accr: 0.825
# 00090 | train_loss: 0.40497, train_accr: 0.825 | val_loss: 0.37455, val_accr: 0.870
# 00100 | train_loss: 0.40327, train_accr: 0.845 | val_loss: 0.36848, val_accr: 0.855
# 00110 | train_loss: 0.31845, train_accr: 0.905 | val_loss: 0.36652, val_accr: 0.855
# 00120 | train_loss: 0.31521, train_accr: 0.905 | val_loss: 0.38797, val_accr: 0.830
# 00130 | train_loss: 0.40031, train_accr: 0.820 | val_loss: 0.34930, val_accr: 0.855
# 00140 | train_loss: 0.30735, train_accr: 0.885 | val_loss: 0.31758, val_accr: 0.870
# 00150 | train_loss: 0.27995, train_accr: 0.895 | val_loss: 0.34123, val_accr: 0.860
# 00160 | train_loss: 0.28796, train_accr: 0.905 | val_loss: 0.33033, val_accr: 0.860
# 00170 | train_loss: 0.29380, train_accr: 0.905 | val_loss: 0.28723, val_accr: 0.870
# 00180 | train_loss: 0.29013, train_accr: 0.860 | val_loss: 0.28949, val_accr: 0.880
# 00190 | train_loss: 0.26329, train_accr: 0.900 | val_loss: 0.27596, val_accr: 0.875
# 00200 | train_loss: 0.30143, train_accr: 0.850 | val_loss: 0.27416, val_accr: 0.870
# 00210 | train_loss: 0.22864, train_accr: 0.940 | val_loss: 0.26403, val_accr: 0.890
# 00220 | train_loss: 0.21778, train_accr: 0.920 | val_loss: 0.23998, val_accr: 0.900
# 00230 | train_loss: 0.20295, train_accr: 0.930 | val_loss: 0.25297, val_accr: 0.880
# 00240 | train_loss: 0.20777, train_accr: 0.930 | val_loss: 0.23063, val_accr: 0.890
# 00250 | train_loss: 0.20512, train_accr: 0.925 | val_loss: 0.22158, val_accr: 0.900
# 00260 | train_loss: 0.19904, train_accr: 0.940 | val_loss: 0.25426, val_accr: 0.895
# 00270 | train_loss: 0.16402, train_accr: 0.945 | val_loss: 0.24299, val_accr: 0.905
# 00280 | train_loss: 0.23018, train_accr: 0.920 | val_loss: 0.22153, val_accr: 0.930
# 00290 | train_loss: 0.18544, train_accr: 0.945 | val_loss: 0.22142, val_accr: 0.905
# 00300 | train_loss: 0.17901, train_accr: 0.940 | val_loss: 0.21258, val_accr: 0.915
# 00310 | train_loss: 0.19005, train_accr: 0.945 | val_loss: 0.22737, val_accr: 0.905
# 00320 | train_loss: 0.14794, train_accr: 0.955 | val_loss: 0.20401, val_accr: 0.905
# 00330 | train_loss: 0.17566, train_accr: 0.950 | val_loss: 0.23903, val_accr: 0.910
# 00340 | train_loss: 0.19233, train_accr: 0.920 | val_loss: 0.19197, val_accr: 0.920
# 00350 | train_loss: 0.16045, train_accr: 0.930 | val_loss: 0.22223, val_accr: 0.905
# 00360 | train_loss: 0.17433, train_accr: 0.940 | val_loss: 0.21033, val_accr: 0.915
# 00370 | train_loss: 0.15479, train_accr: 0.945 | val_loss: 0.19675, val_accr: 0.935
# 00380 | train_loss: 0.15889, train_accr: 0.935 | val_loss: 0.19196, val_accr: 0.930
# 00390 | train_loss: 0.11500, train_accr: 0.965 | val_loss: 0.18752, val_accr: 0.925
# 00400 | train_loss: 0.12114, train_accr: 0.975 | val_loss: 0.20059, val_accr: 0.920
# 00410 | train_loss: 0.10929, train_accr: 0.970 | val_loss: 0.17474, val_accr: 0.920
# 00420 | train_loss: 0.11981, train_accr: 0.970 | val_loss: 0.18854, val_accr: 0.930
# 00430 | train_loss: 0.13382, train_accr: 0.965 | val_loss: 0.16619, val_accr: 0.930
# 00440 | train_loss: 0.09008, train_accr: 0.985 | val_loss: 0.19420, val_accr: 0.920
# 00450 | train_loss: 0.10508, train_accr: 0.985 | val_loss: 0.17582, val_accr: 0.955
# 00460 | train_loss: 0.10580, train_accr: 0.975 | val_loss: 0.17284, val_accr: 0.945
# 00470 | train_loss: 0.10660, train_accr: 0.965 | val_loss: 0.16268, val_accr: 0.940
# 00480 | train_loss: 0.08972, train_accr: 0.980 | val_loss: 0.15050, val_accr: 0.945
# 00490 | train_loss: 0.08393, train_accr: 0.975 | val_loss: 0.15359, val_accr: 0.935
# 00500 | train_loss: 0.09802, train_accr: 0.985 | val_loss: 0.18249, val_accr: 0.930
# 00510 | train_loss: 0.08352, train_accr: 0.975 | val_loss: 0.17884, val_accr: 0.910
# 00520 | train_loss: 0.11114, train_accr: 0.965 | val_loss: 0.16849, val_accr: 0.930
# 00530 | train_loss: 0.08786, train_accr: 0.980 | val_loss: 0.16246, val_accr: 0.940
# 00540 | train_loss: 0.07582, train_accr: 0.985 | val_loss: 0.15649, val_accr: 0.940
# 00550 | train_loss: 0.08143, train_accr: 0.980 | val_loss: 0.16912, val_accr: 0.935
# 00560 | train_loss: 0.06524, train_accr: 0.990 | val_loss: 0.20002, val_accr: 0.920
# 00570 | train_loss: 0.07137, train_accr: 0.985 | val_loss: 0.18789, val_accr: 0.930
# 00580 | train_loss: 0.06507, train_accr: 0.990 | val_loss: 0.18222, val_accr: 0.925
# 00590 | train_loss: 0.08224, train_accr: 0.970 | val_loss: 0.14499, val_accr: 0.940
# 00600 | train_loss: 0.04805, train_accr: 1.000 | val_loss: 0.16918, val_accr: 0.935
# 00610 | train_loss: 0.05237, train_accr: 0.995 | val_loss: 0.15758, val_accr: 0.965
# 00620 | train_loss: 0.05726, train_accr: 0.990 | val_loss: 0.16704, val_accr: 0.940
# 00630 | train_loss: 0.05512, train_accr: 0.995 | val_loss: 0.15539, val_accr: 0.945
# 00640 | train_loss: 0.05237, train_accr: 0.990 | val_loss: 0.17820, val_accr: 0.920
# 00650 | train_loss: 0.05557, train_accr: 0.990 | val_loss: 0.16597, val_accr: 0.940
# 00660 | train_loss: 0.06038, train_accr: 0.990 | val_loss: 0.16251, val_accr: 0.935
# 00670 | train_loss: 0.03273, train_accr: 1.000 | val_loss: 0.14355, val_accr: 0.960
# 00680 | train_loss: 0.04390, train_accr: 0.995 | val_loss: 0.15608, val_accr: 0.940
# 00690 | train_loss: 0.05437, train_accr: 0.985 | val_loss: 0.16572, val_accr: 0.930
# 00700 | train_loss: 0.05055, train_accr: 0.990 | val_loss: 0.13979, val_accr: 0.955
# 00710 | train_loss: 0.05181, train_accr: 0.990 | val_loss: 0.13622, val_accr: 0.955
# 00720 | train_loss: 0.05326, train_accr: 0.995 | val_loss: 0.15092, val_accr: 0.955
# 00730 | train_loss: 0.05350, train_accr: 0.985 | val_loss: 0.13217, val_accr: 0.945
# 00740 | train_loss: 0.03376, train_accr: 1.000 | val_loss: 0.15440, val_accr: 0.950
# 00750 | train_loss: 0.03134, train_accr: 1.000 | val_loss: 0.15110, val_accr: 0.930
# 00760 | train_loss: 0.04279, train_accr: 0.990 | val_loss: 0.15682, val_accr: 0.940
# 00770 | train_loss: 0.02640, train_accr: 1.000 | val_loss: 0.16048, val_accr: 0.935
# 00780 | train_loss: 0.03057, train_accr: 0.995 | val_loss: 0.15634, val_accr: 0.940
# 00790 | train_loss: 0.03706, train_accr: 0.985 | val_loss: 0.16561, val_accr: 0.935
# 00800 | train_loss: 0.03033, train_accr: 1.000 | val_loss: 0.16174, val_accr: 0.930
# 00810 | train_loss: 0.02035, train_accr: 1.000 | val_loss: 0.12378, val_accr: 0.935
# 00820 | train_loss: 0.02801, train_accr: 1.000 | val_loss: 0.16885, val_accr: 0.920
# 00830 | train_loss: 0.02258, train_accr: 1.000 | val_loss: 0.10031, val_accr: 0.960
# 00840 | train_loss: 0.02567, train_accr: 0.995 | val_loss: 0.12734, val_accr: 0.945
# 00850 | train_loss: 0.03600, train_accr: 0.995 | val_loss: 0.16978, val_accr: 0.940
# 00860 | train_loss: 0.01949, train_accr: 1.000 | val_loss: 0.14081, val_accr: 0.950
# 00870 | train_loss: 0.02408, train_accr: 1.000 | val_loss: 0.19186, val_accr: 0.925
# 00880 | train_loss: 0.03122, train_accr: 0.990 | val_loss: 0.15828, val_accr: 0.950
# 00890 | train_loss: 0.02735, train_accr: 0.995 | val_loss: 0.16765, val_accr: 0.950
# 00900 | train_loss: 0.02187, train_accr: 1.000 | val_loss: 0.19380, val_accr: 0.940
# 00910 | train_loss: 0.01661, train_accr: 1.000 | val_loss: 0.17384, val_accr: 0.935
# 00920 | train_loss: 0.01643, train_accr: 1.000 | val_loss: 0.16516, val_accr: 0.930
# 00930 | train_loss: 0.01748, train_accr: 1.000 | val_loss: 0.15471, val_accr: 0.955
# 00940 | train_loss: 0.01882, train_accr: 1.000 | val_loss: 0.15408, val_accr: 0.930
# 00950 | train_loss: 0.01888, train_accr: 1.000 | val_loss: 0.16398, val_accr: 0.935
# 00960 | train_loss: 0.01899, train_accr: 1.000 | val_loss: 0.17454, val_accr: 0.940
# 00970 | train_loss: 0.01826, train_accr: 1.000 | val_loss: 0.15440, val_accr: 0.940
# 00980 | train_loss: 0.01097, train_accr: 1.000 | val_loss: 0.14732, val_accr: 0.930
# 00990 | train_loss: 0.01334, train_accr: 1.000 | val_loss: 0.14022, val_accr: 0.950
# 01000 | train_loss: 0.01421, train_accr: 1.000 | val_loss: 0.13380, val_accr: 0.940
# 01010 | train_loss: 0.01992, train_accr: 1.000 | val_loss: 0.14857, val_accr: 0.940
# 01020 | train_loss: 0.01969, train_accr: 0.995 | val_loss: 0.15481, val_accr: 0.940
# 01030 | train_loss: 0.01440, train_accr: 1.000 | val_loss: 0.19625, val_accr: 0.935
# 01040 | train_loss: 0.01060, train_accr: 1.000 | val_loss: 0.16108, val_accr: 0.940
# 01050 | train_loss: 0.00917, train_accr: 1.000 | val_loss: 0.16594, val_accr: 0.940
# 01060 | train_loss: 0.01210, train_accr: 1.000 | val_loss: 0.19107, val_accr: 0.940
# 01070 | train_loss: 0.00871, train_accr: 1.000 | val_loss: 0.16080, val_accr: 0.945
# 01080 | train_loss: 0.01239, train_accr: 1.000 | val_loss: 0.17741, val_accr: 0.945
# 01090 | train_loss: 0.01305, train_accr: 1.000 | val_loss: 0.18272, val_accr: 0.940
# 01100 | train_loss: 0.01205, train_accr: 1.000 | val_loss: 0.16715, val_accr: 0.945
# 01110 | train_loss: 0.00906, train_accr: 1.000 | val_loss: 0.16022, val_accr: 0.940
# 01120 | train_loss: 0.00868, train_accr: 1.000 | val_loss: 0.14787, val_accr: 0.950
# 01130 | train_loss: 0.00801, train_accr: 1.000 | val_loss: 0.18111, val_accr: 0.945
# 01140 | train_loss: 0.01025, train_accr: 1.000 | val_loss: 0.16268, val_accr: 0.945
# 01150 | train_loss: 0.01023, train_accr: 1.000 | val_loss: 0.18470, val_accr: 0.940
# 01160 | train_loss: 0.01038, train_accr: 1.000 | val_loss: 0.14344, val_accr: 0.950
# 01170 | train_loss: 0.01226, train_accr: 1.000 | val_loss: 0.18586, val_accr: 0.935
# 01180 | train_loss: 0.00809, train_accr: 1.000 | val_loss: 0.18808, val_accr: 0.945
# 01190 | train_loss: 0.00766, train_accr: 1.000 | val_loss: 0.17928, val_accr: 0.940
# 01200 | train_loss: 0.00873, train_accr: 1.000 | val_loss: 0.14380, val_accr: 0.945
# 01210 | train_loss: 0.00961, train_accr: 1.000 | val_loss: 0.15962, val_accr: 0.940
# 01220 | train_loss: 0.01021, train_accr: 1.000 | val_loss: 0.13047, val_accr: 0.945
# 02790 | train_loss: 0.00096, train_accr: 1.000 | val_loss: 0.16254, val_accr: 0.960
# 02800 | train_loss: 0.00073, train_accr: 1.000 | val_loss: 0.21155, val_accr: 0.950
# 02810 | train_loss: 0.00087, train_accr: 1.000 | val_loss: 0.21468, val_accr: 0.955
# 02820 | train_loss: 0.00099, train_accr: 1.000 | val_loss: 0.22821, val_accr: 0.935
# 02830 | train_loss: 0.00057, train_accr: 1.000 | val_loss: 0.28550, val_accr: 0.935
# 02840 | train_loss: 0.00065, train_accr: 1.000 | val_loss: 0.23440, val_accr: 0.940
# 02850 | train_loss: 0.00079, train_accr: 1.000 | val_loss: 0.22581, val_accr: 0.940
# 02860 | train_loss: 0.00096, train_accr: 1.000 | val_loss: 0.26104, val_accr: 0.935
# 02870 | train_loss: 0.00095, train_accr: 1.000 | val_loss: 0.20609, val_accr: 0.945
# 02880 | train_loss: 0.00074, train_accr: 1.000 | val_loss: 0.25053, val_accr: 0.940
# 02890 | train_loss: 0.00069, train_accr: 1.000 | val_loss: 0.17164, val_accr: 0.960
# 02900 | train_loss: 0.00070, train_accr: 1.000 | val_loss: 0.24169, val_accr: 0.945
# 02910 | train_loss: 0.00051, train_accr: 1.000 | val_loss: 0.23836, val_accr: 0.935
# 02920 | train_loss: 0.00068, train_accr: 1.000 | val_loss: 0.23433, val_accr: 0.950
# 02930 | train_loss: 0.00039, train_accr: 1.000 | val_loss: 0.19962, val_accr: 0.955
# 02940 | train_loss: 0.00076, train_accr: 1.000 | val_loss: 0.25766, val_accr: 0.940
# 02950 | train_loss: 0.00071, train_accr: 1.000 | val_loss: 0.26824, val_accr: 0.945
# 02960 | train_loss: 0.00224, train_accr: 1.000 | val_loss: 0.27404, val_accr: 0.935
# 02970 | train_loss: 0.00067, train_accr: 1.000 | val_loss: 0.25049, val_accr: 0.950
# 02980 | train_loss: 0.00051, train_accr: 1.000 | val_loss: 0.25700, val_accr: 0.940
# 02990 | train_loss: 0.00052, train_accr: 1.000 | val_loss: 0.26524, val_accr: 0.930
# 03000 | train_loss: 0.00109, train_accr: 1.000 | val_loss: 0.19937, val_accr: 0.945
# 03010 | train_loss: 0.00110, train_accr: 1.000 | val_loss: 0.19974, val_accr: 0.950
# 03020 | train_loss: 0.00080, train_accr: 1.000 | val_loss: 0.24035, val_accr: 0.945
# 03030 | train_loss: 0.00053, train_accr: 1.000 | val_loss: 0.25353, val_accr: 0.940
# 03040 | train_loss: 0.00089, train_accr: 1.000 | val_loss: 0.25678, val_accr: 0.925
# 03050 | train_loss: 0.00117, train_accr: 1.000 | val_loss: 0.23373, val_accr: 0.940
# 03060 | train_loss: 0.00052, train_accr: 1.000 | val_loss: 0.18812, val_accr: 0.955
# 03070 | train_loss: 0.00044, train_accr: 1.000 | val_loss: 0.20879, val_accr: 0.940
# 03080 | train_loss: 0.00061, train_accr: 1.000 | val_loss: 0.25657, val_accr: 0.940
# 03090 | train_loss: 0.00051, train_accr: 1.000 | val_loss: 0.21034, val_accr: 0.940
# 03100 | train_loss: 0.00051, train_accr: 1.000 | val_loss: 0.21286, val_accr: 0.940
# 03110 | train_loss: 0.00080, train_accr: 1.000 | val_loss: 0.18370, val_accr: 0.965
# 03120 | train_loss: 0.00048, train_accr: 1.000 | val_loss: 0.24551, val_accr: 0.940
# 03130 | train_loss: 0.00065, train_accr: 1.000 | val_loss: 0.25261, val_accr: 0.945
# 03140 | train_loss: 0.00098, train_accr: 1.000 | val_loss: 0.24779, val_accr: 0.950
# 03150 | train_loss: 0.00037, train_accr: 1.000 | val_loss: 0.25115, val_accr: 0.930
# 03160 | train_loss: 0.00084, train_accr: 1.000 | val_loss: 0.19619, val_accr: 0.955
# 03170 | train_loss: 0.00069, train_accr: 1.000 | val_loss: 0.22934, val_accr: 0.945
# 03180 | train_loss: 0.00109, train_accr: 1.000 | val_loss: 0.25457, val_accr: 0.935
# 03190 | train_loss: 0.00058, train_accr: 1.000 | val_loss: 0.15718, val_accr: 0.955
# 03200 | train_loss: 0.00046, train_accr: 1.000 | val_loss: 0.19392, val_accr: 0.955
# 03210 | train_loss: 0.00050, train_accr: 1.000 | val_loss: 0.19731, val_accr: 0.955
# 03220 | train_loss: 0.00050, train_accr: 1.000 | val_loss: 0.25651, val_accr: 0.945
# 03230 | train_loss: 0.00060, train_accr: 1.000 | val_loss: 0.18894, val_accr: 0.955
# 03240 | train_loss: 0.00058, train_accr: 1.000 | val_loss: 0.19495, val_accr: 0.950
# 03250 | train_loss: 0.00049, train_accr: 1.000 | val_loss: 0.21758, val_accr: 0.945
# 03260 | train_loss: 0.00062, train_accr: 1.000 | val_loss: 0.21494, val_accr: 0.945
# 03270 | train_loss: 0.00040, train_accr: 1.000 | val_loss: 0.23225, val_accr: 0.945
# 03280 | train_loss: 0.00049, train_accr: 1.000 | val_loss: 0.23224, val_accr: 0.950
# 03290 | train_loss: 0.00044, train_accr: 1.000 | val_loss: 0.16355, val_accr: 0.960
# 03300 | train_loss: 0.00073, train_accr: 1.000 | val_loss: 0.21682, val_accr: 0.955
# 03310 | train_loss: 0.00041, train_accr: 1.000 | val_loss: 0.26248, val_accr: 0.955
# 03320 | train_loss: 0.00033, train_accr: 1.000 | val_loss: 0.25131, val_accr: 0.935
# 03330 | train_loss: 0.00054, train_accr: 1.000 | val_loss: 0.24866, val_accr: 0.950
# 03340 | train_loss: 0.00039, train_accr: 1.000 | val_loss: 0.23570, val_accr: 0.945
# 03350 | train_loss: 0.00070, train_accr: 1.000 | val_loss: 0.19332, val_accr: 0.940
# 03360 | train_loss: 0.00033, train_accr: 1.000 | val_loss: 0.26146, val_accr: 0.950
# 03370 | train_loss: 0.00081, train_accr: 1.000 | val_loss: 0.22370, val_accr: 0.950
# 03380 | train_loss: 0.00046, train_accr: 1.000 | val_loss: 0.24323, val_accr: 0.935
# 03390 | train_loss: 0.00067, train_accr: 1.000 | val_loss: 0.18507, val_accr: 0.960
# 03400 | train_loss: 0.00044, train_accr: 1.000 | val_loss: 0.22881, val_accr: 0.950
# 03410 | train_loss: 0.00059, train_accr: 1.000 | val_loss: 0.25323, val_accr: 0.945
# 03420 | train_loss: 0.00037, train_accr: 1.000 | val_loss: 0.23126, val_accr: 0.945
# 03430 | train_loss: 0.00047, train_accr: 1.000 | val_loss: 0.20774, val_accr: 0.960
# 03440 | train_loss: 0.00086, train_accr: 1.000 | val_loss: 0.20972, val_accr: 0.945
# 03450 | train_loss: 0.00053, train_accr: 1.000 | val_loss: 0.23489, val_accr: 0.950
# 03460 | train_loss: 0.00035, train_accr: 1.000 | val_loss: 0.22917, val_accr: 0.940
# 03470 | train_loss: 0.00057, train_accr: 1.000 | val_loss: 0.25555, val_accr: 0.945
# 03480 | train_loss: 0.00050, train_accr: 1.000 | val_loss: 0.21144, val_accr: 0.955
# 03490 | train_loss: 0.00057, train_accr: 1.000 | val_loss: 0.24742, val_accr: 0.945
# 03500 | train_loss: 0.00021, train_accr: 1.000 | val_loss: 0.22484, val_accr: 0.945
# 03510 | train_loss: 0.00060, train_accr: 1.000 | val_loss: 0.22437, val_accr: 0.940
# 03520 | train_loss: 0.00041, train_accr: 1.000 | val_loss: 0.20466, val_accr: 0.945
# 03530 | train_loss: 0.00032, train_accr: 1.000 | val_loss: 0.26016, val_accr: 0.940
# 03540 | train_loss: 0.00041, train_accr: 1.000 | val_loss: 0.23834, val_accr: 0.945
# 03550 | train_loss: 0.00043, train_accr: 1.000 | val_loss: 0.24082, val_accr: 0.955
# 03560 | train_loss: 0.00038, train_accr: 1.000 | val_loss: 0.22862, val_accr: 0.950
# 03570 | train_loss: 0.00059, train_accr: 1.000 | val_loss: 0.22692, val_accr: 0.955
# 03580 | train_loss: 0.00040, train_accr: 1.000 | val_loss: 0.22689, val_accr: 0.945
# 03590 | train_loss: 0.00040, train_accr: 1.000 | val_loss: 0.20195, val_accr: 0.950
# 03600 | train_loss: 0.00040, train_accr: 1.000 | val_loss: 0.23948, val_accr: 0.945
# 03610 | train_loss: 0.00034, train_accr: 1.000 | val_loss: 0.29518, val_accr: 0.945
# 03620 | train_loss: 0.00033, train_accr: 1.000 | val_loss: 0.25095, val_accr: 0.945
# 03630 | train_loss: 0.00034, train_accr: 1.000 | val_loss: 0.19552, val_accr: 0.960
# 03640 | train_loss: 0.00033, train_accr: 1.000 | val_loss: 0.23489, val_accr: 0.945
# 03650 | train_loss: 0.00045, train_accr: 1.000 | val_loss: 0.24417, val_accr: 0.940
# 03660 | train_loss: 0.00035, train_accr: 1.000 | val_loss: 0.20710, val_accr: 0.940
# 03670 | train_loss: 0.00038, train_accr: 1.000 | val_loss: 0.26820, val_accr: 0.945
# 03680 | train_loss: 0.00072, train_accr: 1.000 | val_loss: 0.24865, val_accr: 0.945
# 03690 | train_loss: 0.00032, train_accr: 1.000 | val_loss: 0.24071, val_accr: 0.950
# 03700 | train_loss: 0.00034, train_accr: 1.000 | val_loss: 0.25101, val_accr: 0.945
# 03710 | train_loss: 0.00027, train_accr: 1.000 | val_loss: 0.24484, val_accr: 0.950
# 03720 | train_loss: 0.00023, train_accr: 1.000 | val_loss: 0.23485, val_accr: 0.950
# 03730 | train_loss: 0.00041, train_accr: 1.000 | val_loss: 0.22195, val_accr: 0.945
# 03740 | train_loss: 0.00043, train_accr: 1.000 | val_loss: 0.26886, val_accr: 0.945
# 03750 | train_loss: 0.00034, train_accr: 1.000 | val_loss: 0.25627, val_accr: 0.950
# 03760 | train_loss: 0.00043, train_accr: 1.000 | val_loss: 0.27380, val_accr: 0.945
# 03770 | train_loss: 0.00039, train_accr: 1.000 | val_loss: 0.24258, val_accr: 0.950
# 03780 | train_loss: 0.00038, train_accr: 1.000 | val_loss: 0.20118, val_accr: 0.955
# 03790 | train_loss: 0.00034, train_accr: 1.000 | val_loss: 0.23103, val_accr: 0.945
# 03800 | train_loss: 0.00023, train_accr: 1.000 | val_loss: 0.11196, val_accr: 0.970
# 03810 | train_loss: 0.00028, train_accr: 1.000 | val_loss: 0.20994, val_accr: 0.950
# 03820 | train_loss: 0.00019, train_accr: 1.000 | val_loss: 0.28441, val_accr: 0.940
# 03830 | train_loss: 0.00034, train_accr: 1.000 | val_loss: 0.23442, val_accr: 0.955
# 03840 | train_loss: 0.00031, train_accr: 1.000 | val_loss: 0.23919, val_accr: 0.950
# 03850 | train_loss: 0.00036, train_accr: 1.000 | val_loss: 0.22094, val_accr: 0.955
# 03860 | train_loss: 0.00022, train_accr: 1.000 | val_loss: 0.27032, val_accr: 0.935
# 03870 | train_loss: 0.00028, train_accr: 1.000 | val_loss: 0.19610, val_accr: 0.945
# 03880 | train_loss: 0.00017, train_accr: 1.000 | val_loss: 0.28151, val_accr: 0.950
# 03890 | train_loss: 0.00029, train_accr: 1.000 | val_loss: 0.28359, val_accr: 0.945
# 03900 | train_loss: 0.00037, train_accr: 1.000 | val_loss: 0.18170, val_accr: 0.945
# 03910 | train_loss: 0.00038, train_accr: 1.000 | val_loss: 0.22734, val_accr: 0.955
# 03920 | train_loss: 0.00022, train_accr: 1.000 | val_loss: 0.24798, val_accr: 0.950
# 03930 | train_loss: 0.00042, train_accr: 1.000 | val_loss: 0.26393, val_accr: 0.945
# 03940 | train_loss: 0.00028, train_accr: 1.000 | val_loss: 0.23714, val_accr: 0.950
# 03950 | train_loss: 0.00031, train_accr: 1.000 | val_loss: 0.20176, val_accr: 0.950
# 03960 | train_loss: 0.00033, train_accr: 1.000 | val_loss: 0.25779, val_accr: 0.940
# 03970 | train_loss: 0.00028, train_accr: 1.000 | val_loss: 0.15244, val_accr: 0.955
# 03980 | train_loss: 0.00035, train_accr: 1.000 | val_loss: 0.27772, val_accr: 0.945
# 03990 | train_loss: 0.00026, train_accr: 1.000 | val_loss: 0.26838, val_accr: 0.935
# 04000 | train_loss: 0.00025, train_accr: 1.000 | val_loss: 0.27189, val_accr: 0.940
# 04010 | train_loss: 0.00023, train_accr: 1.000 | val_loss: 0.27586, val_accr: 0.940
# 04020 | train_loss: 0.00033, train_accr: 1.000 | val_loss: 0.24723, val_accr: 0.950
# 04030 | train_loss: 0.00014, train_accr: 1.000 | val_loss: 0.18875, val_accr: 0.945
# 04040 | train_loss: 0.00022, train_accr: 1.000 | val_loss: 0.23327, val_accr: 0.955
# 04050 | train_loss: 0.00037, train_accr: 1.000 | val_loss: 0.25508, val_accr: 0.940
# 04060 | train_loss: 0.00019, train_accr: 1.000 | val_loss: 0.26690, val_accr: 0.945
# 04070 | train_loss: 0.00033, train_accr: 1.000 | val_loss: 0.22098, val_accr: 0.945
# 04080 | train_loss: 0.00021, train_accr: 1.000 | val_loss: 0.28080, val_accr: 0.950
# 04090 | train_loss: 0.00040, train_accr: 1.000 | val_loss: 0.25457, val_accr: 0.950
# 04100 | train_loss: 0.00053, train_accr: 1.000 | val_loss: 0.21785, val_accr: 0.950
# 04110 | train_loss: 0.00042, train_accr: 1.000 | val_loss: 0.28089, val_accr: 0.935
# 04120 | train_loss: 0.00015, train_accr: 1.000 | val_loss: 0.21998, val_accr: 0.950
# 04130 | train_loss: 0.00032, train_accr: 1.000 | val_loss: 0.29756, val_accr: 0.945
# 04140 | train_loss: 0.00036, train_accr: 1.000 | val_loss: 0.23793, val_accr: 0.945
# 04150 | train_loss: 0.00019, train_accr: 1.000 | val_loss: 0.27468, val_accr: 0.950
# 04160 | train_loss: 0.00021, train_accr: 1.000 | val_loss: 0.17193, val_accr: 0.955
# 04170 | train_loss: 0.00026, train_accr: 1.000 | val_loss: 0.29865, val_accr: 0.945
# 04180 | train_loss: 0.00038, train_accr: 1.000 | val_loss: 0.20716, val_accr: 0.955
# 04190 | train_loss: 0.00023, train_accr: 1.000 | val_loss: 0.21731, val_accr: 0.950
# 04200 | train_loss: 0.00024, train_accr: 1.000 | val_loss: 0.25945, val_accr: 0.950
# 04210 | train_loss: 0.00024, train_accr: 1.000 | val_loss: 0.20438, val_accr: 0.950
# 04220 | train_loss: 0.00028, train_accr: 1.000 | val_loss: 0.27108, val_accr: 0.950
# 04230 | train_loss: 0.00031, train_accr: 1.000 | val_loss: 0.22598, val_accr: 0.955
# 04240 | train_loss: 0.00025, train_accr: 1.000 | val_loss: 0.26228, val_accr: 0.940
# 04250 | train_loss: 0.00021, train_accr: 1.000 | val_loss: 0.25125, val_accr: 0.950
# 04260 | train_loss: 0.00019, train_accr: 1.000 | val_loss: 0.25340, val_accr: 0.940
# 04270 | train_loss: 0.00031, train_accr: 1.000 | val_loss: 0.26251, val_accr: 0.940
# 04280 | train_loss: 0.00031, train_accr: 1.000 | val_loss: 0.30527, val_accr: 0.945
# 04290 | train_loss: 0.00017, train_accr: 1.000 | val_loss: 0.23549, val_accr: 0.950
# 04300 | train_loss: 0.00021, train_accr: 1.000 | val_loss: 0.22198, val_accr: 0.950
# 04310 | train_loss: 0.00017, train_accr: 1.000 | val_loss: 0.19273, val_accr: 0.955
# 04320 | train_loss: 0.00021, train_accr: 1.000 | val_loss: 0.27318, val_accr: 0.935
# 04330 | train_loss: 0.00027, train_accr: 1.000 | val_loss: 0.24678, val_accr: 0.935
# 04340 | train_loss: 0.00020, train_accr: 1.000 | val_loss: 0.27941, val_accr: 0.940
# 04350 | train_loss: 0.00021, train_accr: 1.000 | val_loss: 0.32514, val_accr: 0.940
# 04360 | train_loss: 0.00038, train_accr: 1.000 | val_loss: 0.26445, val_accr: 0.940
# 04370 | train_loss: 0.00050, train_accr: 1.000 | val_loss: 0.22141, val_accr: 0.940
# 04380 | train_loss: 0.00021, train_accr: 1.000 | val_loss: 0.27679, val_accr: 0.945
# 04390 | train_loss: 0.00029, train_accr: 1.000 | val_loss: 0.19153, val_accr: 0.945
# 04400 | train_loss: 0.00026, train_accr: 1.000 | val_loss: 0.29276, val_accr: 0.935
# 04410 | train_loss: 0.00019, train_accr: 1.000 | val_loss: 0.32083, val_accr: 0.945
# 04420 | train_loss: 0.00029, train_accr: 1.000 | val_loss: 0.30292, val_accr: 0.935
# 04430 | train_loss: 0.00016, train_accr: 1.000 | val_loss: 0.28201, val_accr: 0.945
# 04440 | train_loss: 0.00015, train_accr: 1.000 | val_loss: 0.22197, val_accr: 0.955
# 04450 | train_loss: 0.00027, train_accr: 1.000 | val_loss: 0.28521, val_accr: 0.950
# 04460 | train_loss: 0.00013, train_accr: 1.000 | val_loss: 0.28658, val_accr: 0.950
# 04470 | train_loss: 0.00021, train_accr: 1.000 | val_loss: 0.26861, val_accr: 0.950
# 04480 | train_loss: 0.00023, train_accr: 1.000 | val_loss: 0.30846, val_accr: 0.940
# 04490 | train_loss: 0.00020, train_accr: 1.000 | val_loss: 0.23701, val_accr: 0.955
# 04500 | train_loss: 0.00020, train_accr: 1.000 | val_loss: 0.27404, val_accr: 0.945
# 04510 | train_loss: 0.00022, train_accr: 1.000 | val_loss: 0.22956, val_accr: 0.945
# 04520 | train_loss: 0.00018, train_accr: 1.000 | val_loss: 0.24948, val_accr: 0.945
# 04530 | train_loss: 0.00025, train_accr: 1.000 | val_loss: 0.22730, val_accr: 0.950
# 04540 | train_loss: 0.00015, train_accr: 1.000 | val_loss: 0.28624, val_accr: 0.945
# 04550 | train_loss: 0.00028, train_accr: 1.000 | val_loss: 0.25990, val_accr: 0.935
# 04560 | train_loss: 0.00030, train_accr: 1.000 | val_loss: 0.25505, val_accr: 0.955
# 04570 | train_loss: 0.00018, train_accr: 1.000 | val_loss: 0.27753, val_accr: 0.945
# 04580 | train_loss: 0.00018, train_accr: 1.000 | val_loss: 0.19943, val_accr: 0.950
# 04590 | train_loss: 0.00026, train_accr: 1.000 | val_loss: 0.24626, val_accr: 0.950
# 04600 | train_loss: 0.00033, train_accr: 1.000 | val_loss: 0.21671, val_accr: 0.950
# 04610 | train_loss: 0.00018, train_accr: 1.000 | val_loss: 0.30648, val_accr: 0.950
# 04620 | train_loss: 0.00019, train_accr: 1.000 | val_loss: 0.23897, val_accr: 0.950
# 04630 | train_loss: 0.00016, train_accr: 1.000 | val_loss: 0.20997, val_accr: 0.955
# 04640 | train_loss: 0.00013, train_accr: 1.000 | val_loss: 0.22464, val_accr: 0.945
# 04650 | train_loss: 0.00020, train_accr: 1.000 | val_loss: 0.25562, val_accr: 0.945
# 04660 | train_loss: 0.00017, train_accr: 1.000 | val_loss: 0.27735, val_accr: 0.945
# 04670 | train_loss: 0.00018, train_accr: 1.000 | val_loss: 0.28840, val_accr: 0.935
# 04680 | train_loss: 0.00026, train_accr: 1.000 | val_loss: 0.29337, val_accr: 0.945
# 04690 | train_loss: 0.00014, train_accr: 1.000 | val_loss: 0.28361, val_accr: 0.950
# 04700 | train_loss: 0.00013, train_accr: 1.000 | val_loss: 0.27757, val_accr: 0.940
# 04710 | train_loss: 0.00019, train_accr: 1.000 | val_loss: 0.19236, val_accr: 0.960
# 04720 | train_loss: 0.00009, train_accr: 1.000 | val_loss: 0.23524, val_accr: 0.950
# 04730 | train_loss: 0.00014, train_accr: 1.000 | val_loss: 0.26930, val_accr: 0.950
# 04740 | train_loss: 0.00016, train_accr: 1.000 | val_loss: 0.31968, val_accr: 0.935
# 04750 | train_loss: 0.00011, train_accr: 1.000 | val_loss: 0.24485, val_accr: 0.950
# 04760 | train_loss: 0.00014, train_accr: 1.000 | val_loss: 0.23725, val_accr: 0.950
# 04770 | train_loss: 0.00032, train_accr: 1.000 | val_loss: 0.20272, val_accr: 0.965
# 04780 | train_loss: 0.00025, train_accr: 1.000 | val_loss: 0.24292, val_accr: 0.945
# 04790 | train_loss: 0.00013, train_accr: 1.000 | val_loss: 0.20043, val_accr: 0.955
# 04800 | train_loss: 0.00016, train_accr: 1.000 | val_loss: 0.25068, val_accr: 0.955
# 04810 | train_loss: 0.00009, train_accr: 1.000 | val_loss: 0.26172, val_accr: 0.950
# 04820 | train_loss: 0.00015, train_accr: 1.000 | val_loss: 0.25881, val_accr: 0.955
# 04830 | train_loss: 0.00016, train_accr: 1.000 | val_loss: 0.28769, val_accr: 0.950
# 04840 | train_loss: 0.00015, train_accr: 1.000 | val_loss: 0.26511, val_accr: 0.950
# 04850 | train_loss: 0.00018, train_accr: 1.000 | val_loss: 0.23414, val_accr: 0.945
# 04860 | train_loss: 0.00014, train_accr: 1.000 | val_loss: 0.20676, val_accr: 0.960
# 04870 | train_loss: 0.00010, train_accr: 1.000 | val_loss: 0.27548, val_accr: 0.940
# 04880 | train_loss: 0.00020, train_accr: 1.000 | val_loss: 0.24253, val_accr: 0.945
# 04890 | train_loss: 0.00014, train_accr: 1.000 | val_loss: 0.25776, val_accr: 0.950
# 04900 | train_loss: 0.00010, train_accr: 1.000 | val_loss: 0.25032, val_accr: 0.955
# 04910 | train_loss: 0.00011, train_accr: 1.000 | val_loss: 0.32545, val_accr: 0.940
# 04920 | train_loss: 0.00019, train_accr: 1.000 | val_loss: 0.30933, val_accr: 0.935
# 04930 | train_loss: 0.00015, train_accr: 1.000 | val_loss: 0.23438, val_accr: 0.950
# 04940 | train_loss: 0.00016, train_accr: 1.000 | val_loss: 0.27126, val_accr: 0.945
# 04950 | train_loss: 0.00014, train_accr: 1.000 | val_loss: 0.20755, val_accr: 0.950
# 04960 | train_loss: 0.00021, train_accr: 1.000 | val_loss: 0.27398, val_accr: 0.945
# 04970 | train_loss: 0.00014, train_accr: 1.000 | val_loss: 0.19675, val_accr: 0.955
# 04980 | train_loss: 0.00015, train_accr: 1.000 | val_loss: 0.31551, val_accr: 0.935
# 04990 | train_loss: 0.00011, train_accr: 1.000 | val_loss: 0.24953, val_accr: 0.950
# 05000 | train_loss: 0.00009, train_accr: 1.000 | val_loss: 0.28992, val_accr: 0.945

# %%
fig = plt.figure(figsize = (15,17))
plt.suptitle('Training History', y = 0.92, fontsize = 20)

# x_axis = range(1, 10*len(accr_history)+1, 10)
x_axis = np.arange(10, 10*len(accr_history)+1, 10)

plt.subplot(2, 1, 1)
plt.plot(x_axis, accr_history, 'b-', label = 'Training Accuracy')
plt.plot(x_axis, val_accr_history, 'r-', label = 'Validation Accuracy')
plt.xlabel('Iteration', fontsize = 15)
plt.ylabel('Accuracy', fontsize = 15)
plt.legend(fontsize = 10)
plt.grid('on')
plt.subplot(2, 1, 2)
plt.plot(x_axis, loss_history, 'b-', label = 'Training Loss')
plt.plot(x_axis, val_loss_history, 'r-', label = 'Validation Loss')
plt.xlabel('Iteration', fontsize = 15)
plt.ylabel('Loss', fontsize = 15)
# plt.yticks(np.arange(0, 0.25, step=0.025))
plt.legend(fontsize = 12)
plt.grid('on')
plt.show()

# if save == True:
#     fig.savefig(hist_path + filename)
#     plt.close(fig)
# Out:
# /home/yunseob/Pytorch/lib/python3.5/site-packages/matplotlib/cbook/__init__.py:424: MatplotlibDeprecationWarning:
# Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warn_deprecated("2.2", "Passing one of 'on', 'true', 'off', 'false' as a "

# %%
np.save('./results/0_train_hist/npy/A2_1_GB_accr_history', accr_history)
np.save('./results/0_train_hist/npy/A2_1_GB_val_accr_history', val_accr_history)
np.save('./results/0_train_hist/npy/A2_1_GB_loss_history', loss_history)
np.save('./results/0_train_hist/npy/A2_1_GB_val_loss_history', val_loss_history)
